# %%
# %matplotlib inline

# %%
import dew_gwdata as gd

# %%
db = gd.sageodata()

# %%
wls = gd.fetch_wl_data(db.find_wells("MOR81"))
wls.plot(x="obs_date", y="rswl")

# %%
wls = gd.fetch_wl_data(db.find_wells("MOR81"), exclude_hydstra_qcs=())
wls.plot(x="obs_date", y="rswl")

# %%
wls = gd.fetch_wl_data(db.find_wells("MOR81"), exclude_hydstra_qcs=("Missing",))
wls.plot(x="obs_date", y="rswl")

# %%
wls = gd.fetch_wl_data(db.find_wells("MOR81"), exclude_hydstra_qcs=("undefined",))
wls.plot(x="obs_date", y="rswl")
