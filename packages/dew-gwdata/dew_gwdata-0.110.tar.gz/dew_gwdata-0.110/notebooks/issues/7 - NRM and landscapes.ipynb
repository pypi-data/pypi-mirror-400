# %%
import dew_gwdata as gd

db = gd.sageodata()

# %%
wells = db.wells_in_group_type("OMN").dh_no

# %%
summ = db.wells_summary(wells)
summ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12387 entries, 0 to 389
# Data columns (total 65 columns):
# well_id                      12387 non-null object
# dh_no                        12387 non-null int64
# unit_long                    12387 non-null int64
# unit_hyphen                  12387 non-null object
# obs_no                       10588 non-null object
# dh_name                      4853 non-null object
# easting                      12387 non-null float64
# northing                     12387 non-null float64
# zone                         12387 non-null int64
# latitude                     12387 non-null float64
# longitude                    12387 non-null float64
# aquifer                      11770 non-null object
# pwa                          8154 non-null object
# pwra                         2283 non-null object
# nrm                          12338 non-null object
# landscape                    12343 non-null object
# ...

# %%
summ[["well_id", "pwa", "pwra", "nrm", "landscape"]]
# Out:
#     well_id                    pwa  pwra  \
# 0    WNT011              Far North  None
# 1    WNT019              Far North  None
# 2    WNT007              Far North  None
# 3    WNT018              Far North  None
# 4    WNT015              Far North  None
# ..      ...                    ...   ...
# 385  BEN020  Lower Limestone Coast  None
# 386  HIN114  Lower Limestone Coast  None
# 387  GAM263  Lower Limestone Coast  None
# 388  CAR081  Lower Limestone Coast  None
# 389  RMK409                   None  None
#
#                                        nrm                    landscape
# 0              South Australian Arid Lands  South Australian Arid Lands
# 1              South Australian Arid Lands  South Australian Arid Lands
# 2              South Australian Arid Lands  South Australian Arid Lands
# 3              South Australian Arid Lands  South Australian Arid Lands
# 4              South Australian Arid Lands  South Australian Arid Lands
# ...
