# %%
from rich.console import Console

console = Console(force_jupyter=True)  # 👈
console.print("Hello [bold blue]world[/]\nAAAAAAAA")
# Out:
# Hello world
# AAAAAAAA

# %%
from rich.console import Console

console = Console(force_jupyter=False)  # 👈
console.print("1 Hello [bold blue]world[/]")
console.print("2 Hello [grey50]world[/]")
console.print("3 Hello [grey70]world[/]")
console.print("4 Hello [dim white]world[/]")
console.print("5 Hello [dim black]world[/]")
console.print("6 Hello [dim]world[/]")
console.print("7 Hello [bright]world[/]")
print()
console.print("6 Hello [dim grey50]dim grey50[/]")
console.print("6 Hello [grey50]grey50[/]")
console.print("7 Hello [bright grey50]bright grey50[/]")
# Out:
# 1 Hello world
# 2 Hello world
# 3 Hello world
# 4 Hello world
# 5 Hello world
# 6 Hello world
# 7 Hello world
#
# 6 Hello dim grey50
# 6 Hello grey50
# 7 Hello bright grey50

# %%
from rich.console import Console

console = Console(force_terminal=False)  # 👈
console.print("Hello [bold blue]world[/]\nAAAAAAAA")
print(console.color_system)
print(console.is_terminal)
# Out:
# Hello world
# AAAAAAAA
# truecolor
# False

# %%
import sys, os
sys.path.insert(0, "src")
os.chdir("/Users/andrewsazonov/Development/github.com/EasyScience/diffraction-lib")
#import easydiffraction as ed

# %%
project = ed.Project()

# %%
import easydiffraction as ed

# %%
project.plotter.show_supported_engines()
#project.plotter.show_config()
# Out:
#    Supported plotter engines
# <style>.ed-tbl th, .ed-tbl td { line-height: 1.9 !important;padding-top: 0.0em !important; padding-bottom: 0.0em !important; padding-left: 0.6em !important; padding-right: 0.6em !important; }.ed-tbl th div, .ed-tbl td div { line-height: 1.9 !important;padding-top: 0.0em !important; padding-bottom: 0.0em !important; padding-left: 0.6em !important; padding-right: 0.6em !important; }.ed-tbl thead th { border-bottom: 1px solid color-mix(in srgb, currentColor 20%, transparent) !important; }.ed-tbl tbody th { font-weight: normal !important; opacity: 0.5 !important; color: inherit !important; }</style><table class="dataframe ed-tbl" style="border-collapse: separate; border: 1px solid color-mix(in srgb, currentColor 20%, transparent); margin-left: 0.4em;margin-top: 0.5em;margin-bottom: 1em;max-width: 60em;">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th style="text-align: left;">Engine</th>
#       <th style="text-align: left;">Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td><div style="text-align: left;">asciichartpy</div></td>
#       <td><div style="text-align: left;">Console ASCII line charts</div></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><div style="text-align: left;">plotly</div></td>
#       <td><div style="text-align: left;">Interactive browser-based graphing library</div></td>
#     </tr>
#   </tbody>
# </table>

# %%
project.tabler.show_supported_engines()
#project.tabler.show_config()
# Out:
#    Supported engines
#    Engine                              Description
# 0    rich              Console rendering with Rich
# 1  pandas  Jupyter DataFrame rendering with Pandas

# %%
project.tabler.engine = 'pandas'
# Out:
# WARNING  Engine is already set to 'pandas'. No change made.

# %%
project.tabler.engine = 'rich'
# Out:
# WARNING  Engine is already set to 'rich'. No change made.

# %%
project.plotter.show_supported_engines()
# Out:
#    Supported plotter engines
# <style>.ed-tbl th, .ed-tbl td { line-height: 1.9 !important;padding-top: 0.0em !important; padding-bottom: 0.0em !important; padding-left: 0.6em !important; padding-right: 0.6em !important; }.ed-tbl th div, .ed-tbl td div { line-height: 1.9 !important;padding-top: 0.0em !important; padding-bottom: 0.0em !important; padding-left: 0.6em !important; padding-right: 0.6em !important; }.ed-tbl thead th { border-bottom: 1px solid color-mix(in srgb, currentColor 20%, transparent) !important; }.ed-tbl tbody th { font-weight: normal !important; opacity: 0.5 !important; color: inherit !important; }</style><table class="dataframe ed-tbl" style="border-collapse: separate; border: 1px solid color-mix(in srgb, currentColor 20%, transparent); margin-left: 0.4em;margin-top: 0.5em;margin-bottom: 1em;max-width: 60em;">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th style="text-align: left;">Engine</th>
#       <th style="text-align: left;">Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td><div style="text-align: left;">asciichartpy</div></td>
#       <td><div style="text-align: left;">Console ASCII line charts</div></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><div style="text-align: left;">plotly</div></td>
#       <td><div style="text-align: left;">Interactive browser-based graphing library</div></td>
#     </tr>
#   </tbody>
# </table>

# %%
project.tabler.engine = 'rich2'
# Out:
# WARNING  Engine 'rich2' is not supported. Available engines: 'rich', 'pandas'

# %%
project.tabler.show_supported_engines()
# Out:
#    Supported engines
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 project.tabler.show_supported_engines()                                                      │
# │   2                                                                                              │
# │                                                                                                  │
# │ /Users/andrewsazonov/Development/github.com/easyscience/diffraction-lib/src/easydiffraction/disp │
# │ lay/base.py:71 in show_supported_engines                                                         │
# │                                                                                                  │
# │   68 │   │   log.paragraph('Supported engines')                                                  │
# │   69 │   │   # from easydiffraction.utils.utils import render_table                              │
# │   70 │   │   # render_table(headers, rows)                                                       │
# │ ❱ 71 │   │   self.render(headers, rows)                                                          │
# │   72                                                                                             │
# │   73                                                                                             │
# │   74 class RendererFactoryBase(ABC):                                                             │
# │                                                                                                  │
# │ /Users/andrewsazonov/Development/github.com/easyscience/diffraction-lib/src/easydiffraction/disp │
# │ lay/tables.py:45 in render                                                                       │
# │                                                                                                  │
# │   42 │   │   *,                                                                                  │
# │   43 │   │   align: Sequence[str] | None = None,                                                 │
# │   44 │   ) -> Any:                                                                               │
# │ ❱ 45 │   │   return self._backend.render(                                                        │
# │   46 │   │   │   headers=headers,                                                                │
# │   47 │   │   │   rows=rows,                                                                      │
# │   48 │   │   │   align=align,                                                                    │
# │                                                                                                  │
# │ /Users/andrewsazonov/Development/github.com/easyscience/diffraction-lib/src/easydiffraction/disp │
# │ lay/tablers/rich.py:53 in render                                                                 │
# │                                                                                                  │
# │   50 │   │   align: Sequence[str] | None = None,                                                 │
# │   51 │   ) -> Any:                                                                               │
# │   52 │   │   table = Table(                                                                      │
# │ ❱ 53 │   │   │   title=None, box=self._box, show_header=True, header_style='bold', border_sty    │
# │   54 │   │   )                                                                                   │
# │   55 │   │   for i, header in enumerate(headers):                                                │
# │   56 │   │   │   if align is not None and i < len(align):                                        │
# │                                                                                                  │
# │ /Users/andrewsazonov/Development/github.com/easyscience/diffraction-lib/src/easydiffraction/disp │
# │ lay/tablers/rich.py:31 in _box                                                                   │
# │                                                                                                  │
# │   28 │   │   │ ││ foot                                                                           │
# │   29 │   │   └─┴┘ bottom                                                                         │
# │   30 │   │   """                                                                                 │
# │ ❱ 31 │   │   return Box(                                                                         │
# │   32 │   │   │   """\                                                                            │
# │   33 │   │   │   │   ┌──┐                                                                        │
# │   34 │   │   │   │   │  │                                                                        │
# │                                                                                                  │
# │ /Users/andrewsazonov/Development/github.com/easyscience/diffraction-lib/.pixi/envs/default/lib/p │
# │ ython3.13/site-packages/rich/box.py:30 in __init__                                               │
# │                                                                                                  │
# │    27 │   def __init__(self, box: str, *, ascii: bool = False) -> None:                          │
# │    28 │   │   self._box = box                                                                    │
# │    29 │   │   self.ascii = ascii                                                                 │
# │ ❱  30 │   │   line1, line2, line3, line4, line5, line6, line7, line8 = box.splitlines()          │
# │    31 │   │   # top                                                                              │
# │    32 │   │   self.top_left, self.top, self.top_divider, self.top_right = iter(line1)            │
# │    33 │   │   # head                                                                             │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: too many values to unpack (expected 8)
