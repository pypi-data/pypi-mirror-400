# %%
import pandas as pd
import dew_gwdata as gd
import sqlite3

# %%
aq = gd.DEWAquarius(
    "prod",
    cache_conn=sqlite3.connect(r"c:\devapps\kent\apps\wk-prod\waterkennect.sqlite"),
)

# %%
# %%time
aq.find_locations(name="*PTA*", from_cache=True)
# Out:
# Wall time: 88.6 ms
#         loc_id                      loc_name                  folder  publish  \
# 0   6628-18942       NAP - PTA093 (Tomw(T1))      All Locations.FOUO        0
# 1   6628-19134       NAP - PTA094 (Tomw(T1))      All Locations.FOUO        0
# 2   6628-19717      NAP  - PTA051 (Tomw(T1))      All Locations.FOUO        0
# 3   6628-18881       NAP - PTA161 (Tomw(T1))      All Locations.FOUO        0
# 4   6628-20136       NAP - PTA111 (Tomw(T1))      All Locations.FOUO        0
# 5   6628-20759            NAP  - PTA116 (T2)  All Locations.FOUO.DEW        0
# 6   6628-21005            NAP  - PTA127 (T1)  All Locations.FOUO.DEW        0
# 7   6628-16257            NAP  - PTA091 (T2)  All Locations.FOUO.DEW        0
# 8    6628-3356            NAP  - PTA072 (T1)  All Locations.FOUO.DEW        0
# 9   6628-11479          Metro  - PTA067 (T2)  All Locations.FOUO.DEW        0
# 10  6628-13920           Metro - PTA082 (T2)  All Locations.FOUO.DEW        0
# ...

# %%
loc_ids = gd.identify_aq_locations("A0231013 A0011 6628-20328", aq=aq)
loc_ids
# Out:
# ['6628-20328', 'A0231013']

# %%
df = aq.find_locations("A0231013")

# %%
# %%time
df = aq.fetch_locations_data(loc_ids, from_cache=True).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 0 to 1
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   loc_id                       2 non-null      object
#  1   loc_name                     2 non-null      object
#  2   loc_type                     2 non-null      object
#  3   loc_descr                    2 non-null      object
#  4   publish                      2 non-null      int64
#  5   folder                       2 non-null      object
#  6   tags                         2 non-null      object
#  7   modified_date                2 non-null      object
#  8   latitude                     2 non-null      float64
#  9   longitude                    2 non-null      float64
#  10  elev                         2 non-null      float64
#  11  WDTFSYNC                     0 non-null      object
#  12  WDTFDATAOWNER                0 non-null      object
# ...

# %%
# %%time
df = aq.fetch_locations_data(name="Chowilla *", from_cache=False)
# Out:
# Wall time: 3.84 s

# %%
df[["loc_id", "tags"]]
# Out:
#        loc_id                                               tags
# 0    A4260535  Local Government Area:UIA RIVERLAND|NRM Region...
# 1    A4260693  Local Government Area:RENMARK PARINGA|Hundreds...
# 2    A4261091  Local Government Area:UIA RIVERLAND|NRM Region...
# 3    A4261107  Local Government Area:UIA RIVERLAND|NRM Region...
# 4    A4261167  Local Government Area:UIA RIVERLAND|NRM Region...
# 5    A4261169  Local Government Area:UIA RIVERLAND|NRM Region...
# 6    A4261224  Local Government Area:UIA RIVERLAND|NRM Region...
# 7   7029-1477
# 8   7029-1479
# 9   7029-1478
# 10    7030-85
# 11    7030-86
# 12    7030-87
# 13   7030-360
# 14   7030-442
# 15   7030-405
# 16   7030-447
# 17   7030-453
# 18   7030-486
# 19   7030-601
# 20   7030-603
# 21   7030-644
# 22   7030-654
# 23   7030-659
# 24   7030-663
# 25   7030-671
# 26   7030-695
# 27   7030-699
# 28   7030-703
# 29   7030-704
# 30   7030-718
# 31   7030-705
# 32   7030-722
# 33   7030-719
# 34   7030-734
# 35   7030-735
# ...
