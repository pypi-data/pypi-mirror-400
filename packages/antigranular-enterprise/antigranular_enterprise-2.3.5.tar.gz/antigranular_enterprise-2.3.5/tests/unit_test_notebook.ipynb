# %%
# %run -m pytest -v unit_test.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.10.11, pytest-7.4.0, pluggy-1.2.0 -- c:\Users\taori\Documents\AntigranularClient-11\venv\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\taori\Documents\AntigranularClient-11\tests
# plugins: cov-4.1.0
# collecting ... collected 5 items
#
# unit_test.py::test_connect PASSED                                        [ 20%]
# unit_test.py::test_interrupt_kernel PASSED                               [ 40%]
# unit_test.py::test_terminate_session PASSED                              [ 60%]
# unit_test.py::test_privacy_odometer PASSED                               [ 80%]
# unit_test.py::test_submit_predictions PASSED                             [100%]
#
# ============================== 5 passed in 1.20s ==============================
