# %% [markdown]
# # **Example**: Splitting Text Files with `CharacterSplitter`, `WordSplitter`, `SentenceSplitter`, `ParagraphSplitter`
#
# When processing a plain text file, such as an e-book or an instruction guidebook, for downstream tasks like LLM ingestion, annotation, or search, it is often necessary to divide it into smaller, manageable chunks.
#
# **SplitterMR provides the functionality to segment such files into groups of characters, words, sentences, or paragraphs**. Furthermore, it allows for overlapping chunks to maintain contextual continuity. This example will illustrate the application of each splitter, utilizing the first chapter of "*El Famoso Hidalgo Don Quijote de la Mancha*" (original language) as the sample text.
#
# ![El Quijote](https://www.cartv.es/thumbs/990x750r/2021-05/quijote-1-1-.jpg)

# %% [markdown]
# ## Step 1: Read the Text Document
#
# We will use [**Vanilla Reader**](https://andreshere00.github.io/Splitter_MR/api_reference/reader/#vanillareader) to load our text file. The result will be [`ReaderOutput`](https://andreshere00.github.io/Splitter_MR/api_reference/reader/#output-format), a Pydantic object with the following fields:

# %%
from splitter_mr.reader import VanillaReader

reader = VanillaReader()
data = "https://raw.githubusercontent.com/andreshere00/Splitter_MR/refs/heads/main/data/quijote_example.txt"  # Path to your file
reader_output = reader.read(data)
print(reader_output.model_dump_json(indent=4))
# Out:
# {
#     "text": "Capítulo Primero\n\nQue trata de la condición y ejercicio del famoso hidalgo D. Quijote de la Mancha\n\nEn un lugar de la Mancha, de cuyo nombre no quiero acordarme, no ha mucho tiempo que vivía un hidalgo de los de lanza en astillero, adarga antigua, rocín flaco y galgo corredor. Una olla de algo más vaca que carnero, salpicón las más noches, duelos y quebrantos los sábados, lentejas los viernes, algún palomino de añadidura los domingos, consumían las tres partes de su hacienda. El resto della concluían sayo de velarte, calzas de velludo para las fiestas con sus pantuflos de lo mismo, los días de entre semana se honraba con su vellori de lo más fino. Tenía en su casa una ama que pasaba de los cuarenta, y una sobrina que no llegaba a los veinte, y un mozo de campo y plaza, que así ensillaba el rocín como tomaba la podadera. Frisaba la edad de nuestro hidalgo con los cincuenta años, era de complexión recia, seco de carnes, enjuto de rostro; gran madrugador y amigo de la caza. Quieren decir que tenía el sobrenombre de Quijada o Quesada (que en esto hay alguna diferencia en los autores que deste caso escriben), aunque por conjeturas verosímiles se deja entender que se llama Quijana; pero esto importa poco a nuestro cuento; basta que en la narración dél no se salga un punto de la verdad.\n\nEs, pues, de saber, que este sobredicho hidalgo, los ratos que estaba ocioso (que eran los más del año) se daba a leer libros de caballerías con tanta afición y gusto, que olvidó casi de todo punto el ejercicio de la caza, y aun la administración de su hacienda; y llegó a tanto su curiosidad y desatino en esto, que vendió muchas hanegas de tierra de sembradura, para comprar libros de caballerías en que leer; y así llevó a su casa todos cuantos pudo haber dellos; y de todos ningunos le parecían tan bien como los que compuso el famoso Feliciano de Silva: porque la claridad de su prosa, y aquellas intrincadas razones suyas, le parecían de perlas; y más cuando llegaba a leer aquellos requiebros y cartas de desafío, donde en muchas partes hallaba escrito: la razón de la sinrazón que a mi razón se hace, de tal manera mi razón enflaquece, que con razón me quejo de la vuestra fermosura, y también cuando leía: los altos cielos que de vuestra divinidad divinamente con las estrellas se fortifican, y os hacen merecedora del merecimiento que merece la vuestra grandeza. Con estas y semejantes razones perdía el pobre caballero el juicio, y desvelábase por entenderlas, y desentrañarles el sentido, que no se lo sacara, ni las entendiera el mismo Aristóteles, si resucitara para sólo ello. No estaba muy bien con las heridas que don Belianis daba y recibía, porque se imaginaba que por grandes maestros que le hubiesen curado, no dejaría de tener el rostro y todo el cuerpo lleno de cicatrices y señales; pero con todo alababa en su autor aquel acabar su libro con la promesa de aquella inacabable aventura, y muchas veces le vino deseo de tomar la pluma, y darle fin al pie de la letra como allí se promete; y sin duda alguna lo hiciera, y aun saliera con ello, si otros mayores y continuos pensamientos no se lo estorbaran.\n\nTuvo muchas veces competencia con el cura de su lugar (que era hombre docto graduado en Sigüenza), sobre cuál había sido mejor caballero, Palmerín de Inglaterra o Amadís de Gaula; mas maese Nicolás, barbero del mismo pueblo, decía que ninguno llegaba al caballero del Febo, y que si alguno se le podía comparar, era don Galaor, hermano de Amadís de Gaula, porque tenía muy acomodada condición para todo; que no era caballero melindroso, ni tan llorón como su hermano, y que en lo de la valentía no le iba en zaga.\n\nEn resolución, él se enfrascó tanto en su lectura, que se le pasaban las noches leyendo de claro en claro, y los días de turbio en turbio, y así, del poco dormir y del mucho leer, se le secó el cerebro, de manera que vino a perder el juicio. Llenósele la fantasía de todo aquello que leía en los libros, así de encantamientos, como ...
#     "document_name": "quijote_example.txt",
#     "document_path": "https://raw.githubusercontent.com/andreshere00/Splitter_MR/refs/heads/main/data/quijote_example.txt",
#     "document_id": "fdbbad6f-bfca-41c2-be76-22b4af7bf119",
#     "conversion_method": "txt",
#     "reader_method": "vanilla",
#     "ocr_method": null,
#     "page_placeholder": null,
#     "metadata": {}
# }

# %% [markdown]
# If you want to extract the text, you can access the content via the `text` attribute:

# %%
print(reader_output.text)
# Out:
# Capítulo Primero
#
# Que trata de la condición y ejercicio del famoso hidalgo D. Quijote de la Mancha
#
# En un lugar de la Mancha, de cuyo nombre no quiero acordarme, no ha mucho tiempo que vivía un hidalgo de los de lanza en astillero, adarga antigua, rocín flaco y galgo corredor. Una olla de algo más vaca que carnero, salpicón las más noches, duelos y quebrantos los sábados, lentejas los viernes, algún palomino de añadidura los domingos, consumían las tres partes de su hacienda. El resto della concluían sayo de velarte, calzas de velludo para las fiestas con sus pantuflos de lo mismo, los días de entre semana se honraba con su vellori de lo más fino. Tenía en su casa una ama que pasaba de los cuarenta, y una sobrina que no llegaba a los veinte, y un mozo de campo y plaza, que así ensillaba el rocín como tomaba la podadera. Frisaba la edad de nuestro hidalgo con los cincuenta años, era de complexión recia, seco de carnes, enjuto de rostro; gran madrugador y amigo de la caza. Quieren decir que tenía el sobrenombre de Quijada o Quesada (que en esto hay alguna diferencia en los autores que deste caso escriben), aunque por conjeturas verosímiles se deja entender que se llama Quijana; pero esto importa poco a nuestro cuento; basta que en la narración dél no se salga un punto de la verdad.
#
# Es, pues, de saber, que este sobredicho hidalgo, los ratos que estaba ocioso (que eran los más del año) se daba a leer libros de caballerías con tanta afición y gusto, que olvidó casi de todo punto el ejercicio de la caza, y aun la administración de su hacienda; y llegó a tanto su curiosidad y desatino en esto, que vendió muchas hanegas de tierra de sembradura, para comprar libros de caballerías en que leer; y así llevó a su casa todos cuantos pudo haber dellos; y de todos ningunos le parecían tan bien como los que compuso el famoso Feliciano de Silva: porque la claridad de su prosa, y aquellas intrincadas razones suyas, le parecían de perlas; y más cuando llegaba a le
sula Malindrania, a quien venció en singular batalla el jamás como se debe alabado caballero D. Quijote de la Mancha, el cual me mandó que me presentase ante la vuestra merced, para que la vuestra grandeza disponga de mí a su talante? ¡Oh, cómo se holgó nuestro buen caballero, cuando hubo hecho este discurso, y más cuando halló a quién dar nombre de su dama! Y fue, a lo que se cree, que en un lugar cerca del suyo había una moza labradora de muy buen parecer, de quien él un tiempo anduvo enamorado, aunque según se entiende, ella jamás lo supo ni se dió cata de ello. Llamábase Aldonza Lorenzo, y a esta le pareció ser bien darle título de señora de sus pensamientos; y buscándole nombre que no desdijese mucho del suyo, y que tirase y se encaminase al de princesa y gran señora, vino a llamarla DULCINEA DEL TOBOSO, porque era natural del Toboso, nombre a su parecer músico y peregrino y significativo, como todos los demás que a él y a sus cosas había puesto.

# %% [markdown]
# ---
#
# ## Step 2: Split the Document
#
# We will try four different splitting strategies: by **characters**, **words**, **sentences**, and **paragraphs**. Remember that you can adjust the chunk size as needed.

# %%
from splitter_mr.splitter import (
    CharacterSplitter,
    WordSplitter,
    SentenceSplitter,
    ParagraphSplitter,
)

# %% [markdown]
# ---
#
# ### 2.1. Split by **Characters**
#
# Firstly, we will test the character-based splitting strategy. To do this, you can instantiate the [**`CharacterSplitter`**](https://andreshere00.github.io/Splitter_MR/api_reference/splitter/#charactersplitter) class with the splitting attributes as your choice and pass the reader's output to the split method of this class. Accessing the [**`SplitterOutput`**](https://andreshere00.github.io/Splitter_MR/api_reference/splitter/#splitter_mr.schema.models.SplitterOutput) object's content is then straightforward:

# %%
char_splitter = CharacterSplitter(chunk_size=100)
char_splitter_output = char_splitter.split(reader_output)

print(char_splitter_output.model_dump_json(indent=4))
# Out:
# {
#     "chunks": [
#         "Capítulo Primero\n\nQue trata de la condición y ejercicio del famoso hidalgo D. Quijote de la Mancha\n\n",
#         "En un lugar de la Mancha, de cuyo nombre no quiero acordarme, no ha mucho tiempo que vivía un hidalg",
#         "o de los de lanza en astillero, adarga antigua, rocín flaco y galgo corredor. Una olla de algo más v",
#         "aca que carnero, salpicón las más noches, duelos y quebrantos los sábados, lentejas los viernes, alg",
#         "ún palomino de añadidura los domingos, consumían las tres partes de su hacienda. El resto della conc",
#         "luían sayo de velarte, calzas de velludo para las fiestas con sus pantuflos de lo mismo, los días de",
#         " entre semana se honraba con su vellori de lo más fino. Tenía en su casa una ama que pasaba de los c",
#         "uarenta, y una sobrina que no llegaba a los veinte, y un mozo de campo y plaza, que así ensillaba el",
#         " rocín como tomaba la podadera. Frisaba la edad de nuestro hidalgo con los cincuenta años, era de co",
#         "mplexión recia, seco de carnes, enjuto de rostro; gran madrugador y amigo de la caza. Quieren decir ",
#         "que tenía el sobrenombre de Quijada o Quesada (que en esto hay alguna diferencia en los autores que ",
#         "deste caso escriben), aunque por conjeturas verosímiles se deja entender que se llama Quijana; pero ",
#         "esto importa poco a nuestro cuento; basta que en la narración dél no se salga un punto de la verdad.",
#         "\n\nEs, pues, de saber, que este sobredicho hidalgo, los ratos que estaba ocioso (que eran los más del",
#         " año) se daba a leer libros de caballerías con tanta afición y gusto, que olvidó casi de todo punto ",
#         "el ejercicio de la caza, y aun la administración de su hacienda; y llegó a tanto su curiosidad y des",
#         "atino en esto, que vendió muchas hanegas de tierra de sembradura, para comprar libros de caballerías",
#         " en que leer; y así llevó a su casa todos cuantos pudo haber dellos; y de todos ningunos le parecían",
#         " tan bien como los que compuso el famoso Feliciano de Silva: porque la claridad de su prosa, y aquel",
#         "las intrincadas razones suyas, le parecían de perlas; y más cuando llegaba a leer aquellos requiebro",
#         "s y cartas de desafío, donde en muchas partes hallaba escrito: la razón de la sinrazón que a mi razó",
#         "n se hace, de tal manera mi razón enflaquece, que con razón me quejo de la vuestra fermosura, y tamb",
#         "ién cuando leía: los altos cielos que de vuestra divinidad divinamente con las estrellas se fortific",
#         "an, y os hacen merecedora del merecimiento que merece la vuestra grandeza. Con estas y semejantes ra",
#         "zones perdía el pobre caballero el juicio, y desvelábase por entenderlas, y desentrañarles el sentid",
#         "o, que no se lo sacara, ni las entendiera el mismo Aristóteles, si resucitara para sólo ello. No est",
#         "aba muy bien con las heridas que don Belianis daba y recibía, porque se imaginaba que por grandes ma",
#         "estros que le hubiesen curado, no dejaría de tener el rostro y todo el cuerpo lleno de cicatrices y ",
#         "señales; pero con todo alababa en su autor aquel acabar su libro con la promesa de aquella inacababl",
#         "e aventura, y muchas veces le vino deseo de tomar la pluma, y darle fin al pie de la letra como allí",
#         " se promete; y sin duda alguna lo hiciera, y aun saliera con ello, si otros mayores y continuos pens",
#         "amientos no se lo estorbaran.\n\nTuvo muchas veces competencia con el cura de su lugar (que era hombre",
#         " docto graduado en Sigüenza), sobre cuál había sido mejor caballero, Palmerín de Inglaterra o Amadís",
#         " de Gaula; mas maese Nicolás, barbero del mismo pueblo, decía que ninguno llegaba al caballero del F",
#         "ebo, y que si alguno se le podía comparar, era don Galaor, hermano de Amadís de Gaula, porque tenía ",
#         "muy acomodada condición para todo; que no era caballero melindroso, ni tan llorón como su hermano, y",
#         " que en lo de la valentía no le iba en zaga.\n\nEn resolución, él se enfrascó tanto en su lectura, que",
#         " se le pasaban las noches leyendo de claro en claro, y los días de turbio en turbio, y así, del poco",
#         " dormir y del mucho leer, se le secó el cerebro, de manera que vino a perder el juicio. Llenósele la",
#         " fantasía de todo aquello que leía en los libros, así de encantamientos, como de pendencias, batalla",
#         "s, desafíos, heridas, requiebros, amores, tormentas y disparates imposibles, y asentósele de tal mod",
#         "o en la imaginación que era verdad toda aquella máquina de aquellas soñadas invenciones que leía, qu",
#         "e para él no había otra historia más cierta en el mundo.\n\nDecía él, que el Cid Ruy Díaz había sido m",
#         "uy buen caballero; pero que no tenía que ver con el caballero de la ardiente espada, que de sólo un ",
#         "revés había partido por medio dos fieros y descomunales gigantes. Mejor estaba con Bernardo del Carp",
#         "io, porque en Roncesvalle había muerto a Roldán el encantado, valiéndose de la industria de Hércules",
#         ", cuando ahogó a Anteo, el hijo de la Tierra, entre los brazos. Decía mucho bien del gigante Morgant",
#         "e, porque con ser de aquella generación gigantesca, que todos son soberbios y descomedidos, él solo ",
#         "era afable y bien criado; pero sobre todos estaba bien con Reinaldos de Montalbán, y más cuando le v",
#         "eía salir de su castillo y robar cuantos topaba, y cuando en Allende robó aquel ídolo de Mahoma, que",
#         " era todo de oro, según dice su historia. Diera él, por dar una mano de coces al traidor de Galalón,",
#         " al ama que tenía y aun a su sobrina de añadidura.\n\nEn efecto, rematado ya su juicio, vino a dar en ",
#         "el más extraño pensamiento que jamás dio loco en el mundo, y fue que le pareció convenible y necesar",
#         "io, así para el aumento de su honra, como para el servicio de su república, hacerse caballero andant",
#         "e, e irse por todo el mundo con sus armas y caballo a buscar las aventuras, y a ejercitarse en todo ",
#         "aquello que él había leído, que los caballeros andantes se ejercitaban, deshaciendo todo género de a",
#         "gravio, y poniéndose en ocasiones y peligros, donde acabándolos, cobrase eterno nombre y fama.\n\nImag",
#         "inábase el pobre ya coronado por el valor de su brazo por lo menos del imperio de Trapisonda: y así ",
#         "con estos tan agradables pensamientos, llevado del estraño gusto que en ellos sentía, se dió priesa ",
#         "a poner en efecto lo que deseaba. Y lo primero que hizo, fue limpiar unas armas, que habían sido de ",
#         "sus bisabuelos, que, tomadas de orín y llenas de moho, luengos siglos había que estaban puestas y ol",
#         "vidadas en un rincón. Limpiólas y aderezólas lo mejor que pudo; pero vió que tenían una gran falta, ",
#         "y era que no tenía celada de encaje, sino morrión simple; mas a esto suplió su industria, porque de ",
#         "cartones hizo un modo de media celada, que encajada con el morrión, hacía una apariencia de celada e",
#         "ntera. Es verdad que para probar si era fuerte, y podía estar al riesgo de una cuchillada, sacó su e",
#         "spada, y le dió dos golpes, y con el primero y en un punto deshizo lo que había hecho en una semana:",
#         " y no dejó de parecerle mal la facilidad con que la había hecho pedazos, y por asegurarse de este pe",
#         "ligro, lo tornó a hacer de nuevo, poniéndole unas barras de hierro por de dentro de tal manera, que ",
#         "él quedó satisfecho de su fortaleza; y, sin querer hacer nueva experiencia de ella, la diputó y tuvo",
#         " por celada finísima de encaje. Fue luego a ver a su rocín, y aunque tenía más cuartos que un real, ",
#         "y más tachas que el caballo de Gonela, que tantum pellis, et ossa fuit, le pareció que ni el Bucéfal",
#         "o de Alejandro, ni Babieca el del Cid con él se igualaban. Cuatro días se le pasaron en imaginar qué",
#         " nombre le podría: porque, según se decía él a sí mismo, no era razón que caballo de caballero tan f",
#         "amoso, y tan bueno él por sí, estuviese sin nombre conocido; y así procuraba acomodársele, de manera",
#         " que declarase quien había sido, antes que fuese de caballero andante, y lo que era entones: pues es",
#         "taba muy puesto en razón, que mudando su señor estado, mudase él también el nombre; y le cobrase fam",
#         "oso y de estruendo, como convenía a la nueva orden y al nuevo ejercicio que ya profesaba: y así desp",
#         "ués de muchos nombres que formó, borró y quitó, añadió, deshizo y tornó a hacer en su memoria e imag",
#         "inación, al fin le vino a llamar ROCINANTE, nombre a su parecer alto, sonoro y significativo de lo q",
#         "ue había sido cuando fue rocín, antes de lo que ahora era, que era antes y primero de todos los roci",
#         "nes del mundo. Puesto nombre y tan a su gusto a su caballo, quiso ponérsele a sí mismo, y en este pe",
#         "nsamiento, duró otros ocho días, y al cabo se vino a llamar DON QUIJOTE, de donde como queda dicho, ",
#         "tomaron ocasión los autores de esta tan verdadera historia, que sin duda se debía llamar Quijada, y ",
#         "no Quesada como otros quisieron decir. Pero acordándose que el valeroso Amadís, no sólo se había con",
#         "tentado con llamarse Amadís a secas, sino que añadió el nombre de su reino y patria, por hacerla fam",
#         "osa, y se llamó Amadís de Gaula, así quiso, como buen caballero, añadir al suyo el nombre de la suya",
#         ", y llamarse DON QUIJOTE DE LA MANCHA, con que a su parecer declaraba muy al vivo su linaje y patria",
#         ", y la honraba con tomar el sobrenombre della.\n\nLimpias, pues, sus armas, hecho del morrión celada, ",
#         "puesto nombre a su rocín, y confirmándose a sí mismo, se dió a entender que no le faltaba otra cosa,",
#         " sino buscar una dama de quien enamorarse, porque el caballero andante sin amores, era árbol sin hoj",
#         "as y sin fruto, y cuerpo sin alma. Decíase él: si yo por malos de mis pecados, por por mi buena suer",
#         "te, me encuentro por ahí con algún gigante, como de ordinario les acontece a los caballeros andantes",
#         ", y le derribo de un encuentro, o le parto por mitad del cuerpo, o finalmente, le venzo y le rindo, ",
#         "¿no será bien tener a quién enviarle presentado, y que entre y se hinque de rodillas ante mi dulce s",
#         "eñora, y diga con voz humilde y rendida: yo señora, soy el gigante Caraculiambro, señor de la ínsula",
#         " Malindrania, a quien venció en singular batalla el jamás como se debe alabado caballero D. Quijote ",
#         "de la Mancha, el cual me mandó que me presentase ante la vuestra merced, para que la vuestra grandez",
#         "a disponga de mí a su talante? ¡Oh, cómo se holgó nuestro buen caballero, cuando hubo hecho este dis",
#         "curso, y más cuando halló a quién dar nombre de su dama! Y fue, a lo que se cree, que en un lugar ce",
#         "rca del suyo había una moza labradora de muy buen parecer, de quien él un tiempo anduvo enamorado, a",
#         "unque según se entiende, ella jamás lo supo ni se dió cata de ello. Llamábase Aldonza Lorenzo, y a e",
#         "sta le pareció ser bien darle título de señora de sus pensamientos; y buscándole nombre que no desdi",
#         "jese mucho del suyo, y que tirase y se encaminase al de princesa y gran señora, vino a llamarla DULC",
#         "INEA DEL TOBOSO, porque era natural del Toboso, nombre a su parecer músico y peregrino y significati",
#         "vo, como todos los demás que a él y a sus cosas había puesto."
#     ],
#     "chunk_id": [
#         "4aed6451-a49c-4bbf-9cd8-f0f4af96ebb1",
#         "8551ec7d-11c4-48c1-a8f0-5aefdeb5f01d",
#         "50bb1f51-adc2-433c-86df-b74f628a850e",
#         "5d3d296c-9e9b-4e34-83f9-6f7d7168673e",
#         "3c991d9e-fd39-4696-8017-adafaf0f1644",
#         "c572942a-91d9-42b9-a172-f3864ca7d8a7",
#         "9502ea9c-b309-41e9-bd1b-1a42a10902ae",
#         "17f9b752-096c-4dd3-97f8-d40f99d1c85a",
#         "020eb171-7c9a-470d-b5c5-ac27bb59e5d8",
#         "23d10724-d8a4-4c58-a426-df4c0730819a",
#         "b2eb49b2-239a-4347-a9c5-62a77a115c70",
#         "421a8777-a4a5-4cd1-bec1-76955a8b4a57",
#         "8bb94c76-ee6d-4629-9ce1-d381ffd35d6d",
#         "0e08592e-92e2-4d00-b08e-34c3e84f9459",
#         "905a7916-5f43-4e0d-aab1-0137cda37cf1",
#         "6d93f65c-110b-4961-982a-cc468efea21d",
#         "604bc31c-c55b-473d-bef6-94516ae45d54",
#         "c7bf4fda-49b9-48ba-b0b1-4cc3b3d67bd0",
#         "a97554d6-cfb1-4b9b-bdf8-1c90741f4226",
#         "eb7f51fe-a396-493d-b02b-6b17d74b0427",
#         "0fc73de2-47ab-4e73-8b1c-f94f4c4d18e4",
#         "1749c0be-8f69-415e-b4ba-b6437d18ea2e",
#         "b7098e30-cabd-48e4-b3ec-f1375709cb00",
#         "7090ed8a-1a86-417e-ae6e-f46343922f44",
#         "7d92e72c-d01e-4306-be95-5edd2c973dd2",
#         "729cf8bb-5250-4675-9947-a99f3346c768",
#         "e9cbd22a-9841-4574-a921-95fbe8533c5c",
#         "35a6d12e-df13-45cf-b44f-eefd2a0f1f4f",
#         "d14c9da0-9275-433c-8b6a-7a1270a704f1",
#         "586d102c-68a0-4aa7-a462-40d3d07190f3",
#         "6393628d-6dfd-46dd-bf5e-7e2193febbbe",
#         "901bb728-49b3-4ae2-bc3f-d4a1643379b2",
#         "5c08bfc9-afc8-4876-b0d1-d034141a133c",
#         "092d9558-1ec4-4f32-9034-968b37a023cd",
#         "ee74f8e2-8133-4fb7-a908-89ad20180670",
#         "ca915548-16d9-4f9f-9c83-e6fdce806dc7",
#         "e8ab6113-0133-4f66-82c8-db23168cc3a4",
#         "bdcb695a-6ff1-405b-bc43-a9d141be6232",
#         "f271505a-fb75-44b9-ab85-5ee9941036db",
#         "c69fdc5e-a712-4a18-8caf-0a7ac6a5f46a",
#         "7a1e8061-fdaa-4a23-9481-a3bcdffb186a",
#         "0020d2a3-5e35-4d86-9aae-0e22ced9c80a",
#         "61d38da3-ab89-4dc4-b443-0812619c08fb",
#         "e1e7c217-b713-4e4c-9a0f-f97b8749b3d6",
#         "f230e6f5-18a5-45de-b87f-e54d9cc077f7",
#         "bb409309-cee4-44e0-8a59-cfe13b0425c6",
#         "83d0bc00-e4d6-4646-a0a4-12a0ef26fd34",
#         "c1fc8df7-7a29-4080-b64f-45eedf9e5353",
#         "afc0001a-01e3-4c38-9b96-0a594f9a3c26",
#         "c72705bc-a819-4dfa-abaf-c8712460e31e",
#         "6bd115f8-3ae3-4cad-8961-86aa14f79a52",
#         "6de9b06c-98f2-4488-aea3-e62c04b14d7f",
#         "16931cb3-2b9d-4111-b0ad-3601ef856f9a",
#         "0d384272-3085-4f54-8d3f-a25695a72799",
#         "9b80265d-db06-4304-acec-f9ee581f4110"
#     ],
#     "document_name": "quijote_example.txt",
#     "document_path": "https://raw.githubusercontent.com/andreshere00/Splitter_MR/refs/heads/main/data/quijote_example.txt",
#     "document_id": "fdbbad6f-bfca-41c2-be76-22b4af7bf119",
#     "conversion_method": "txt",
#     "reader_method": "vanilla",
#     "ocr_method": null,
#     "split_method": "character_splitter",
#     "split_params": {
#         "chunk_size": 100,
#         "chunk_overlap": 0
#     },
#     "metadata": {}
# }

# %% [markdown]
# To visualize each chunk, you can use the following instruction:

# %%
for idx, chunk in enumerate(char_splitter_output.chunks):
    print("=" * 40 + f" Chunk {idx + 1} " + "=" * 40 + "\n" + chunk + "\n")
# Out:
# ======================================== Chunk 1 ========================================
# Capítulo Primero
#
# Que trata de la condición y ejercicio del famoso hidalgo D. Quijote de la Mancha
#
#
#
# ======================================== Chunk 2 ========================================
# En un lugar de la Mancha, de cuyo nombre no quiero acordarme, no ha mucho tiempo que vivía un hidalg
#
# ======================================== Chunk 3 ========================================
# o de los de lanza en astillero, adarga antigua, rocín flaco y galgo corredor. Una olla de algo más v
#
# ======================================== Chunk 4 ========================================
# aca que carnero, salpicón las más noches, duelos y quebrantos los sábados, lentejas los viernes, alg
#
# ======================================== Chunk 5 ========================================
# ún palomino de añadidura los domingos, consumían las tres partes de su hacienda. El resto della conc
#
# ======================================== Chunk 6 ========================================
# luían sayo de velarte, calzas de velludo para las fiestas con sus pantuflos de lo mismo, los días de
#
# ======================================== Chunk 7 ========================================
#  entre semana se honraba con su vellori de lo más fino. Tenía en su casa una ama que pasaba de los c
#
# ======================================== Chunk 8 ========================================
# uarenta, y una sobrina que no llegaba a los veinte, y un mozo de campo y plaza, que así ensillaba el
#
# ======================================== Chunk 9 ========================================
#  rocín como tomaba la podadera. Frisaba la edad de nuestro hidalgo con los cincuenta años, era de co
#
# ======================================== Chunk 10 ========================================
# mplexión recia, seco de carnes, enjuto de rostro; gran madrugador y amigo de la caza. Quieren decir
#
# ======================================== Chunk 11 ========================================
# que tenía el sobrenombre de Quijada o Quesada (que en esto hay alguna diferencia en los autores que
#
# ======================================== Chunk 12 ========================================
# deste caso escriben), aunque por conjeturas verosímiles se deja entender que se llama Quijana; pero
#
# ======================================== Chunk 13 ========================================
# esto importa poco a nuestro cuento; basta que en la narración dél no se salga un punto de la verdad.
#
# ======================================== Chunk 14 ========================================
#
#
# Es, pues, de saber, que este sobredicho hidalgo, los ratos que estaba ocioso (que eran los más del
#
# ======================================== Chunk 15 ========================================
#  año) se daba a leer libros de caballerías con tanta afición y gusto, que olvidó casi de todo punto
#
# ======================================== Chunk 16 ========================================
# el ejercicio de la caza, y aun la administración de su hacienda; y llegó a tanto su curiosidad y des
#
# ======================================== Chunk 17 ========================================
# atino en esto, que vendió muchas hanegas de tierra de sembradura, para comprar libros de caballerías
#
# ======================================== Chunk 18 ========================================
#  en que leer; y así llevó a su casa todos cuantos pudo haber dellos; y de todos ningunos le parecían
#
# ======================================== Chunk 19 ========================================
#  tan bien como los que compuso el famoso Feliciano de Silva: porque la claridad de su prosa, y aquel
#
# ======================================== Chunk 20 ========================================
# las intrincadas razones suyas, le parecían de perlas; y más cuando llegaba a leer aquellos requiebro
#
# ======================================== Chunk 21 ========================================
# s y cartas de desafío, donde en muchas partes hallaba escrito: la razón de la sinrazón que a mi razó
#
# ======================================== Chunk 22 ========================================
# n se hace, de tal manera mi razón enflaquece, que con razón me quejo de la vuestra fermosura, y tamb
#
# ======================================== Chunk 23 ========================================
# ién cuando leía: los altos cielos que de vuestra divinidad divinamente con las estrellas se fortific
#
# ======================================== Chunk 24 ========================================
# an, y os hacen merecedora del merecimiento que merece la vuestra grandeza. Con estas y semejantes ra
#
# ======================================== Chunk 25 ========================================
# zones perdía el pobre caballero el juicio, y desvelábase por entenderlas, y desentrañarles el sentid
#
# ======================================== Chunk 26 ========================================
# o, que no se lo sacara, ni las entendiera el mismo Aristóteles, si resucitara para sólo ello. No est
#
# ======================================== Chunk 27 ========================================
# aba muy bien con las heridas que don Belianis daba y recibía, porque se imaginaba que por grandes ma
#
# ======================================== Chunk 28 ========================================
# estros que le hubiesen curado, no dejaría de tener el rostro y todo el cuerpo lleno de cicatrices y
#
# ======================================== Chunk 29 ========================================
# señales; pero con todo alababa en su autor aquel acabar su libro con la promesa de aquella inacababl
#
# ======================================== Chunk 30 ========================================
# e aventura, y muchas veces le vino deseo de tomar la pluma, y darle fin al pie de la letra como allí
#
# ======================================== Chunk 31 ========================================
#  se promete; y sin duda alguna lo hiciera, y aun saliera con ello, si otros mayores y continuos pens
#
# ======================================== Chunk 32 ========================================
# amientos no se lo estorbaran.
#
# Tuvo muchas veces competencia con el cura de su lugar (que era hombre
#
# ======================================== Chunk 33 ========================================
#  docto graduado en Sigüenza), sobre cuál había sido mejor caballero, Palmerín de Inglaterra o Amadís
#
# ======================================== Chunk 34 ========================================
#  de Gaula; mas maese Nicolás, barbero del mismo pueblo, decía que ninguno llegaba al caballero del F
#
# ======================================== Chunk 35 ========================================
# ebo, y que si alguno se le podía comparar, era don Galaor, hermano de Amadís de Gaula, porque tenía
#
# ======================================== Chunk 36 ========================================
# muy acomodada condición para todo; que no era caballero melindroso, ni tan llorón como su hermano, y
#
# ======================================== Chunk 37 ========================================
#  que en lo de la valentía no le iba en zaga.
#
# En resolución, él se enfrascó tanto en su lectura, que
#
# ======================================== Chunk 38 ========================================
#  se le pasaban las noches leyendo de claro en claro, y los días de turbio en turbio, y así, del poco
#
# ======================================== Chunk 39 ========================================
#  dormir y del mucho leer, se le secó el cerebro, de manera que vino a perder el juicio. Llenósele la
#
# ======================================== Chunk 40 ========================================
#  fantasía de todo aquello que leía en los libros, así de encantamientos, como de pendencias, batalla
#
# ======================================== Chunk 41 ========================================
# s, desafíos, heridas, requiebros, amores, tormentas y disparates imposibles, y asentósele de tal mod
#
# ======================================== Chunk 42 ========================================
# o en la imaginación que era verdad toda aquella máquina de aquellas soñadas invenciones que leía, qu
#
# ======================================== Chunk 43 ========================================
# e para él no había otra historia más cierta en el mundo.
#
# Decía él, que el Cid Ruy Díaz había sido m
#
# ======================================== Chunk 44 ========================================
# uy buen caballero; pero que no tenía que ver con el caballero de la ardiente espada, que de sólo un
#
# ======================================== Chunk 45 ========================================
# revés había partido por medio dos fieros y descomunales gigantes. Mejor estaba con Bernardo del Carp
#
# ======================================== Chunk 46 ========================================
# io, porque en Roncesvalle había muerto a Roldán el encantado, valiéndose de la industria de Hércules
#
# ======================================== Chunk 47 ========================================
# , cuando ahogó a Anteo, el hijo de la Tierra, entre los brazos. Decía mucho bien del gigante Morgant
#
# ======================================== Chunk 48 ========================================
# e, porque con ser de aquella generación gigantesca, que todos son soberbios y descomedidos, él solo
#
# ======================================== Chunk 49 ========================================
# era afable y bien criado; pero sobre todos estaba bien con Reinaldos de Montalbán, y más cuando le v
#
# ======================================== Chunk 50 ========================================
# eía salir de su castillo y robar cuantos topaba, y cuando en Allende robó aquel ídolo de Mahoma, que
#
# ======================================== Chunk 51 ========================================
#  era todo de oro, según dice su historia. Diera él, por dar una mano de coces al traidor de Galalón,
#
# ======================================== Chunk 52 ========================================
#  al ama que tenía y aun a su sobrina de añadidura.
#
# En efecto, rematado ya su juicio, vino a dar en
#
# ======================================== Chunk 53 ========================================
# el más extraño pensamiento que jamás dio loco en el mundo, y fue que le pareció convenible y necesar
#
# ======================================== Chunk 54 ========================================
# io, así para el aumento de su honra, como para el servicio de su república, hacerse caballero andant
#
# ======================================== Chunk 55 ========================================
# e, e irse por todo el mundo con sus armas y caballo a buscar las aventuras, y a ejercitarse en todo
#
# ======================================== Chunk 56 ========================================
# aquello que él había leído, que los caballeros andantes se ejercitaban, deshaciendo todo género de a
#
# ======================================== Chunk 57 ========================================
# gravio, y poniéndose en ocasiones y peligros, donde acabándolos, cobrase eterno nombre y fama.
#
# Imag
#
# ======================================== Chunk 58 ========================================
# inábase el pobre ya coronado por el valor de su brazo por lo menos del imperio de Trapisonda: y así
#
# ======================================== Chunk 59 ========================================
# con estos tan agradables pensamientos, llevado del estraño gusto que en ellos sentía, se dió priesa
#
# ======================================== Chunk 60 ========================================
# a poner en efecto lo que deseaba. Y lo primero que hizo, fue limpiar unas armas, que habían sido de
#
# ======================================== Chunk 61 ========================================
# sus bisabuelos, que, tomadas de orín y llenas de moho, luengos siglos había que estaban puestas y ol
#
# ======================================== Chunk 62 ========================================
# vidadas en un rincón. Limpiólas y aderezólas lo mejor que pudo; pero vió que tenían una gran falta,
#
# ======================================== Chunk 63 ========================================
# y era que no tenía celada de encaje, sino morrión simple; mas a esto suplió su industria, porque de
#
# ======================================== Chunk 64 ========================================
# cartones hizo un modo de media celada, que encajada con el morrión, hacía una apariencia de celada e
#
# ======================================== Chunk 65 ========================================
# ntera. Es verdad que para probar si era fuerte, y podía estar al riesgo de una cuchillada, sacó su e
#
# ======================================== Chunk 66 ========================================
# spada, y le dió dos golpes, y con el primero y en un punto deshizo lo que había hecho en una semana:
#
# ======================================== Chunk 67 ========================================
#  y no dejó de parecerle mal la facilidad con que la había hecho pedazos, y por asegurarse de este pe
#
# ======================================== Chunk 68 ========================================
# ligro, lo tornó a hacer de nuevo, poniéndole unas barras de hierro por de dentro de tal manera, que
#
# ======================================== Chunk 69 ========================================
# él quedó satisfecho de su fortaleza; y, sin querer hacer nueva experiencia de ella, la diputó y tuvo
#
# ======================================== Chunk 70 ========================================
#  por celada finísima de encaje. Fue luego a ver a su rocín, y aunque tenía más cuartos que un real,
#
# ======================================== Chunk 71 ========================================
# y más tachas que el caballo de Gonela, que tantum pellis, et ossa fuit, le pareció que ni el Bucéfal
#
# ======================================== Chunk 72 ========================================
# o de Alejandro, ni Babieca el del Cid con él se igualaban. Cuatro días se le pasaron en imaginar qué
#
# ======================================== Chunk 73 ========================================
#  nombre le podría: porque, según se decía él a sí mismo, no era razón que caballo de caballero tan f
#
# ======================================== Chunk 74 ========================================
# amoso, y tan bueno él por sí, estuviese sin nombre conocido; y así procuraba acomodársele, de manera
#
# ======================================== Chunk 75 ========================================
#  que declarase quien había sido, antes que fuese de caballero andante, y lo que era entones: pues es
#
# ======================================== Chunk 76 ========================================
# taba muy puesto en razón, que mudando su señor estado, mudase él también el nombre; y le cobrase fam
#
# ======================================== Chunk 77 ========================================
# oso y de estruendo, como convenía a la nueva orden y al nuevo ejercicio que ya profesaba: y así desp
#
# ======================================== Chunk 78 ========================================
# ués de muchos nombres que formó, borró y quitó, añadió, deshizo y tornó a hacer en su memoria e imag
#
# ======================================== Chunk 79 ========================================
# inación, al fin le vino a llamar ROCINANTE, nombre a su parecer alto, sonoro y significativo de lo q
#
# ======================================== Chunk 80 ========================================
# ue había sido cuando fue rocín, antes de lo que ahora era, que era antes y primero de todos los roci
#
# ======================================== Chunk 81 ========================================
# nes del mundo. Puesto nombre y tan a su gusto a su caballo, quiso ponérsele a sí mismo, y en este pe
#
# ======================================== Chunk 82 ========================================
# nsamiento, duró otros ocho días, y al cabo se vino a llamar DON QUIJOTE, de donde como queda dicho,
#
# ======================================== Chunk 83 ========================================
# tomaron ocasión los autores de esta tan verdadera historia, que sin duda se debía llamar Quijada, y
#
# ======================================== Chunk 84 ========================================
# no Quesada como otros quisieron decir. Pero acordándose que el valeroso Amadís, no sólo se había con
#
# ======================================== Chunk 85 ========================================
# tentado con llamarse Amadís a secas, sino que añadió el nombre de su reino y patria, por hacerla fam
#
# ======================================== Chunk 86 ========================================
# osa, y se llamó Amadís de Gaula, así quiso, como buen caballero, añadir al suyo el nombre de la suya
#
# ======================================== Chunk 87 ========================================
# , y llamarse DON QUIJOTE DE LA MANCHA, con que a su parecer declaraba muy al vivo su linaje y patria
#
# ======================================== Chunk 88 ========================================
# , y la honraba con tomar el sobrenombre della.
#
# Limpias, pues, sus armas, hecho del morrión celada,
#
# ======================================== Chunk 89 ========================================
# puesto nombre a su rocín, y confirmándose a sí mismo, se dió a entender que no le faltaba otra cosa,
#
# ======================================== Chunk 90 ========================================
#  sino buscar una dama de quien enamorarse, porque el caballero andante sin amores, era árbol sin hoj
#
# ======================================== Chunk 91 ========================================
# as y sin fruto, y cuerpo sin alma. Decíase él: si yo por malos de mis pecados, por por mi buena suer
#
# ======================================== Chunk 92 ========================================
# te, me encuentro por ahí con algún gigante, como de ordinario les acontece a los caballeros andantes
#
# ======================================== Chunk 93 ========================================
# , y le derribo de un encuentro, o le parto por mitad del cuerpo, o finalmente, le venzo y le rindo,
#
# ======================================== Chunk 94 ========================================
# ¿no será bien tener a quién enviarle presentado, y que entre y se hinque de rodillas ante mi dulce s
#
# ======================================== Chunk 95 ========================================
# eñora, y diga con voz humilde y rendida: yo señora, soy el gigante Caraculiambro, señor de la ínsula
#
# ======================================== Chunk 96 ========================================
#  Malindrania, a quien venció en singular batalla el jamás como se debe alabado caballero D. Quijote
#
# ======================================== Chunk 97 ========================================
# de la Mancha, el cual me mandó que me presentase ante la vuestra merced, para que la vuestra grandez
#
# ======================================== Chunk 98 ========================================
# a disponga de mí a su talante? ¡Oh, cómo se holgó nuestro buen caballero, cuando hubo hecho este dis
#
# ======================================== Chunk 99 ========================================
# curso, y más cuando halló a quién dar nombre de su dama! Y fue, a lo que se cree, que en un lugar ce
#
# ======================================== Chunk 100 ========================================
# rca del suyo había una moza labradora de muy buen parecer, de quien él un tiempo anduvo enamorado, a
#
# ======================================== Chunk 101 ========================================
# unque según se entiende, ella jamás lo supo ni se dió cata de ello. Llamábase Aldonza Lorenzo, y a e
#
# ======================================== Chunk 102 ========================================
# sta le pareció ser bien darle título de señora de sus pensamientos; y buscándole nombre que no desdi
#
# ======================================== Chunk 103 ========================================
# jese mucho del suyo, y que tirase y se encaminase al de princesa y gran señora, vino a llamarla DULC
#
# ======================================== Chunk 104 ========================================
# INEA DEL TOBOSO, porque era natural del Toboso, nombre a su parecer músico y peregrino y significati
#
# ======================================== Chunk 105 ========================================
# vo, como todos los demás que a él y a sus cosas había puesto.

# %% [markdown]
# As you can see, the final characters of "hidalgo" are cut by this method. So how can we avoid cutting words? Introducing `WordSplitter`.
#
# ---
#
# ### 2.2. Split by **Words**
#
# To use the [**`WordSplitter`**](https://andreshere00.github.io/Splitter_MR/api_reference/splitter/#wordsplitter), instantiate the class with your desired parameters (you can consult the [Developer guide](../../api_reference/splitter.md) for information on available parameters). Then, split the content using the previous output from the Reader. To visualize the chunks, you need to access the `chunks` attribute in the [`SplitterOutput`](https://andreshere00.github.io/Splitter_MR/api_reference/splitter/#splitter_mr.schema.models.SplitterOutput) object:

# %%
word_splitter = WordSplitter(chunk_size=20)
word_splitter_output = word_splitter.split(reader_output)

for idx, chunk in enumerate(word_splitter_output.chunks):
    print("=" * 40 + f" Chunk {idx + 1} " + "=" * 40 + "\n" + chunk + "\n")
# Out:
# ======================================== Chunk 1 ========================================
# Capítulo Primero Que trata de la condición y ejercicio del famoso hidalgo D. Quijote de la Mancha En un lugar
#
# ======================================== Chunk 2 ========================================
# de la Mancha, de cuyo nombre no quiero acordarme, no ha mucho tiempo que vivía un hidalgo de los de
#
# ======================================== Chunk 3 ========================================
# lanza en astillero, adarga antigua, rocín flaco y galgo corredor. Una olla de algo más vaca que carnero, salpicón las
#
# ======================================== Chunk 4 ========================================
# más noches, duelos y quebrantos los sábados, lentejas los viernes, algún palomino de añadidura los domingos, consumían las tres partes
#
# ======================================== Chunk 5 ========================================
# de su hacienda. El resto della concluían sayo de velarte, calzas de velludo para las fiestas con sus pantuflos de
#
# ======================================== Chunk 6 ========================================
# lo mismo, los días de entre semana se honraba con su vellori de lo más fino. Tenía en su casa
#
# ======================================== Chunk 7 ========================================
# una ama que pasaba de los cuarenta, y una sobrina que no llegaba a los veinte, y un mozo de
#
# ======================================== Chunk 8 ========================================
# campo y plaza, que así ensillaba el rocín como tomaba la podadera. Frisaba la edad de nuestro hidalgo con los
#
# ======================================== Chunk 9 ========================================
# cincuenta años, era de complexión recia, seco de carnes, enjuto de rostro; gran madrugador y amigo de la caza. Quieren
#
# ======================================== Chunk 10 ========================================
# decir que tenía el sobrenombre de Quijada o Quesada (que en esto hay alguna diferencia en los autores que deste
#
# ======================================== Chunk 11 ========================================
# caso escriben), aunque por conjeturas verosímiles se deja entender que se llama Quijana; pero esto importa poco a nuestro cuento;
#
# ======================================== Chunk 12 ========================================
# basta que en la narración dél no se salga un punto de la verdad. Es, pues, de saber, que este
#
# ======================================== Chunk 13 ========================================
# sobredicho hidalgo, los ratos que estaba ocioso (que eran los más del año) se daba a leer libros de caballerías
#
# ======================================== Chunk 14 ========================================
# con tanta afición y gusto, que olvidó casi de todo punto el ejercicio de la caza, y aun la administración
#
# ======================================== Chunk 15 ========================================
# de su hacienda; y llegó a tanto su curiosidad y desatino en esto, que vendió muchas hanegas de tierra de
#
# ======================================== Chunk 16 ========================================
# sembradura, para comprar libros de caballerías en que leer; y así llevó a su casa todos cuantos pudo haber dellos;
#
# ======================================== Chunk 17 ========================================
# y de todos ningunos le parecían tan bien como los que compuso el famoso Feliciano de Silva: porque la claridad
#
# ======================================== Chunk 18 ========================================
# de su prosa, y aquellas intrincadas razones suyas, le parecían de perlas; y más cuando llegaba a leer aquellos requiebros
#
# ======================================== Chunk 19 ========================================
# y cartas de desafío, donde en muchas partes hallaba escrito: la razón de la sinrazón que a mi razón se
#
# ======================================== Chunk 20 ========================================
# hace, de tal manera mi razón enflaquece, que con razón me quejo de la vuestra fermosura, y también cuando leía:
#
# ======================================== Chunk 21 ========================================
# los altos cielos que de vuestra divinidad divinamente con las estrellas se fortifican, y os hacen merecedora del merecimiento que
#
# ======================================== Chunk 22 ========================================
# merece la vuestra grandeza. Con estas y semejantes razones perdía el pobre caballero el juicio, y desvelábase por entenderlas, y
#
# ======================================== Chunk 23 ========================================
# desentrañarles el sentido, que no se lo sacara, ni las entendiera el mismo Aristóteles, si resucitara para sólo ello. No
#
# ======================================== Chunk 24 ========================================
# estaba muy bien con las heridas que don Belianis daba y recibía, porque se imaginaba que por grandes maestros que
#
# ======================================== Chunk 25 ========================================
# le hubiesen curado, no dejaría de tener el rostro y todo el cuerpo lleno de cicatrices y señales; pero con
#
# ======================================== Chunk 26 ========================================
# todo alababa en su autor aquel acabar su libro con la promesa de aquella inacabable aventura, y muchas veces le
#
# ======================================== Chunk 27 ========================================
# vino deseo de tomar la pluma, y darle fin al pie de la letra como allí se promete; y sin
#
# ======================================== Chunk 28 ========================================
# duda alguna lo hiciera, y aun saliera con ello, si otros mayores y continuos pensamientos no se lo estorbaran. Tuvo
#
# ======================================== Chunk 29 ========================================
# muchas veces competencia con el cura de su lugar (que era hombre docto graduado en Sigüenza), sobre cuál había sido
#
# ======================================== Chunk 30 ========================================
# mejor caballero, Palmerín de Inglaterra o Amadís de Gaula; mas maese Nicolás, barbero del mismo pueblo, decía que ninguno llegaba
#
# ======================================== Chunk 31 ========================================
# al caballero del Febo, y que si alguno se le podía comparar, era don Galaor, hermano de Amadís de Gaula,
#
# ======================================== Chunk 32 ========================================
# porque tenía muy acomodada condición para todo; que no era caballero melindroso, ni tan llorón como su hermano, y que
#
# ======================================== Chunk 33 ========================================
# en lo de la valentía no le iba en zaga. En resolución, él se enfrascó tanto en su lectura, que
#
# ======================================== Chunk 34 ========================================
# se le pasaban las noches leyendo de claro en claro, y los días de turbio en turbio, y así, del
#
# ======================================== Chunk 35 ========================================
# poco dormir y del mucho leer, se le secó el cerebro, de manera que vino a perder el juicio. Llenósele
#
# ======================================== Chunk 36 ========================================
# la fantasía de todo aquello que leía en los libros, así de encantamientos, como de pendencias, batallas, desafíos, heridas, requiebros,
#
# ======================================== Chunk 37 ========================================
# amores, tormentas y disparates imposibles, y asentósele de tal modo en la imaginación que era verdad toda aquella máquina de
#
# ======================================== Chunk 38 ========================================
# aquellas soñadas invenciones que leía, que para él no había otra historia más cierta en el mundo. Decía él, que
#
# ======================================== Chunk 39 ========================================
# el Cid Ruy Díaz había sido muy buen caballero; pero que no tenía que ver con el caballero de la
#
# ======================================== Chunk 40 ========================================
# ardiente espada, que de sólo un revés había partido por medio dos fieros y descomunales gigantes. Mejor estaba con Bernardo
#
# ======================================== Chunk 41 ========================================
# del Carpio, porque en Roncesvalle había muerto a Roldán el encantado, valiéndose de la industria de Hércules, cuando ahogó a
#
# ======================================== Chunk 42 ========================================
# Anteo, el hijo de la Tierra, entre los brazos. Decía mucho bien del gigante Morgante, porque con ser de aquella
#
# ======================================== Chunk 43 ========================================
# generación gigantesca, que todos son soberbios y descomedidos, él solo era afable y bien criado; pero sobre todos estaba bien
#
# ======================================== Chunk 44 ========================================
# con Reinaldos de Montalbán, y más cuando le veía salir de su castillo y robar cuantos topaba, y cuando en
#
# ======================================== Chunk 45 ========================================
# Allende robó aquel ídolo de Mahoma, que era todo de oro, según dice su historia. Diera él, por dar una
#
# ======================================== Chunk 46 ========================================
# mano de coces al traidor de Galalón, al ama que tenía y aun a su sobrina de añadidura. En efecto,
#
# ======================================== Chunk 47 ========================================
# rematado ya su juicio, vino a dar en el más extraño pensamiento que jamás dio loco en el mundo, y
#
# ======================================== Chunk 48 ========================================
# fue que le pareció convenible y necesario, así para el aumento de su honra, como para el servicio de su
#
# ======================================== Chunk 49 ========================================
# república, hacerse caballero andante, e irse por todo el mundo con sus armas y caballo a buscar las aventuras, y
#
# ======================================== Chunk 50 ========================================
# a ejercitarse en todo aquello que él había leído, que los caballeros andantes se ejercitaban, deshaciendo todo género de agravio,
#
# ======================================== Chunk 51 ========================================
# y poniéndose en ocasiones y peligros, donde acabándolos, cobrase eterno nombre y fama. Imaginábase el pobre ya coronado por el
#
# ======================================== Chunk 52 ========================================
# valor de su brazo por lo menos del imperio de Trapisonda: y así con estos tan agradables pensamientos, llevado del
#
# ======================================== Chunk 53 ========================================
# estraño gusto que en ellos sentía, se dió priesa a poner en efecto lo que deseaba. Y lo primero que
#
# ======================================== Chunk 54 ========================================
# hizo, fue limpiar unas armas, que habían sido de sus bisabuelos, que, tomadas de orín y llenas de moho, luengos
#
# ======================================== Chunk 55 ========================================
# siglos había que estaban puestas y olvidadas en un rincón. Limpiólas y aderezólas lo mejor que pudo; pero vió que
#
# ======================================== Chunk 56 ========================================
# tenían una gran falta, y era que no tenía celada de encaje, sino morrión simple; mas a esto suplió su
#
# ======================================== Chunk 57 ========================================
# industria, porque de cartones hizo un modo de media celada, que encajada con el morrión, hacía una apariencia de celada
#
# ======================================== Chunk 58 ========================================
# entera. Es verdad que para probar si era fuerte, y podía estar al riesgo de una cuchillada, sacó su espada,
#
# ======================================== Chunk 59 ========================================
# y le dió dos golpes, y con el primero y en un punto deshizo lo que había hecho en una
#
# ======================================== Chunk 60 ========================================
# semana: y no dejó de parecerle mal la facilidad con que la había hecho pedazos, y por asegurarse de este
#
# ======================================== Chunk 61 ========================================
# peligro, lo tornó a hacer de nuevo, poniéndole unas barras de hierro por de dentro de tal manera, que él
#
# ======================================== Chunk 62 ========================================
# quedó satisfecho de su fortaleza; y, sin querer hacer nueva experiencia de ella, la diputó y tuvo por celada finísima
#
# ======================================== Chunk 63 ========================================
# de encaje. Fue luego a ver a su rocín, y aunque tenía más cuartos que un real, y más tachas
#
# ======================================== Chunk 64 ========================================
# que el caballo de Gonela, que tantum pellis, et ossa fuit, le pareció que ni el Bucéfalo de Alejandro, ni
#
# ======================================== Chunk 65 ========================================
# Babieca el del Cid con él se igualaban. Cuatro días se le pasaron en imaginar qué nombre le podría: porque,
#
# ======================================== Chunk 66 ========================================
# según se decía él a sí mismo, no era razón que caballo de caballero tan famoso, y tan bueno él
#
# ======================================== Chunk 67 ========================================
# por sí, estuviese sin nombre conocido; y así procuraba acomodársele, de manera que declarase quien había sido, antes que fuese
#
# ======================================== Chunk 68 ========================================
# de caballero andante, y lo que era entones: pues estaba muy puesto en razón, que mudando su señor estado, mudase
#
# ======================================== Chunk 69 ========================================
# él también el nombre; y le cobrase famoso y de estruendo, como convenía a la nueva orden y al nuevo
#
# ======================================== Chunk 70 ========================================
# ejercicio que ya profesaba: y así después de muchos nombres que formó, borró y quitó, añadió, deshizo y tornó a
#
# ======================================== Chunk 71 ========================================
# hacer en su memoria e imaginación, al fin le vino a llamar ROCINANTE, nombre a su parecer alto, sonoro y
#
# ======================================== Chunk 72 ========================================
# significativo de lo que había sido cuando fue rocín, antes de lo que ahora era, que era antes y primero
#
# ======================================== Chunk 73 ========================================
# de todos los rocines del mundo. Puesto nombre y tan a su gusto a su caballo, quiso ponérsele a sí
#
# ======================================== Chunk 74 ========================================
# mismo, y en este pensamiento, duró otros ocho días, y al cabo se vino a llamar DON QUIJOTE, de donde
#
# ======================================== Chunk 75 ========================================
# como queda dicho, tomaron ocasión los autores de esta tan verdadera historia, que sin duda se debía llamar Quijada, y
#
# ======================================== Chunk 76 ========================================
# no Quesada como otros quisieron decir. Pero acordándose que el valeroso Amadís, no sólo se había contentado con llamarse Amadís
#
# ======================================== Chunk 77 ========================================
# a secas, sino que añadió el nombre de su reino y patria, por hacerla famosa, y se llamó Amadís de
#
# ======================================== Chunk 78 ========================================
# Gaula, así quiso, como buen caballero, añadir al suyo el nombre de la suya, y llamarse DON QUIJOTE DE LA
#
# ======================================== Chunk 79 ========================================
# MANCHA, con que a su parecer declaraba muy al vivo su linaje y patria, y la honraba con tomar el
#
# ======================================== Chunk 80 ========================================
# sobrenombre della. Limpias, pues, sus armas, hecho del morrión celada, puesto nombre a su rocín, y confirmándose a sí mismo,
#
# ======================================== Chunk 81 ========================================
# se dió a entender que no le faltaba otra cosa, sino buscar una dama de quien enamorarse, porque el caballero
#
# ======================================== Chunk 82 ========================================
# andante sin amores, era árbol sin hojas y sin fruto, y cuerpo sin alma. Decíase él: si yo por malos
#
# ======================================== Chunk 83 ========================================
# de mis pecados, por por mi buena suerte, me encuentro por ahí con algún gigante, como de ordinario les acontece
#
# ======================================== Chunk 84 ========================================
# a los caballeros andantes, y le derribo de un encuentro, o le parto por mitad del cuerpo, o finalmente, le
#
# ======================================== Chunk 85 ========================================
# venzo y le rindo, ¿no será bien tener a quién enviarle presentado, y que entre y se hinque de rodillas
#
# ======================================== Chunk 86 ========================================
# ante mi dulce señora, y diga con voz humilde y rendida: yo señora, soy el gigante Caraculiambro, señor de la
#
# ======================================== Chunk 87 ========================================
# ínsula Malindrania, a quien venció en singular batalla el jamás como se debe alabado caballero D. Quijote de la Mancha,
#
# ======================================== Chunk 88 ========================================
# el cual me mandó que me presentase ante la vuestra merced, para que la vuestra grandeza disponga de mí a
#
# ======================================== Chunk 89 ========================================
# su talante? ¡Oh, cómo se holgó nuestro buen caballero, cuando hubo hecho este discurso, y más cuando halló a quién
#
# ======================================== Chunk 90 ========================================
# dar nombre de su dama! Y fue, a lo que se cree, que en un lugar cerca del suyo había
#
# ======================================== Chunk 91 ========================================
# una moza labradora de muy buen parecer, de quien él un tiempo anduvo enamorado, aunque según se entiende, ella jamás
#
# ======================================== Chunk 92 ========================================
# lo supo ni se dió cata de ello. Llamábase Aldonza Lorenzo, y a esta le pareció ser bien darle título
#
# ======================================== Chunk 93 ========================================
# de señora de sus pensamientos; y buscándole nombre que no desdijese mucho del suyo, y que tirase y se encaminase
#
# ======================================== Chunk 94 ========================================
# al de princesa y gran señora, vino a llamarla DULCINEA DEL TOBOSO, porque era natural del Toboso, nombre a su
#
# ======================================== Chunk 95 ========================================
# parecer músico y peregrino y significativo, como todos los demás que a él y a sus cosas había puesto.

# %% [markdown]
# Note that even though words aren't cut, the context isn't adequate because sentences are left incomplete. To avoid this issue, we should split by sentences. Introducing the [**`SentenceSplitter`**](https://andreshere00.github.io/Splitter_MR/api_reference/splitter/#sentencesplitter):
#
# ---
#
# ### 2.3. Split by **Sentences**
#
# Analogously to the previous steps, we can define the [**`SentenceSplitter`**](https://andreshere00.github.io/Splitter_MR/api_reference/splitter/#sentencesplitter) object with the number of sentences to split on:

# %%
sentence_splitter = SentenceSplitter(chunk_size=5)
sentence_splitter_output = sentence_splitter.split(reader_output)

for idx, chunk in enumerate(sentence_splitter_output.chunks):
    print("=" * 40 + f" Chunk {idx + 1} " + "=" * 40 + "\n" + chunk + "\n")
# Out:
# ======================================== Chunk 1 ========================================
# Capítulo Primero
#
# Que trata de la condición y ejercicio del famoso hidalgo D. Quijote de la Mancha
#
# En un lugar de la Mancha, de cuyo nombre no quiero acordarme, no ha mucho tiempo que vivía un hidalgo de los de lanza en astillero, adarga antig
#
# ======================================== Chunk 6 ========================================
# Pero acordándose que el valeroso Amadís, no sólo se había contentado con llamarse Amadís a secas, sino que añadió el nombre de su reino y patria, por hacerla famosa, y se llamó Amadís de Gaula, así quiso, como buen caballero, añadir al suyo el nombre de la suya, y llamarse DON QUIJOTE DE LA MANCHA, con que a su parecer declaraba muy al vivo su linaje y patria, y la honraba con tomar el sobrenombre della. Limpias, pues, sus armas, hecho del morrión celada, puesto nombre a su rocín, y confirmándose a sí mismo, se dió a entender que no le faltaba otra cosa, sino buscar una dama de quien enamorarse, porque el caballero andante sin amores, era árbol sin hojas y sin fruto, y cuerpo sin alma. Decíase él: si yo por malos de mis pecados, por por mi buena suerte, me encuentro por ahí con algún gigante, como de ordinario les acontece a los caballeros andantes, y le derribo de un encuentro, o le parto por mitad del cuerpo, o finalmente, le venzo y le rindo, ¿no será bien tener a quién enviarle presentado, y que entre y se hinque de rodillas ante mi dulce señora, y diga con voz humilde y rendida: yo señora, soy el gigante Caraculiambro, señor de la ínsula Malindrania, a quien venció en singular batalla el jamás como se debe alabado caballero D. Quijote de la Mancha, el cual me mandó que me presentase ante la vuestra merced, para que la vuestra grandeza disponga de mí a su talante? ¡Oh, cómo se holgó nuestro buen caballero, cuando hubo hecho este discurso, y más cuando halló a quién dar nombre de su dama!
#
# ======================================== Chunk 7 ========================================
# Y fue, a lo que se cree, que en un lugar cerca del suyo había una moza labradora de muy buen parecer, de quien él un tiempo anduvo enamorado, aunque según se entiende, ella jamás lo supo ni se dió cata de ello. Llamábase Aldonza Lorenzo, y a esta le pareció ser bien darle título de señora de sus pensamientos; y buscándole nombre que no desdijese mucho del suyo, y que tirase y se encaminase al de princesa y gran señora, vino a llamarla DULCINEA DEL TOBOSO, porque era natural del Toboso, nombre a su parecer músico y peregrino y significativo, como todos los demás que a él y a sus cosas había puesto.

# %% [markdown]
# While the entire context is preserved when splitting by sentences, the varying chunk sizes suggest that chunking by paragraphs might be more beneficial. Introducing [**`ParagraphSplitter`**](https://andreshere00.github.io/Splitter_MR/api_reference/splitter/#paragraphsplitter).
#
# ---
#
# ### 2.4. Split by **Paragraphs**
#
# We can select `3` as the desired number of paragraphs per chunk. The resulting chunks are the following:

# %%
paragraph_splitter = ParagraphSplitter(chunk_size=3)
paragraph_splitter_output = paragraph_splitter.split(reader_output)

for idx, chunk in enumerate(paragraph_splitter_output.chunks):
    print("=" * 40 + f" Chunk {idx + 1} " + "=" * 40 + "\n" + chunk + "\n")
# Out:
# ======================================== Chunk 1 ========================================
# Capítulo Primero
# Que trata de la condición y ejercicio del famoso hidalgo D. Quijote de la Mancha
# En un lugar de la Mancha, de cuyo nombre no quiero acordarme, no ha mucho tiempo que vivía un hidalgo de los de lanza en astillero, adarga antig
otros ocho días, y al cabo se vino a llamar DON QUIJOTE, de donde como queda dicho, tomaron ocasión los autores de esta tan verdadera historia, que sin duda se debía llamar Quijada, y no Quesada como otros quisieron decir. Pero acordándose que el valeroso Amadís, no sólo se había contentado con llamarse Amadís a secas, sino que añadió el nombre de su reino y patria, por hacerla famosa, y se llamó Amadís de Gaula, así quiso, como buen caballero, añadir al suyo el nombre de la suya, y llamarse DON QUIJOTE DE LA MANCHA, con que a su parecer declaraba muy al vivo su linaje y patria, y la honraba con tomar el sobrenombre della.
#
# ======================================== Chunk 4 ========================================
# Limpias, pues, sus armas, hecho del morrión celada, puesto nombre a su rocín, y confirmándose a sí mismo, se dió a entender que no le faltaba otra cosa, sino buscar una dama de quien enamorarse, porque el caballero andante sin amores, era árbol sin hojas y sin fruto, y cuerpo sin alma. Decíase él: si yo por malos de mis pecados, por por mi buena suerte, me encuentro por ahí con algún gigante, como de ordinario les acontece a los caballeros andantes, y le derribo de un encuentro, o le parto por mitad del cuerpo, o finalmente, le venzo y le rindo, ¿no será bien tener a quién enviarle presentado, y que entre y se hinque de rodillas ante mi dulce señora, y diga con voz humilde y rendida: yo señora, soy el gigante Caraculiambro, señor de la ínsula Malindrania, a quien venció en singular batalla el jamás como se debe alabado caballero D. Quijote de la Mancha, el cual me mandó que me presentase ante la vuestra merced, para que la vuestra grandeza disponga de mí a su talante? ¡Oh, cómo se holgó nuestro buen caballero, cuando hubo hecho este discurso, y más cuando halló a quién dar nombre de su dama! Y fue, a lo que se cree, que en un lugar cerca del suyo había una moza labradora de muy buen parecer, de quien él un tiempo anduvo enamorado, aunque según se entiende, ella jamás lo supo ni se dió cata de ello. Llamábase Aldonza Lorenzo, y a esta le pareció ser bien darle título de señora de sus pensamientos; y buscándole nombre que no desdijese mucho del suyo, y que tirase y se encaminase al de princesa y gran señora, vino a llamarla DULCINEA DEL TOBOSO, porque era natural del Toboso, nombre a su parecer músico y peregrino y significativo, como todos los demás que a él y a sus cosas había puesto.

# %% [markdown]
# ---
#
# ### 2.5. Add **Overlapping Chunks**
#
# Another strategy you can employ is to preserve some text between chunks. For this use case, you can optionally add *overlap* between chunks. Overlap can be defined as either a fraction (e.g., `chunk_overlap = 0.2` for 20% overlap) or an integer number (e.g., `chunk_overlap = 20`):

# %%
char_splitter_with_overlap = CharacterSplitter(chunk_size=100, chunk_overlap=0.2)
char_splitter_output = char_splitter_with_overlap.split(reader_output)

for idx, chunk in enumerate(char_splitter_output.chunks):
    print("=" * 40 + f" Chunk {idx + 1} " + "=" * 40 + "\n" + chunk + "\n")
# Out:
# ======================================== Chunk 1 ========================================
# Capítulo Primero
#
# Que trata de la condición y ejercicio del famoso hidalgo D. Quijote de la Mancha
#
#
#
# ======================================== Chunk 2 ========================================
# ijote de la Mancha
#
# En un lugar de la Mancha, de cuyo nombre no quiero acordarme, no ha mucho tiempo
#
# ======================================== Chunk 3 ========================================
# , no ha mucho tiempo que vivía un hidalgo de los de lanza en astillero, adarga antigua, rocín flaco
#
# ======================================== Chunk 4 ========================================
# ntigua, rocín flaco y galgo corredor. Una olla de algo más vaca que carnero, salpicón las más noches
#
# ======================================== Chunk 5 ========================================
# picón las más noches, duelos y quebrantos los sábados, lentejas los viernes, algún palomino de añadi
#
# ======================================== Chunk 6 ========================================
# ún palomino de añadidura los domingos, consumían las tres partes de su hacienda. El resto della conc
#
# ======================================== Chunk 7 ========================================
#  El resto della concluían sayo de velarte, calzas de velludo para las fiestas con sus pantuflos de l
#
# ======================================== Chunk 8 ========================================
# n sus pantuflos de lo mismo, los días de entre semana se honraba con su vellori de lo más fino. Tení
#
# ======================================== Chunk 9 ========================================
# de lo más fino. Tenía en su casa una ama que pasaba de los cuarenta, y una sobrina que no llegaba a
#
# ======================================== Chunk 10 ========================================
# na que no llegaba a los veinte, y un mozo de campo y plaza, que así ensillaba el rocín como tomaba l
#
# ======================================== Chunk 11 ========================================
#  rocín como tomaba la podadera. Frisaba la edad de nuestro hidalgo con los cincuenta años, era de co
#
# ======================================== Chunk 12 ========================================
# enta años, era de complexión recia, seco de carnes, enjuto de rostro; gran madrugador y amigo de la
#
# ======================================== Chunk 13 ========================================
# gador y amigo de la caza. Quieren decir que tenía el sobrenombre de Quijada o Quesada (que en esto h
#
# ======================================== Chunk 14 ========================================
# esada (que en esto hay alguna diferencia en los autores que deste caso escriben), aunque por conjetu
#
# ======================================== Chunk 15 ========================================
# , aunque por conjeturas verosímiles se deja entender que se llama Quijana; pero esto importa poco a
#
# ======================================== Chunk 16 ========================================
# esto importa poco a nuestro cuento; basta que en la narración dél no se salga un punto de la verdad.
#
# ======================================== Chunk 17 ========================================
#  punto de la verdad.
#
# Es, pues, de saber, que este sobredicho hidalgo, los ratos que estaba ocioso (
#
# ======================================== Chunk 18 ========================================
#  que estaba ocioso (que eran los más del año) se daba a leer libros de caballerías con tanta afición
#
# ======================================== Chunk 19 ========================================
# as con tanta afición y gusto, que olvidó casi de todo punto el ejercicio de la caza, y aun la admini
#
# ======================================== Chunk 20 ========================================
# aza, y aun la administración de su hacienda; y llegó a tanto su curiosidad y desatino en esto, que v
#
# ======================================== Chunk 21 ========================================
# atino en esto, que vendió muchas hanegas de tierra de sembradura, para comprar libros de caballerías
#
# ======================================== Chunk 22 ========================================
# ibros de caballerías en que leer; y así llevó a su casa todos cuantos pudo haber dellos; y de todos
#
# ======================================== Chunk 23 ========================================
#  dellos; y de todos ningunos le parecían tan bien como los que compuso el famoso Feliciano de Silva:
#
# ======================================== Chunk 24 ========================================
#  Feliciano de Silva: porque la claridad de su prosa, y aquellas intrincadas razones suyas, le parecí
#
# ======================================== Chunk 25 ========================================
# nes suyas, le parecían de perlas; y más cuando llegaba a leer aquellos requiebros y cartas de desafí
#
# ======================================== Chunk 26 ========================================
# s y cartas de desafío, donde en muchas partes hallaba escrito: la razón de la sinrazón que a mi razó
#
# ======================================== Chunk 27 ========================================
# nrazón que a mi razón se hace, de tal manera mi razón enflaquece, que con razón me quejo de la vuest
#
# ======================================== Chunk 28 ========================================
# me quejo de la vuestra fermosura, y también cuando leía: los altos cielos que de vuestra divinidad d
#
# ======================================== Chunk 29 ========================================
#  vuestra divinidad divinamente con las estrellas se fortifican, y os hacen merecedora del merecimien
#
# ======================================== Chunk 30 ========================================
# edora del merecimiento que merece la vuestra grandeza. Con estas y semejantes razones perdía el pobr
#
# ======================================== Chunk 31 ========================================
# zones perdía el pobre caballero el juicio, y desvelábase por entenderlas, y desentrañarles el sentid
#
# ======================================== Chunk 32 ========================================
# ntrañarles el sentido, que no se lo sacara, ni las entendiera el mismo Aristóteles, si resucitara pa
#
# ======================================== Chunk 33 ========================================
# es, si resucitara para sólo ello. No estaba muy bien con las heridas que don Belianis daba y recibía
#
# ======================================== Chunk 34 ========================================
# ianis daba y recibía, porque se imaginaba que por grandes maestros que le hubiesen curado, no dejarí
#
# ======================================== Chunk 35 ========================================
# en curado, no dejaría de tener el rostro y todo el cuerpo lleno de cicatrices y señales; pero con to
#
# ======================================== Chunk 36 ========================================
# señales; pero con todo alababa en su autor aquel acabar su libro con la promesa de aquella inacababl
#
# ======================================== Chunk 37 ========================================
# de aquella inacabable aventura, y muchas veces le vino deseo de tomar la pluma, y darle fin al pie d
#
# ======================================== Chunk 38 ========================================
# y darle fin al pie de la letra como allí se promete; y sin duda alguna lo hiciera, y aun saliera con
#
# ======================================== Chunk 39 ========================================
# a, y aun saliera con ello, si otros mayores y continuos pensamientos no se lo estorbaran.
#
# Tuvo much
#
# ======================================== Chunk 40 ========================================
# torbaran.
#
# Tuvo muchas veces competencia con el cura de su lugar (que era hombre docto graduado en S
#
# ======================================== Chunk 41 ========================================
#  docto graduado en Sigüenza), sobre cuál había sido mejor caballero, Palmerín de Inglaterra o Amadís
#
# ======================================== Chunk 42 ========================================
#  Inglaterra o Amadís de Gaula; mas maese Nicolás, barbero del mismo pueblo, decía que ninguno llegab
#
# ======================================== Chunk 43 ========================================
# a que ninguno llegaba al caballero del Febo, y que si alguno se le podía comparar, era don Galaor, h
#
# ======================================== Chunk 44 ========================================
# r, era don Galaor, hermano de Amadís de Gaula, porque tenía muy acomodada condición para todo; que n
#
# ======================================== Chunk 45 ========================================
# ión para todo; que no era caballero melindroso, ni tan llorón como su hermano, y que en lo de la val
#
# ======================================== Chunk 46 ========================================
#  que en lo de la valentía no le iba en zaga.
#
# En resolución, él se enfrascó tanto en su lectura, que
#
# ======================================== Chunk 47 ========================================
# o en su lectura, que se le pasaban las noches leyendo de claro en claro, y los días de turbio en tur
#
# ======================================== Chunk 48 ========================================
# ías de turbio en turbio, y así, del poco dormir y del mucho leer, se le secó el cerebro, de manera q
#
# ======================================== Chunk 49 ========================================
# cerebro, de manera que vino a perder el juicio. Llenósele la fantasía de todo aquello que leía en lo
#
# ======================================== Chunk 50 ========================================
# uello que leía en los libros, así de encantamientos, como de pendencias, batallas, desafíos, heridas
#
# ======================================== Chunk 51 ========================================
# s, desafíos, heridas, requiebros, amores, tormentas y disparates imposibles, y asentósele de tal mod
#
# ======================================== Chunk 52 ========================================
# sentósele de tal modo en la imaginación que era verdad toda aquella máquina de aquellas soñadas inve
#
# ======================================== Chunk 53 ========================================
# quellas soñadas invenciones que leía, que para él no había otra historia más cierta en el mundo.
#
# De
#
# ======================================== Chunk 54 ========================================
# rta en el mundo.
#
# Decía él, que el Cid Ruy Díaz había sido muy buen caballero; pero que no tenía que
#
# ======================================== Chunk 55 ========================================
# ero que no tenía que ver con el caballero de la ardiente espada, que de sólo un revés había partido
#
# ======================================== Chunk 56 ========================================
# revés había partido por medio dos fieros y descomunales gigantes. Mejor estaba con Bernardo del Carp
#
# ======================================== Chunk 57 ========================================
# on Bernardo del Carpio, porque en Roncesvalle había muerto a Roldán el encantado, valiéndose de la i
#
# ======================================== Chunk 58 ========================================
# , valiéndose de la industria de Hércules, cuando ahogó a Anteo, el hijo de la Tierra, entre los braz
#
# ======================================== Chunk 59 ========================================
# erra, entre los brazos. Decía mucho bien del gigante Morgante, porque con ser de aquella generación
#
# ======================================== Chunk 60 ========================================
#  aquella generación gigantesca, que todos son soberbios y descomedidos, él solo era afable y bien cr
#
# ======================================== Chunk 61 ========================================
# era afable y bien criado; pero sobre todos estaba bien con Reinaldos de Montalbán, y más cuando le v
#
# ======================================== Chunk 62 ========================================
# n, y más cuando le veía salir de su castillo y robar cuantos topaba, y cuando en Allende robó aquel
#
# ======================================== Chunk 63 ========================================
#  Allende robó aquel ídolo de Mahoma, que era todo de oro, según dice su historia. Diera él, por dar
#
# ======================================== Chunk 64 ========================================
# . Diera él, por dar una mano de coces al traidor de Galalón, al ama que tenía y aun a su sobrina de
#
# ======================================== Chunk 65 ========================================
# aun a su sobrina de añadidura.
#
# En efecto, rematado ya su juicio, vino a dar en el más extraño pensa
#
# ======================================== Chunk 66 ========================================
# el más extraño pensamiento que jamás dio loco en el mundo, y fue que le pareció convenible y necesar
#
# ======================================== Chunk 67 ========================================
# convenible y necesario, así para el aumento de su honra, como para el servicio de su república, hace
#
# ======================================== Chunk 68 ========================================
# e su república, hacerse caballero andante, e irse por todo el mundo con sus armas y caballo a buscar
#
# ======================================== Chunk 69 ========================================
# s y caballo a buscar las aventuras, y a ejercitarse en todo aquello que él había leído, que los caba
#
# ======================================== Chunk 70 ========================================
#  leído, que los caballeros andantes se ejercitaban, deshaciendo todo género de agravio, y poniéndose
#
# ======================================== Chunk 71 ========================================
# gravio, y poniéndose en ocasiones y peligros, donde acabándolos, cobrase eterno nombre y fama.
#
# Imag
#
# ======================================== Chunk 72 ========================================
# nombre y fama.
#
# Imaginábase el pobre ya coronado por el valor de su brazo por lo menos del imperio d
#
# ======================================== Chunk 73 ========================================
#  menos del imperio de Trapisonda: y así con estos tan agradables pensamientos, llevado del estraño g
#
# ======================================== Chunk 74 ========================================
# levado del estraño gusto que en ellos sentía, se dió priesa a poner en efecto lo que deseaba. Y lo p
#
# ======================================== Chunk 75 ========================================
#  que deseaba. Y lo primero que hizo, fue limpiar unas armas, que habían sido de sus bisabuelos, que,
#
# ======================================== Chunk 76 ========================================
# sus bisabuelos, que, tomadas de orín y llenas de moho, luengos siglos había que estaban puestas y ol
#
# ======================================== Chunk 77 ========================================
# estaban puestas y olvidadas en un rincón. Limpiólas y aderezólas lo mejor que pudo; pero vió que ten
#
# ======================================== Chunk 78 ========================================
# do; pero vió que tenían una gran falta, y era que no tenía celada de encaje, sino morrión simple; ma
#
# ======================================== Chunk 79 ========================================
# o morrión simple; mas a esto suplió su industria, porque de cartones hizo un modo de media celada, q
#
# ======================================== Chunk 80 ========================================
# o de media celada, que encajada con el morrión, hacía una apariencia de celada entera. Es verdad que
#
# ======================================== Chunk 81 ========================================
# ntera. Es verdad que para probar si era fuerte, y podía estar al riesgo de una cuchillada, sacó su e
#
# ======================================== Chunk 82 ========================================
# uchillada, sacó su espada, y le dió dos golpes, y con el primero y en un punto deshizo lo que había
#
# ======================================== Chunk 83 ========================================
# eshizo lo que había hecho en una semana: y no dejó de parecerle mal la facilidad con que la había he
#
# ======================================== Chunk 84 ========================================
#  con que la había hecho pedazos, y por asegurarse de este peligro, lo tornó a hacer de nuevo, ponién
#
# ======================================== Chunk 85 ========================================
# cer de nuevo, poniéndole unas barras de hierro por de dentro de tal manera, que él quedó satisfecho
#
# ======================================== Chunk 86 ========================================
# él quedó satisfecho de su fortaleza; y, sin querer hacer nueva experiencia de ella, la diputó y tuvo
#
# ======================================== Chunk 87 ========================================
# la, la diputó y tuvo por celada finísima de encaje. Fue luego a ver a su rocín, y aunque tenía más c
#
# ======================================== Chunk 88 ========================================
# y aunque tenía más cuartos que un real, y más tachas que el caballo de Gonela, que tantum pellis, et
#
# ======================================== Chunk 89 ========================================
# ue tantum pellis, et ossa fuit, le pareció que ni el Bucéfalo de Alejandro, ni Babieca el del Cid co
#
# ======================================== Chunk 90 ========================================
# abieca el del Cid con él se igualaban. Cuatro días se le pasaron en imaginar qué nombre le podría: p
#
# ======================================== Chunk 91 ========================================
#  nombre le podría: porque, según se decía él a sí mismo, no era razón que caballo de caballero tan f
#
# ======================================== Chunk 92 ========================================
# o de caballero tan famoso, y tan bueno él por sí, estuviese sin nombre conocido; y así procuraba aco
#
# ======================================== Chunk 93 ========================================
#  y así procuraba acomodársele, de manera que declarase quien había sido, antes que fuese de caballer
#
# ======================================== Chunk 94 ========================================
# ue fuese de caballero andante, y lo que era entones: pues estaba muy puesto en razón, que mudando su
#
# ======================================== Chunk 95 ========================================
# azón, que mudando su señor estado, mudase él también el nombre; y le cobrase famoso y de estruendo,
#
# ======================================== Chunk 96 ========================================
# oso y de estruendo, como convenía a la nueva orden y al nuevo ejercicio que ya profesaba: y así desp
#
# ======================================== Chunk 97 ========================================
# rofesaba: y así después de muchos nombres que formó, borró y quitó, añadió, deshizo y tornó a hacer
#
# ======================================== Chunk 98 ========================================
# izo y tornó a hacer en su memoria e imaginación, al fin le vino a llamar ROCINANTE, nombre a su pare
#
# ======================================== Chunk 99 ========================================
# TE, nombre a su parecer alto, sonoro y significativo de lo que había sido cuando fue rocín, antes de
#
# ======================================== Chunk 100 ========================================
#  fue rocín, antes de lo que ahora era, que era antes y primero de todos los rocines del mundo. Puest
#
# ======================================== Chunk 101 ========================================
# nes del mundo. Puesto nombre y tan a su gusto a su caballo, quiso ponérsele a sí mismo, y en este pe
#
# ======================================== Chunk 102 ========================================
#  mismo, y en este pensamiento, duró otros ocho días, y al cabo se vino a llamar DON QUIJOTE, de dond
#
# ======================================== Chunk 103 ========================================
# DON QUIJOTE, de donde como queda dicho, tomaron ocasión los autores de esta tan verdadera historia,
#
# ======================================== Chunk 104 ========================================
# verdadera historia, que sin duda se debía llamar Quijada, y no Quesada como otros quisieron decir. P
#
# ======================================== Chunk 105 ========================================
# s quisieron decir. Pero acordándose que el valeroso Amadís, no sólo se había contentado con llamarse
#
# ======================================== Chunk 106 ========================================
# tentado con llamarse Amadís a secas, sino que añadió el nombre de su reino y patria, por hacerla fam
#
# ======================================== Chunk 107 ========================================
# ria, por hacerla famosa, y se llamó Amadís de Gaula, así quiso, como buen caballero, añadir al suyo
#
# ======================================== Chunk 108 ========================================
# ero, añadir al suyo el nombre de la suya, y llamarse DON QUIJOTE DE LA MANCHA, con que a su parecer
#
# ======================================== Chunk 109 ========================================
# on que a su parecer declaraba muy al vivo su linaje y patria, y la honraba con tomar el sobrenombre
#
# ======================================== Chunk 110 ========================================
# omar el sobrenombre della.
#
# Limpias, pues, sus armas, hecho del morrión celada, puesto nombre a su r
#
# ======================================== Chunk 111 ========================================
# puesto nombre a su rocín, y confirmándose a sí mismo, se dió a entender que no le faltaba otra cosa,
#
# ======================================== Chunk 112 ========================================
# e faltaba otra cosa, sino buscar una dama de quien enamorarse, porque el caballero andante sin amore
#
# ======================================== Chunk 113 ========================================
# ro andante sin amores, era árbol sin hojas y sin fruto, y cuerpo sin alma. Decíase él: si yo por mal
#
# ======================================== Chunk 114 ========================================
# se él: si yo por malos de mis pecados, por por mi buena suerte, me encuentro por ahí con algún gigan
#
# ======================================== Chunk 115 ========================================
#  ahí con algún gigante, como de ordinario les acontece a los caballeros andantes, y le derribo de un
#
# ======================================== Chunk 116 ========================================
# , y le derribo de un encuentro, o le parto por mitad del cuerpo, o finalmente, le venzo y le rindo,
#
# ======================================== Chunk 117 ========================================
# e venzo y le rindo, ¿no será bien tener a quién enviarle presentado, y que entre y se hinque de rodi
#
# ======================================== Chunk 118 ========================================
#  y se hinque de rodillas ante mi dulce señora, y diga con voz humilde y rendida: yo señora, soy el g
#
# ======================================== Chunk 119 ========================================
#  yo señora, soy el gigante Caraculiambro, señor de la ínsula Malindrania, a quien venció en singular
#
# ======================================== Chunk 120 ========================================
# n venció en singular batalla el jamás como se debe alabado caballero D. Quijote de la Mancha, el cua
#
# ======================================== Chunk 121 ========================================
# de la Mancha, el cual me mandó que me presentase ante la vuestra merced, para que la vuestra grandez
#
# ======================================== Chunk 122 ========================================
# e la vuestra grandeza disponga de mí a su talante? ¡Oh, cómo se holgó nuestro buen caballero, cuando
#
# ======================================== Chunk 123 ========================================
# en caballero, cuando hubo hecho este discurso, y más cuando halló a quién dar nombre de su dama! Y f
#
# ======================================== Chunk 124 ========================================
# mbre de su dama! Y fue, a lo que se cree, que en un lugar cerca del suyo había una moza labradora de
#
# ======================================== Chunk 125 ========================================
# na moza labradora de muy buen parecer, de quien él un tiempo anduvo enamorado, aunque según se entie
#
# ======================================== Chunk 126 ========================================
# unque según se entiende, ella jamás lo supo ni se dió cata de ello. Llamábase Aldonza Lorenzo, y a e
#
# ======================================== Chunk 127 ========================================
# donza Lorenzo, y a esta le pareció ser bien darle título de señora de sus pensamientos; y buscándole
#
# ======================================== Chunk 128 ========================================
# ientos; y buscándole nombre que no desdijese mucho del suyo, y que tirase y se encaminase al de prin
#
# ======================================== Chunk 129 ========================================
# ncaminase al de princesa y gran señora, vino a llamarla DULCINEA DEL TOBOSO, porque era natural del
#
# ======================================== Chunk 130 ========================================
# que era natural del Toboso, nombre a su parecer músico y peregrino y significativo, como todos los d
#
# ======================================== Chunk 131 ========================================
# vo, como todos los demás que a él y a sus cosas había puesto.

# %% [markdown]
# ---
#
# **And that’s it!** With these splitters, you can flexibly chunk your text data however you need. Remember that you can visit the complete [**Developer Reference**](../../api_reference/splitter.md) to have more information about specific examples, methods, attributes and more of these Splitter classes.
#
# ## Complete Example Script
#
# Finally, we provide a full example script for reproducibility purposes:
#
# ```python
# from splitter_mr.reader import VanillaReader
# from splitter_mr.splitter import (CharacterSplitter, ParagraphSplitter,
#                                   SentenceSplitter, WordSplitter)
#
# reader = VanillaReader()
#
# data = "https://raw.githubusercontent.com/andreshere00/Splitter_MR/refs/heads/main/data/quijote_example.txt"
# reader_output = reader.read(data)
#
# print(reader_output.model_dump_json(indent=4)) # Visualize the ReaderOutput object
# print(reader_output.text) # Get the text from the document
#
# # 1. Split by Characters
#
# char_splitter = CharacterSplitter(chunk_size=100)
# char_splitter_output = char_splitter.split(reader_output)
# print(char_splitter_output) # Visualize Character Splitter output
#
# for idx, chunk in enumerate(char_splitter_output.chunks): # Visualize chunks
#     print("="*40 + " Chunk " + str(idx + 1) + " " + "="*40 + "\n" + chunk + "\n")
#
# # 2. Split by Words
#
# word_splitter = WordSplitter(chunk_size=20)
# word_splitter_output = word_splitter.split(reader_output)
#
# for idx, chunk in enumerate(word_splitter_output.chunks):
#     print("="*40 + " Chunk " + str(idx + 1) + " " + "="*40 + "\n" + chunk + "\n")
#
# # 3. Split by Sentences
#
# sentence_splitter = SentenceSplitter(chunk_size=5)
# sentence_splitter_output = sentence_splitter.split(reader_output)
#
# for idx, chunk in enumerate(sentence_splitter_output.chunks):
#     print("="*40 + " Chunk " + str(idx + 1) + " " + "="*40 + "\n" + chunk + "\n")
#
# # 4. Split by Paragraphs
#
# paragraph_splitter = ParagraphSplitter(chunk_size=3)
# paragraph_splitter_output = paragraph_splitter.split(reader_output)
#
# for idx, chunk in enumerate(paragraph_splitter_output.chunks):
#     print("="*40 + " Chunk " + str(idx + 1) + " " + "="*40 + "\n" + chunk + "\n")
#
# # 5. Add overlapping words between chunks
#
# char_splitter_with_overlap = CharacterSplitter(chunk_size=100, chunk_overlap=0.2)
# char_splitter_output = char_splitter_with_overlap.split(reader_output)
#
# for idx, chunk in enumerate(char_splitter_output.chunks):
#     print("="*40 + " Chunk " + str(idx + 1) + " " + "="*40 + "\n" + chunk + "\n")
# ```
