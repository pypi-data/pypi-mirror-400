# %%
from abdwp.plot import draw_field
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(7, 7))
draw_field(ax)
# ax.set_xlim(-100, 100)
# ax.set_ylim(-20, 180)

# %%
fig, ax = plt.subplots(figsize=(7, 7))
draw_field(ax, add_detail=True)
