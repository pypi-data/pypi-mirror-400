# %%
import antigranular_enterprise as ag

ag.load_config("https://api-agent2.staging.antigranular.com/config/client", profile='default')
session = ag.login("1nWY1QPlp7huXA9T0rOAldZzb55WKv4qvrfG3tyysQE")
# Out:
# Your request is pending approval. Please visit the following URL to approve the request: https://agent2.staging.antigranular.com
# Request approved.
# Connected to Antigranular server session id: dd39f973-9ef3-4e6f-a8fb-2c7fdf8f6e6b
# Cell magic '%%ag' registered successfully, use `%%ag` in a notebook cell to execute your python code on Antigranular private python server

# %%
import antigranular_enterprise as ag

# %%
import antigranular_enterprise as ag

ag.load_config("https://api-agent2.staging.antigranular.com/config/client", profile='default')
session = ag.login("1nWY1QPlp7huXA9T0rOAldZzb55WKv4qvrfG3tyysQE")
# Out:
#  You are not logged in to SQL server, please login using login_sql method

# %%
ag.login_sql(api_key = "1nWY1QPlp7huXA9T0rOAldZzb55WKv4qvrfG3tyysQE")
# Out:
# Please approve the token request from the console
# Making POST request to https://api-agent2.staging.antigranular.com/api/jupyter/login/request with params: {} and data: {'apikey': '1nWY1QPlp7huXA9T0rOAldZzb55WKv4qvrfG3tyysQE', 'machineUuid': 'fcc615bb-87a0-4a6e-8cfc-eac645f44961', 'os': 'Windows-10-10.0.26100-SP0', 'nicId': '00-FF-E7-2C-55-39'} and headers: {'Content-Type': 'application/json', 'Accept': 'application/json'} and stream: True
# Response is not JSON, returning text: data: {"approvalUrl":"https:\/\/agent2.staging.antigranular.com","approvalStatus":"pending"}
#
# ...

# %%
ag.login_sql(api_key = "1nWY1QPlp7huXA9T0rOAldZzb55WKv4qvrfG3tyysQE")
# Out:
# Please approve the token request from the console
# ...

# %%
# %%sql my_var
# with dp(eps=0.01, delta=0.0005)
# SELECT COUNT(race) FROM "school_pg"."scores" where race = 'Hispanic';
# Out:
# Making POST request to https://sql-server2.staging.antigranular.com/api/execute_sql with params: {} and data: {'sql': 'with dp(eps=0.01, delta=0.0005) \nSELECT COUNT(race) FROM "school_pg"."scores" where race = \'Hispanic\';\n', 'connectionId': 'dfc34452-eeab-4dc7-8091-935218507411', 'teamName': '', 'clientName': 'AGENT_Client'} and headers: {'Content-Type': 'application/json', 'Accept': 'application/json', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJnQUdRZzRjSldlbGZkSVBBcU1rN280aEw4dlFXUHlvQ0ZtNG9XX2lNY0l3In0.....Gxt6dVB_xZ0ZLCJL2y_Da1Gdf3gL7WppKTP4DMcPP5p-1DwD_sl0Wf2dFGPTLiPA8N_rmBwihZXCBZ6V0DWq2GQP4yKrWRJ53FooeGB6_TRWYOiRJWObFhZNp9_gwktiUaMcjFPjONz24ISwu1YXcTKPpjYhwtT9trmzOU0fcL_1i07i1If_wMBN9F_QpXsCcTj0MATlkM2xAiOePpeL3balUPD1rpixsvHGMLxoVT1TuD6KTmDqbeHRkQTBcXTLL4T3olCXRh783p3ut8TxRHZaSnIShdqdIxVTEl2rMlKh4LEfjtoR9_PCtQ3ZRm6Gv5cZUFtedPvNpqLBU-kz7w', 'refresh-token': 'eyJhbGciOiJIUzUxMiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICIxMTM0OGI1My00NDZkLTRkYjMtODc4MC0
# ...

# %%
# %%sql
# with dp(eps=0.01, delta=0.0005)
# SELECT COUNT(*) FROM "school_pg"."scores" where race = 'Hispanic';
# Out:
# Making POST request to https://sql-server2.staging.antigranular.com/api/execute_sql with params: {} and data: {'sql': 'with dp(eps=0.01, delta=0.0005) \nSELECT COUNT(*) FROM "school_pg"."scores" where race = \'Hispanic\';\n', 'connectionId': 'dfc34452-eeab-4dc7-8091-935218507411', 'teamName': '', 'clientName': 'AGENT_Client'} and headers: {'Content-Type': 'application/json', 'Accept': 'application/json', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJnQUdRZzRjSldlbGZkSVBBcU1rN280aEw4dlFXUHlvQ0ZtNG9XX2lNY0l3In0.....Gxt6dVB_xZ0ZLCJL2y_Da1Gdf3gL7WppKTP4DMcPP5p-1DwD_sl0Wf2dFGPTLiPA8N_rmBwihZXCBZ6V0DWq2GQP4yKrWRJ53FooeGB6_TRWYOiRJWObFhZNp9_gwktiUaMcjFPjONz24ISwu1YXcTKPpjYhwtT9trmzOU0fcL_1i07i1If_wMBN9F_QpXsCcTj0MATlkM2xAiOePpeL3balUPD1rpixsvHGMLxoVT1TuD6KTmDqbeHRkQTBcXTLL4T3olCXRh783p3ut8TxRHZaSnIShdqdIxVTEl2rMlKh4LEfjtoR9_PCtQ3ZRm6Gv5cZUFtedPvNpqLBU-kz7w', 'refresh-token': 'eyJhbGciOiJIUzUxMiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICIxMTM0OGI1My00NDZkLTRkYjMtODc4MC0wMz
# ...

# %%
# %%sql my_var
# with dp(eps=0.01, delta=0.0005) select gender, count(*) as total from school.students group by gender
# Out:
# Making POST request to https://sql-server2.staging.antigranular.com/api/execute_sql with params: {} and data: {'sql': 'with dp(eps=0.01, delta=0.0005) select gender, count(*) as total from school.students group by gender\n', 'connectionId': 'dfc34452-eeab-4dc7-8091-935218507411', 'teamName': '', 'clientName': 'AGENT_Client'} and headers: {'Content-Type': 'application/json', 'Accept': 'application/json', 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJnQUdRZzRjSldlbGZkSVBBcU1rN280aEw4dlFXUHlvQ0ZtNG9XX2lNY0l3In0.....Gxt6dVB_xZ0ZLCJL2y_Da1Gdf3gL7WppKTP4DMcPP5p-1DwD_sl0Wf2dFGPTLiPA8N_rmBwihZXCBZ6V0DWq2GQP4yKrWRJ53FooeGB6_TRWYOiRJWObFhZNp9_gwktiUaMcjFPjONz24ISwu1YXcTKPpjYhwtT9trmzOU0fcL_1i07i1If_wMBN9F_QpXsCcTj0MATlkM2xAiOePpeL3balUPD1rpixsvHGMLxoVT1TuD6KTmDqbeHRkQTBcXTLL4T3olCXRh783p3ut8TxRHZaSnIShdqdIxVTEl2rMlKh4LEfjtoR9_PCtQ3ZRm6Gv5cZUFtedPvNpqLBU-kz7w', 'refresh-token': 'eyJhbGciOiJIUzUxMiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICIxMTM0OGI1My00NDZkLTRkYjMtODc4MC0wMzh
# ...

# %%
# %%ag
# import pandas
# Out:
#  You are not logged in to Antigranular server, please login using login method

# %%
session = ag.login("b75Wke67jmHrhCw4ZiDZt-roK_1YP1Z8Zbt608LLiKI")

# %%
session = ag.login("b75Wke67jmHrhCw4ZiDZt-roK_1YP1Z8Zbt608LLiKI")

# %%
session = ag.login("b75Wke67jmHrhCw4ZiDZt-roK_1YP1Z8Zbt608LLiKI")

# %%
session = ag.login("b75Wke67jmHrhCw4ZiDZt-roK_1YP1Z8Zbt608LLiKI")

# %%
session = ag.login("b75Wke67jmHrhCw4ZiDZt-roK_1YP1Z8Zbt608LLiKI")

# %%
session = ag.login("b75Wke67jmHrhCw4ZiDZt-roK_1YP1Z8Zbt608LLiKI")

# %%
session = ag.login("2m_nWrhE5LxBimB71ls4OYO31-neZ_aw0nA0Pf71NDo")

# %%
session = ag.login("2m_nWrhE5LxBimB71ls4OYO31-neZ_aw0nA0Pf71NDo")

# %%
session.termi

# %%
session = ag.login("2m_nWrhE5LxBimB71ls4OYO31-neZ_aw0nA0Pf71NDo")

# %%
session.terminate_session()

# %%
session.terminate_session()

# %%
import antigranular_enterprise as ag
session = ag.login(api_key='l-QKEr3B5x3wWh0IfbmYBUAb0stS6FWXcUZfu5E1EIU')

# %%
# %%ag
# ag_print('test')

# %%
session.terminate_session()

# %%
# %%ag
# ag_print('test')

# %%
session.terminate_session()

# %%
requests.get("https://k8s-capitalq-agenthap-30d4e40a78-1e7dec3aa44a49f0.elb.us-east-2.amazonaws.com", verify=False)

# %%
session = ag.login(api_key="dTs3NOoBFgcBGznTOGfsWs69dP-ZvATAnx4olwIHOj4")

# %%
session = ag.login(api_key="dTs3NOoBFgcBGznTOGfsWs69dP-ZvATAnx4olwIHOj4")

# %%
# %%ag
# ag_print('test')

# %%
# %%ag
# ag_print('test')

# %%
# %%ag
# ag_print('test')

# %%
# %%ag
# ag_print('test')

# %%
session.privacy_odometer()

# %%
session.privacy_odometer()

# %%
# %%ag
# ag_print('test')

# %%
# %%ag
# ag_print('test')

# %%
# %%ag
# ag_print('test')

# %%
# %%ag
# ag_print('test', 'test')

# %%
session.private_import(data={"name": "test", "data": "test"}, name='test_dict')

# %%
# %%ag
# ag_print(test_dict)

# %%
import antigranular_enterprise as ag
ag_client = ag.login()

# %%
ag_client.private_import(data={"name": "test", "data": "test"}, name='test')

# %%
import pandas as pd

# %%
df = pd.DataFrame({'a': [1, 2, 3]})

# %%
ag_client.private_import(data=df, name='test')

# %%
# %%ag
# ag_print(test)

# %%
# %%ag
# ag_print(test)

# %%
import antigranular_enterprise as ag
ag_client = ag.login()

# %%
import antigranular_enterprise as ag
ag_client = ag.login()

# %%
import antigranular_enterprise as ag
ag_client = ag.login()

# %%
import antigranular_enterprise as ag
ag_client = ag.login()

# %%
import antigranular_enterprise as ag
ag_client = ag.login()

# %%
import antigranular_enterprise as ag
ag_client = ag.login()

# %%
ag_client.read_config('test')

# %%
conf_yaml = """
AG_EXEC_TIMEOUT: '1'
AG_OAUTH_URL: 'https://auth-dev.antigranular.com/oauth/token'
"""

# %%
ag_client.write_config(profile='test', yaml_config="""
AG_EXEC_TIMEOUT: '1'
AG_OAUTH_URL: 'https://auth-dev.antigranular.com/oauth/token'
""")

# %%
ag_client.config.AGENT_URL

# %%
ag_client.read_config('DEFAULT')

# %%
ag_client.config.AG_EXEC_TIMEOUT

# %%
# %%ag
# test

# %%
dict_values = { "key1": "value1", "key2": "value2" }

# %%
ag_client.private_import(data=dict_values, name='dict_name')

# %%
from collections import OrderedDict

# %%
ag_client.private_import(data=od, name='od_name')

# %%
type(od), type(dict_values)

# %%
# %%ag
# ag_print(od_name)

# %%
# %%ag
# ag_print(dict_name)

# %%
ag_client.private_import(data=df, name='dict_name')

# %%
from onnx import hub
model = hub.load("resnet50")
ag_client.private_import(data=model, name='onnx_model')

# %%
# %%ag
# ag_print('test')

# %%
ag_client.terminate_session()

# %%
# %%ag
# ag_print('test')

# %%
from onnx import hub

# %%
model = hub.load("resnet50")

# %%
ag_client.private_import(data=model, name='onnx_model')

# %%
ag_client.private_import(data=dict_values, name='df_example')

# %%
import onnx

# %%
ag_client.private_import(data=dict_example, name='dict_example')

# %%
ag_client.private_import(data=df, name='test_df')

# %%
# %%ag
# ag_print(test_df)

# %%
# %%ag
# export("test", 'test')

# %%
# %%ag
# import pandas as pd
# submit_predictions(pd.DataFrame())

# %%
ag_client.private_import(data=df, name='test_dict')

# %%
ag_client.private_import(data=df, name='test_dict')

# %%
ag_client.private_import(data=df, name='test_dict')

# %%
# %%ag
# ag_print(test_df)

# %%
import antigranular_enterprise as ag
ag_client = ag.login(x_oblv_name="CDl6m0dfjtOPYzZUkvSDznKMKWVaEGCg")

# %%
import antigranular_enterprise as ag
ag_client = ag.login(x_oblv_name="CDl6m0dfjtOPYzZUkvSDznKMKWVaEGCg")

# %%
import antigranular_enterprise as ag
ag_client = ag.login(x_oblv_name="CDl6m0dfjtOPYzZUkvSDznKMKWVaEGCg")

# %%
ag_client

# %%
# !pip install sklearn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
iris = load_iris()
X, y = iris.data, iris.target
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from sklearn.linear_model import LogisticRegression
clr = LogisticRegression()
clr.fit(X_train, y_train)
print(clr)

# %% [markdown]
# Convert or export the model into ONNX format

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
import numpy as np

# Generate synthetic data
X, y = make_regression(n_samples=100, n_features=1, noise=0.1)

# Create a linear regression model and train it
model = LinearRegression()
model.fit(X, y)

# %%
from skl2onnx import convert_sklearn
from skl2onnx.common.data_types import FloatTensorType

initial_type = [('float_input', FloatTensorType([None, 1]))]
onnx_model = convert_sklearn(model, initial_types=initial_type)

# Save the ONNX model to disk
with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
import pandas as pd

# %%
# %%ag
# import pandas as pd
# submit_predictions(pd.DataFrame())

# %%
ag_client.private_import(name="model", path="model.onnx")

# %%
# %%ag
# import numpy as np

# %%
# %%ag
# import onnxruntime as rt
# # Load the ONNX model
# sess = rt.InferenceSession(model.SerializeToString())

# %%
# %%ag
# input_name = sess.get_inputs()[0].name

# %%
# %%ag
# output_name = sess.get_outputs()[0].name

# %%
# %%ag
# import numpy as np

# %%
# %%ag
# input_data = np.array([[1.0], [2.0], [3.0]], dtype=np.float32)
#
# # Run the model and make a prediction
# result = sess.run([output_name], {input_name: input_data})
#
# # Extract and print the output
# output_data = result[0]
# ag_print(f"Predictions: {output_data}")

# %%
# %%ag
# import pandas as pd
# df = pd.DataFrame({'a':[1,2,3]})
# ag_print(str(df))

# %%
ag_client.private_import(name="df", data=pd.DataFrame({'a':[1,2,3]}))

# %%
# %%ag
# ag_print(df)

# %%
ag_client.terminate_session()

# %%
# %%ag
# ag_print('test')

# %%
import pandas as pd

# %%
from onnx import hub

# %%
model = hub.load("resnet50")

# %%
ag_client.load(name='model_1', data=model)

# %%
ag_client.load(name='model_from_file', path='C:\\Users\\taori\\Desktop\\something.onnx')

# %%
# %%ag
# test

# %%
ag_client.load(name='model_from_file', path='C:\\Users\\taori\\.cache\\onnx\\hub\\vision\\classification\\resnet\\model\\af16a04a6ec48ac494065d4439fe9dea590d337b9ca6dc328160ccf04a217b9c_resnet50-v1-7.onnx')

# %%
# %%ag
# from ag_utils import export

# %%
# %%ag
# export(model_1, 'model_1')

# %%
# %%ag
# export(model_from_file, 'model_from_file')

# %%
type(model_from_file)

# %%
type(model_1)

# %%
# %%ag
# export(model_1, 'model_1')

# %%
import base64
b = base64.b64encode(open("C:\\Users\\taori\\Desktop\\something.onnx", "rb").read()).decode()

# %%
byte_data = base64.b64decode(b)

# %%
byte_data

# %%
byte_data.decode()

# %%
model_from_file

# %%
# %%ag
# export(df, 'test_dataframe')

# %%
ag_client.terminate_session()

# %%
ag_client.load(name='model_1', data=model)

# %%
# %%ag
# from ag_utils import load_dataframe

# %%
# %%ag
# from ag_utils import export

# %%
# %%ag
# export(test_dataframe, 'test')

# %%
test

# %%
# %%ag
# export(test.head(), 'test')

# %%
test

# %%
# %%ag
# from ag_utils import load_dataframe

# %%
# %%ag

# %%
ag_client.privacy_odometer()

# %%
# %%ag
# test_interrupt

# %%
# %%ag
# test

# %%
# %%ag
# from privacy_request import request_privacy

# %%
# %%ag
# req_privacy = request_privacy(0.1,0.01,'test')

# %%
# %%ag
# from ag_utils import export

# %%
# %%ag
# export(req_privacy, 'req_privacy')

# %%
req_privacy

# %%
# %%ag
# export(test_x, 'test_x')

# %%
ag_client.interrupt_kernal()

# %%
# %%ag
# from ag_utils import load_dataset

# %%
# %%ag
# test_x = load_dataset('test with new schema')

# %%
# %%ag
# from ag_utils import submit_predictions

# %%
# %%ag
# import pandas as pd

# %%
# %%ag
# df = pd.DataFrame.from_dict(d)

# %%
# %%ag
# #negative scenario
# submit_predictions(df)

# %%
# %%ag
# df = pd.DataFrame.from_dict(d)

# %%
# %%ag
# #positive scenario
# submit_predictions(df)

# %%
# %%ag
# submit_predictions(df)

# %%
load_dataset('test_with')

# %%
# %%ag
# from ag_utils import submit_predictions

# %%
ag_client.terminate_session()

# %%
ag_client.active_count()

# %%
#ag_client.interrupt_kernal()

# %%
ag_client.user_name

# %%
# %%ag
# from ag_utils import load_dataset

# %%
# %%ag
# load_dataset('dataset_id')

# %%
# %%ag
# x=5

# %%
# %%ag
# from ag_utils import export
