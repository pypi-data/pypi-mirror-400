# %%
import pandas as pd
import dew_gwdata as gd

# %%
def erupt_dict(frame, key):
    main_frame = frame.drop([key], axis=1)
    erupted_frame = frame[key].apply(pd.Series).rename(columns=lambda x: key + "." + str(x))
    return pd.concat([main_frame, erupted_frame], axis=1)

def erupt(f):
    for col in f.columns:
        series = f[col]
        series_valid = series.dropna()
        if len(series_valid) > 0:
            example = series_valid.iloc[0]
            if isinstance(example, dict):
                return erupt(erupt_dict(f, col))
    return f

def erupt_and_clean(f):
    f = erupt(f)
    f = cleanup_numeric_unit_cols(f)
    f.columns = [c.replace("DischargeSummary.", "Summ.") for c in f.columns]
    return f

def explode(f, col):
    if col in f:
        f = f.explode(col)
    return f

def explode_erupt_and_clean(f, col):
    if col in f:
        f = f.explode(col)
    f = erupt_and_clean(f)
    return f

def cleanup_numeric_unit_cols(f):
    f = f[[c for c in f.columns if not c.endswith(".0") and not c.endswith(".Unit")]]
    f.columns = [c.replace(".Numeric", "") for c in f.columns]
    return f

def fixdf(f):
    for col in f.columns:
        series = f[col]
        if len(series) > 0:
            example = series.iloc[0]
            if isinstance(example, list):
                if len(example) > 0:
                    return fixdf(f.explode(col))
                else:
                    return fixdf(f.drop([col], axis=1))
            elif isinstance(example, dict):
                return fixdf(erupt_dict(f, col))
    return f

# %%
aq = gd.DEWAquarius("AQTS Prod")

# %%
r = aq.publish.get("GetFieldVisitDescriptionList", params={"LocationIdentifier": "A5050502"})
# Out:
# C:\devapps\envs\kent\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
def fetch_field_visits_for_single_location(self, locid):
    r = self.publish.get("GetFieldVisitDescriptionList", params={"LocationIdentifier": locid})
    df = pd.io.json.json_normalize(r.json()["FieldVisitDescriptions"])
    df = df.rename(columns={"Identifier": "FieldVisitIdentifier"})
    return df

# %%
# %%time
df = fetch_field_visits_for_single_location(aq, "A5050502")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 15 columns):
# FieldVisitIdentifier                       141 non-null object
# LocationIdentifier                         141 non-null object
# StartTime                                  141 non-null object
# EndTime                                    141 non-null object
# Party                                      128 non-null object
# IsValid                                    141 non-null bool
# LastModified                               141 non-null object
# CompletedWork.BiologicalSampleTaken        141 non-null bool
# CompletedWork.GroundWaterLevelPerformed    141 non-null bool
# CompletedWork.LevelsPerformed              141 non-null bool
# CompletedWork.OtherSampleTaken             141 non-null bool
# CompletedWork.RecorderDataCollected        141 non-null bool
# CompletedWork.SedimentSampleTaken          141 non-null bool
# CompletedWork.SafetyInspectionPerformed    141 non-null bool
# CompletedWork.WaterQualitySampleTaken      141 non-null bool
# dtypes: bool(9), object(6)
# memory usage: 8.0+ KB
# Wall time: 178 ms
# C:\devapps\envs\kent\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
# %%time
def fetch_field_visit_data_for_single_location(self, locid, cleanup_columns=True):
    r = self.publish.get("GetFieldVisitDataByLocation", params={"LocationIdentifier": locid})
    df = pd.io.json.json_normalize(r.json()["FieldVisitData"])
#     df = df.rename(columns={"Identifier": "FieldVisitIdentifier"})    
    for dt_col in ["StartTime", "EndTime", "LastModified"]:
        df.loc[:, dt_col] = pd.to_datetime(df[dt_col].str[:19], format="%Y-%m-%dT%H:%M:%S")
    df = df[[c for c in df.columns if not c.startswith("CompletedWork.")]]
    df = df.drop(["Attachments"], axis=1)
    return df

df = fetch_field_visit_data_for_single_location(aq, "A5050502", cleanup_columns=False)
for old, new in (
    ("DischargeActivities", "DISCHARGE"),
    ("InspectionActivity", "INSPECT"),
    ("CrossSectionSurveyActivity", "XSECT"),
    ("LevelSurveyActivity", "LEVELS")
):
    df.columns = [c.replace(old, new) for c in df.columns]
# Out:
# C:\devapps\envs\kent\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# Wall time: 1.74 s

# %%
for c in df.columns:
    for col in ["LEVELS", "INSPECT", "XSECT"]:
        if c.startswith(col):
            df = df.drop([c], axis=1)
df = explode_erupt_and_clean(df, "DISCHARGE")
df.columns = [c.replace("DischargeActivities.", ".") for c in df.columns]
# df = explode(df, "XSECT")
# df = explode(df, "INSPECT.Readings")
# df = explode(df, "LEVELS.LevelMeasurements")
# DISCHARGE.Adcp
# DISCHARGE.EngineeredStructure
# DISCHARGE.OtherMethod
# DISCHARGE.PointVelocity
# DISCHARGE.Volumetric
# df = df.explode("DISCHARGE.Summ.GageHeightReadings")
# df = df.pipe(erupt_and_clean)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179 entries, 0 to 140
# Data columns (total 40 columns):
# Identifier                                                    179 non-null object
# LocationIdentifier                                            179 non-null object
# StartTime                                                     179 non-null datetime64[ns]
# EndTime                                                       179 non-null datetime64[ns]
# Party                                                         166 non-null object
# IsValid                                                       179 non-null bool
# LastModified                                                  179 non-null datetime64[ns]
# Approval.ApprovalLevel                                        179 non-null int64
# Approval.LevelDescription                                     179 non-null object
# DISCHARGE.AdcpDischargeActivities                             162 non-null object
# DISCHARGE.EngineeredStructureDischargeActivities              162 non-null object
# DISCHARGE.OtherMethodDischargeActivities                      162 non-null object
# DISCHARGE.PointVelocityDischargeActivities                    162 non-null object
# DISCHARGE.VolumetricDischargeActivities                       162 non-null object
# DISCHARGE.Summ.BaseFlow                                       162 non-null object
# DISCHARGE.Summ.Comments                                       162 non-null object
# DISCHARGE.Summ.DischargeMeasurementReason                     162 non-null object
# DISCHARGE.Summ.DischargeMethod                                162 non-null object
# DISCHARGE.Summ.GageHeightCalculation                          162 non-null object
# DISCHARGE.Summ.GageHeightReadings                             162 non-null object
# DISCHARGE.Summ.GradeCode                                      162 non-null float64
# DISCHARGE.Summ.IsValid                                        162 non-null object
# DISCHARGE.Summ.MeanGageHeightMethod                           162 non-null object
# DISCHARGE.Summ.MeasurementEndTime                             162 non-null object
# DISCHARGE.Summ.MeasurementGrade                               162 non-null object
# DISCHARGE.Summ.MeasurementId                                  162 non-null object
# DISCHARGE.Summ.MeasurementStartTime                           162 non-null object
# DISCHARGE.Summ.MeasurementTime                                162 non-null object
# DISCHARGE.Summ.Party                                          162 non-null object
# DISCHARGE.Summ.Publish                                        162 non-null object
# DISCHARGE.Summ.QualityAssuranceComments                       162 non-null object
# DISCHARGE.Summ.Reviewer                                       162 non-null object
# DISCHARGE.Summ.Adjustment.AdjustmentType                      162 non-null object
# DISCHARGE.Summ.Adjustment.ReasonForAdjustment                 162 non-null object
# DISCHARGE.Summ.DifferenceDuringVisit                          162 non-null float64
# DISCHARGE.Summ.Discharge                                      162 non-null float64
# DISCHARGE.Summ.DischargeUncertainty.ActiveUncertaintyType     162 non-null object
# DISCHARGE.Summ.DischargeUncertainty.QualitativeUncertainty    162 non-null object
# DISCHARGE.Summ.DurationInHours                                162 non-null float64
# DISCHARGE.Summ.MeanGageHeight                                 162 non-null float64
# dtypes: bool(1), datetime64[ns](3), float64(5), int64(1), object(30)
# memory usage: 56.1+ KB

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-138-542b9c0e77d3> in <module>
# ----> 1 df = df.explode("DISCHARGE")
#       2 df = df.pipe(erupt_and_clean)
#       3 df.columns = [c.replace("DischargeActivities.", ".") for c in df.columns]
#       4 # df = df.explode("XSECT")
#       5 # df = df.explode("INSPECT.Readings")
#
# C:\devapps\envs\kent\lib\site-packages\pandas\core\frame.py in explode(self, column)
#    6322             raise ValueError("columns must be unique")
#    6323
# -> 6324         result = self[column].explode()
#    6325         return (
#    6326             self.drop([column], axis=1)
#
# C:\devapps\envs\kent\lib\site-packages\pandas\core\series.py in explode(self)
#    3698             return self.copy()
#    3699
# -> 3700         values, counts = reshape.explode(np.asarray(self.array))
#    3701
#    3702         result = Series(values, index=self.index.repeat(counts), name=self.name)
#
# pandas\_libs\reshape.pyx in pandas._libs.reshape.explode()
#
# KeyError: 0

# %%
df["DISCHARGE.Summ.GageHeightReadings"]
# Out:
# 0      {'IsUsed': True, 'ReadingTime': '2017-09-08T10...
# 0      {'IsUsed': True, 'ReadingTime': '2017-09-08T11...
# 1      {'IsUsed': True, 'ReadingTime': '2015-06-11T13...
# 1      {'IsUsed': True, 'ReadingTime': '2015-06-11T13...
# 2      {'IsUsed': True, 'ReadingTime': '2013-10-15T09...
#                              ...
# 138    {'IsUsed': True, 'ReadingTime': '1973-08-28T12...
# 139    {'IsUsed': True, 'ReadingTime': '1973-07-30T15...
# 139    {'IsUsed': True, 'ReadingTime': '1973-07-30T15...
# 140    {'IsUsed': True, 'ReadingTime': '1973-04-03T11...
# 140    {'IsUsed': True, 'ReadingTime': '1973-04-03T11...
# Name: DISCHARGE.Summ.GageHeightReadings, Length: 581, dtype: object

# %%
df.expl"DISCHARGE.Summ.GageHeightReadings"]
# Out:
# 0      [{'IsUsed': True, 'ReadingTime': '2017-09-08T1...
# 1      [{'IsUsed': True, 'ReadingTime': '2015-06-11T1...
# 2      [{'IsUsed': True, 'ReadingTime': '2013-10-15T0...
# 3      [{'IsUsed': True, 'ReadingTime': '2013-07-16T1...
# 4                                                    NaN
#                              ...
# 136    [{'IsUsed': True, 'ReadingTime': '1974-05-31T1...
# 137    [{'IsUsed': True, 'ReadingTime': '1974-02-01T1...
# 138    [{'IsUsed': True, 'ReadingTime': '1973-08-28T1...
# 139    [{'IsUsed': True, 'ReadingTime': '1973-07-30T1...
# 140    [{'IsUsed': True, 'ReadingTime': '1973-04-03T1...
# Name: DISCHARGE.Summ.GageHeightReadings, Length: 179, dtype: object

# %%
yal.to_csv("test.csv")

# %%
yal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 304 entries, 0 to 140
# Data columns (total 56 columns):
# Attachments                                                   304 non-null object
# Identifier                                                    304 non-null object
# LocationIdentifier                                            304 non-null object
# StartTime                                                     304 non-null datetime64[ns]
# EndTime                                                       304 non-null datetime64[ns]
# Party                                                         291 non-null object
# IsValid                                                       304 non-null bool
# LastModified                                                  304 non-null datetime64[ns]
# Approval.ApprovalLevel                                        304 non-null int64
# Approval.LevelDescription                                     304 non-null object
# INSPECT.Readings                                              2 non-null object
# INSPECT.IsValid                                               2 non-null object
# LEVELS.OriginReferencePointUniqueId                           14 non-null object
# LEVELS.Method                                                 14 non-null object
# LEVELS.Comments                                               14 non-null object
# LEVELS.LevelMeasurements                                      14 non-null object
# LEVELS.Party                                                  13 non-null object
# DISCHARGE.AdcpDischargeActivities                             282 non-null object
# DISCHARGE.EngineeredStructureDischargeActivities              282 non-null object
# DISCHARGE.OtherMethodDischargeActivities                      282 non-null object
# DISCHARGE.PointVelocityDischargeActivities                    282 non-null object
# DISCHARGE.VolumetricDischargeActivities                       282 non-null object
# XSECT.Channel                                                 9 non-null object
# XSECT.Comments                                                9 non-null object
# XSECT.EndTime                                                 9 non-null object
# XSECT.Party                                                   9 non-null object
# XSECT.RelativeLocation                                        9 non-null object
# XSECT.StartTime                                               9 non-null object
# XSECT.StartingPoint                                           9 non-null object
# DISCHARGE.Summ.BaseFlow                                       282 non-null object
# DISCHARGE.Summ.Comments                                       282 non-null object
# DISCHARGE.Summ.DischargeMeasurementReason                     282 non-null object
# DISCHARGE.Summ.DischargeMethod                                282 non-null object
# DISCHARGE.Summ.GageHeightCalculation                          282 non-null object
# DISCHARGE.Summ.GageHeightReadings                             282 non-null object
# DISCHARGE.Summ.GradeCode                                      282 non-null float64
# DISCHARGE.Summ.IsValid                                        282 non-null object
# DISCHARGE.Summ.MeanGageHeightMethod                           282 non-null object
# DISCHARGE.Summ.MeasurementEndTime                             282 non-null object
# DISCHARGE.Summ.MeasurementGrade                               282 non-null object
# DISCHARGE.Summ.MeasurementId                                  282 non-null object
# DISCHARGE.Summ.MeasurementStartTime                           282 non-null object
# DISCHARGE.Summ.MeasurementTime                                282 non-null object
# DISCHARGE.Summ.Party                                          282 non-null object
# DISCHARGE.Summ.Publish                                        282 non-null object
# DISCHARGE.Summ.QualityAssuranceComments                       282 non-null object
# DISCHARGE.Summ.Reviewer                                       282 non-null object
# XSECT.Stage                                                   9 non-null float64
# DISCHARGE.Summ.Adjustment.AdjustmentType                      282 non-null object
# DISCHARGE.Summ.Adjustment.ReasonForAdjustment                 282 non-null object
# DISCHARGE.Summ.DifferenceDuringVisit                          282 non-null float64
# DISCHARGE.Summ.Discharge                                      282 non-null float64
# DISCHARGE.Summ.DischargeUncertainty.ActiveUncertaintyType     282 non-null object
# DISCHARGE.Summ.DischargeUncertainty.QualitativeUncertainty    282 non-null object
# DISCHARGE.Summ.DurationInHours                                282 non-null float64
# DISCHARGE.Summ.MeanGageHeight                                 282 non-null float64
# dtypes: bool(1), datetime64[ns](3), float64(6), int64(1), object(45)
# memory usage: 133.3+ KB

# %%
yal.pipe(erupt)
# Out:
#                                            Attachments  \
# 0    [{'AttachmentType': 'FieldDataPlugin', 'Attach...
# 1    [{'AttachmentType': 'FieldDataPlugin', 'Attach...
# 2    [{'AttachmentType': 'FieldDataPlugin', 'Attach...
# 3    [{'AttachmentType': 'FieldDataPlugin', 'Attach...
# 4    [{'AttachmentType': 'FieldDataPlugin', 'Attach...
# ..                                                 ...
# 136  [{'AttachmentType': 'FieldDataPlugin', 'Attach...
# 137  [{'AttachmentType': 'FieldDataPlugin', 'Attach...
# 138  [{'AttachmentType': 'FieldDataPlugin', 'Attach...
# 139  [{'AttachmentType': 'FieldDataPlugin', 'Attach...
# 140  [{'AttachmentType': 'FieldDataPlugin', 'Attach...
#
#                                Identifier LocationIdentifier  \
# 0    de6edd37-2dc0-4b98-a774-d95499250b4e           A5050502
# 1    e565d270-69ff-4e95-a768-45c4cb3bd633           A5050502
# 2    a43d1b06-bafe-4cdb-99eb-30cd0794f294           A5050502
# 3    295182fb-a704-4341-974d-d5d030dcd703           A5050502
# 4    a5157e2d-ff6e-4893-918a-5dcf60aedd9c           A5050502
# ..                                    ...                ...
# 136  ecdbe2b0-2a1d-4da8-acea-26246e17e1f1           A5050502
# 137  e7e9d6a1-eee8-4d24-b51f-8e3c1472ce2f           A5050502
# 138  7c07d9d3-cc9f-470a-88c8-fdc226ad875c           A5050502
# 139  7aacbe1f-0fd1-4d7e-88b1-b716ee512e1d           A5050502
# 140  4f592b26-bafb-4bbf-bce0-3b99d0cb6e47           A5050502
#
#               StartTime             EndTime    Party  IsValid  \
# 0   2017-09-08 10:28:00 2017-09-08 11:04:00   DCR/PB     True
# 1   2015-06-11 13:34:00 2015-06-11 13:45:00   TS DCD     True
# 2   2013-10-15 09:13:00 2013-10-15 09:35:00  DR / TS     True
# 3   2013-07-16 14:15:00 2013-07-16 15:01:00   DCR/KS     True
# 4   2013-04-29 00:00:00 2013-04-29 03:00:00  PHANSEN     True
# ..                  ...                 ...      ...      ...
# 136 1974-05-31 12:20:00 1974-05-31 12:20:00       TF     True
# 137 1974-02-01 15:40:00 1974-02-01 15:40:00       JM     True
# 138 1973-08-28 12:15:00 1973-08-28 12:15:00      JLW     True
# 139 1973-07-30 15:45:00 1973-07-30 15:45:00       JM     True
# 140 1973-04-03 11:10:00 1973-04-03 11:10:00       JM     True
#
#            LastModified  Approval.ApprovalLevel Approval.LevelDescription  \
# 0   2020-03-18 14:59:29                    1200                  Approved
# 1   2020-03-18 14:59:29                    1200                  Approved
# 2   2020-03-18 14:59:29                    1200                  Approved
# 3   2020-03-18 14:59:29                    1200                  Approved
# 4   2020-03-18 14:59:29                    1200                  Approved
# ..                  ...                     ...                       ...
# 136 2020-03-18 14:59:29                    1200                  Approved
# 137 2020-03-18 14:59:29                    1200                  Approved
# 138 2020-03-18 14:59:29                    1200                  Approved
# 139 2020-03-18 14:59:29                    1200                  Approved
# 140 2020-03-18 14:59:29                    1200                  Approved
#
#      ... DISCHARGE.Summ.Reviewer XSECT.Stage  \
# 0    ...                                 NaN
# 1    ...                                 NaN
# 2    ...                                 NaN
# 3    ...                                 NaN
# 4    ...                     NaN         0.0
# ..   ...                     ...         ...
# 136  ...                                 NaN
# 137  ...                                 NaN
# 138  ...                                 NaN
# 139  ...                                 NaN
# 140  ...                                 NaN
#
#     DISCHARGE.Summ.Adjustment.AdjustmentType  \
# 0                                    Unknown
# 1                                    Unknown
# 2                                    Unknown
# 3                                    Unknown
# 4                                        NaN
# ..                                       ...
# 136                                  Unknown
# 137                                  Unknown
# 138                                  Unknown
# 139                                  Unknown
# 140                                  Unknown
#
#     DISCHARGE.Summ.Adjustment.ReasonForAdjustment  \
# 0                                         Unknown
# 1                                         Unknown
# 2                                         Unknown
# 3                                         Unknown
# 4                                             NaN
# ..                                            ...
# 136                                       Unknown
# 137                                       Unknown
# 138                                       Unknown
# 139                                       Unknown
# 140                                       Unknown
#
#     DISCHARGE.Summ.DifferenceDuringVisit DISCHARGE.Summ.Discharge  \
# 0                                 -0.002                   1.3700
# 1                                  0.000                   0.0124
# 2                                  0.000                   0.0637
# 3                                 -0.002                   0.2671
# 4                                    NaN                      NaN
# ..                                   ...                      ...
# 136                                0.000                   0.4010
# 137                                0.000                  28.8100
# 138                                0.000                   4.0900
# 139                                0.000                   0.5760
# 140                                0.000                   0.0550
#
#     DISCHARGE.Summ.DischargeUncertainty.ActiveUncertaintyType  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                  NaN
# ..                                                 ...
# 136                                               None
# 137                                               None
# 138                                               None
# 139                                               None
# 140                                               None
#
#     DISCHARGE.Summ.DischargeUncertainty.QualitativeUncertainty  \
# 0                                              Unknown
# 1                                              Unknown
# 2                                              Unknown
# 3                                              Unknown
# 4                                                  NaN
# ..                                                 ...
# 136                                            Unknown
# 137                                            Unknown
# 138                                            Unknown
# 139                                            Unknown
# 140                                            Unknown
#
#     DISCHARGE.Summ.DurationInHours DISCHARGE.Summ.MeanGageHeight
# 0                         0.600000                         1.690
# 1                         0.183333                         1.032
# 2                         0.366667                         1.104
# 3                         0.766667                         1.300
# 4                              NaN                           NaN
# ..                             ...                           ...
# 136                       0.000000                         1.357
# 137                       0.000000                         2.603
# 138                       0.000000                         1.893
# 139                       0.000000                         1.472
# 140                       0.000000                         1.098
#
# [304 rows x 56 columns]

# %%
dfx = pd.io.json.json_normalize(r.json()["FieldVisitData"])

# %%
dfxx = fixdf(dfx)
# Out:
#                                Identifier LocationIdentifier  \
# 0    de6edd37-2dc0-4b98-a774-d95499250b4e           A5050502
# 0    de6edd37-2dc0-4b98-a774-d95499250b4e           A5050502
# 1    e565d270-69ff-4e95-a768-45c4cb3bd633           A5050502
# 1    e565d270-69ff-4e95-a768-45c4cb3bd633           A5050502
# 2    a43d1b06-bafe-4cdb-99eb-30cd0794f294           A5050502
# ..                                    ...                ...
# 138  7c07d9d3-cc9f-470a-88c8-fdc226ad875c           A5050502
# 139  7aacbe1f-0fd1-4d7e-88b1-b716ee512e1d           A5050502
# 139  7aacbe1f-0fd1-4d7e-88b1-b716ee512e1d           A5050502
# 140  4f592b26-bafb-4bbf-bce0-3b99d0cb6e47           A5050502
# 140  4f592b26-bafb-4bbf-bce0-3b99d0cb6e47           A5050502
#
#                              StartTime                            EndTime  \
# 0    2017-09-08T10:28:00.0000000+09:30  2017-09-08T11:04:00.0000000+09:30
# 0    2017-09-08T10:28:00.0000000+09:30  2017-09-08T11:04:00.0000000+09:30
# 1    2015-06-11T13:34:00.0000000+09:30  2015-06-11T13:45:00.0000000+09:30
# 1    2015-06-11T13:34:00.0000000+09:30  2015-06-11T13:45:00.0000000+09:30
# 2    2013-10-15T09:13:00.0000000+09:30  2013-10-15T09:35:00.0000000+09:30
# ..                                 ...                                ...
# 138  1973-08-28T12:15:00.0000000+09:30  1973-08-28T12:15:00.0000000+09:30
# 139  1973-07-30T15:45:00.0000000+09:30  1973-07-30T15:45:00.0000000+09:30
# 139  1973-07-30T15:45:00.0000000+09:30  1973-07-30T15:45:00.0000000+09:30
# 140  1973-04-03T11:10:00.0000000+09:30  1973-04-03T11:10:00.0000000+09:30
# 140  1973-04-03T11:10:00.0000000+09:30  1973-04-03T11:10:00.0000000+09:30
#
#        Party  IsValid                       LastModified  \
# 0     DCR/PB     True  2020-03-18T14:59:29.3880024+09:30
# 0     DCR/PB     True  2020-03-18T14:59:29.3880024+09:30
# 1     TS DCD     True  2020-03-18T14:59:29.3880024+09:30
# 1     TS DCD     True  2020-03-18T14:59:29.3880024+09:30
# 2    DR / TS     True  2020-03-18T14:59:29.3880024+09:30
# ..       ...      ...                                ...
# 138      JLW     True  2020-03-18T14:59:29.3880024+09:30
# 139       JM     True  2020-03-18T14:59:29.3880024+09:30
# 139       JM     True  2020-03-18T14:59:29.3880024+09:30
# 140       JM     True  2020-03-18T14:59:29.3880024+09:30
# 140       JM     True  2020-03-18T14:59:29.3880024+09:30
#
#      Approval.ApprovalLevel Approval.LevelDescription  \
# 0                      1200                  Approved
# 0                      1200                  Approved
# 1                      1200                  Approved
# 1                      1200                  Approved
# 2                      1200                  Approved
# ..                      ...                       ...
# 138                    1200                  Approved
# 139                    1200                  Approved
# 139                    1200                  Approved
# 140                    1200                  Approved
# 140                    1200                  Approved
#
#      CompletedWork.BiologicalSampleTaken  ...  \
# 0                                  False  ...
# 0                                  False  ...
# 1                                  False  ...
# 1                                  False  ...
# 2                                  False  ...
# ..                                   ...  ...
# 138                                False  ...
# 139                                False  ...
# 139                                False  ...
# 140                                False  ...
# 140                                False  ...
#
#      DischargeActivities.PointVelocityDischargeActivities.Width.Numeric  \
# 0                                                8.267
# 0                                                8.267
# 1                                                0.000
# 1                                                0.000
# 2                                                4.500
# ..                                                 ...
# 138                                              0.000
# 139                                              0.000
# 139                                              0.000
# 140                                              0.000
# 140                                              0.000
#
#      DischargeActivities.PointVelocityDischargeActivities.Width.Unit  \
# 0                                                    m
# 0                                                    m
# 1                                                    m
# 1                                                    m
# 2                                                    m
# ..                                                 ...
# 138                                                  m
# 139                                                  m
# 139                                                  m
# 140                                                  m
# 140                                                  m
#
#      DischargeActivities.DischargeSummary.DischargeUncertainty.QuantitativeUncertainty.0  \
# 0                                                  NaN
# 0                                                  NaN
# 1                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# ..                                                 ...
# 138                                                NaN
# 139                                                NaN
# 139                                                NaN
# 140                                                NaN
# 140                                                NaN
#
#      DischargeActivities.DischargeSummary.GageHeightReadings.GageHeight.0  \
# 0                                                  NaN
# 0                                                  NaN
# 1                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# ..                                                 ...
# 138                                                NaN
# 139                                                NaN
# 139                                                NaN
# 140                                                NaN
# 140                                                NaN
#
#      DischargeActivities.DischargeSummary.GageHeightReadings.GageHeight.Numeric  \
# 0                                                1.691
# 0                                                1.689
# 1                                                1.032
# 1                                                1.032
# 2                                                1.104
# ..                                                 ...
# 138                                              1.893
# 139                                              1.472
# 139                                              1.472
# 140                                              1.098
# 140                                              1.098
#
#      DischargeActivities.PointVelocityDischargeActivities.DischargeChannelMeasurement.Discharge.0  \
# 0                                                  NaN
# 0                                                  NaN
# 1                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# ..                                                 ...
# 138                                                NaN
# 139                                                NaN
# 139                                                NaN
# 140                                                NaN
# 140                                                NaN
#
#      DischargeActivities.PointVelocityDischargeActivities.DischargeChannelMeasurement.Discharge.Numeric  \
# 0                                               1.3700
# 0                                               1.3700
# 1                                               0.0124
# 1                                               0.0124
# 2                                               0.0637
# ..                                                 ...
# 138                                             4.0900
# 139                                             0.5760
# 139                                             0.5760
# 140                                             0.0550
# 140                                             0.0550
#
#     DischargeActivities.PointVelocityDischargeActivities.DischargeChannelMeasurement.Discharge.Unit  \
# 0                                                m^3/s
# 0                                                m^3/s
# 1                                                m^3/s
# 1                                                m^3/s
# 2                                                m^3/s
# ..                                                 ...
# 138                                              m^3/s
# 139                                              m^3/s
# 139                                              m^3/s
# 140                                              m^3/s
# 140                                              m^3/s
#
#     DischargeActivities.PointVelocityDischargeActivities.DischargeChannelMeasurement.DistanceToGage.0  \
# 0                                                  NaN
# 0                                                  NaN
# 1                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# ..                                                 ...
# 138                                                NaN
# 139                                                NaN
# 139                                                NaN
# 140                                                NaN
# 140                                                NaN
#
#     DischargeActivities.PointVelocityDischargeActivities.DischargeChannelMeasurement.DistanceToGage.Unit
# 0                                                    m
# 0                                                    m
# 1                                                    m
# 1                                                    m
# 2                                                    m
# ..                                                 ...
# 138                                                  m
# 139                                                  m
# 139                                                  m
# 140                                                  m
# 140                                                  m
#
# [5309 rows x 120 columns]

# %%
e = d.explode("DischargeSummary.GageHeightReadings")
e.columns = [c.replace("DischargeSummary", "DS") for c in e.columns]
print(e.T)
# Out:
#                                                                                                 0  \
# VolumetricDischargeActivities                                                                  []
# EngineeredStructureDischargeActivities                                                         []
# PointVelocityDischargeActivities                [{'DischargeChannelMeasurement': {'Channel': '...
# OtherMethodDischargeActivities                                                                 []
# AdcpDischargeActivities                                                                        []
# DS.MeasurementStartTime                                         2017-09-08T10:28:00.0000000+09:30
# DS.MeasurementEndTime                                           2017-09-08T11:04:00.0000000+09:30
# DS.MeasurementTime                                              2017-09-08T10:46:00.0000000+09:30
# DS.Party                                                                                   DCR/PB
# DS.BaseFlow                                                                               Unknown
# DS.Adjustment.AdjustmentType                                                              Unknown
# DS.Adjustment.ReasonForAdjustment                                                         Unknown
# DS.AlternateRatingDischarge.Unit                                                            m^3/s
# DS.Discharge.Unit                                                                           m^3/s
# DS.Discharge.Numeric                                                                         1.37
# DS.DischargeMethod                                                                    Mid-section
# DS.MeanGageHeight.Unit                                                                          m
# DS.MeanGageHeight.Numeric                                                                    1.69
# DS.MeanGageHeightMethod                                                                      None
# DS.MeanIndexVelocity.Unit
# DS.DischargeMeasurementReason                                                             Unknown
# DS.Comments                                     METHOD: Moving Boat METER NO: RS-M9 3934 COMMN...
# DS.GageHeightCalculation                                                            SimpleAverage
# DS.GageHeightReadings                           {'IsUsed': True, 'ReadingTime': '2017-09-08T10...
# DS.DifferenceDuringVisit.Numeric                                                           -0.002
# DS.DurationInHours.Numeric                                                                    0.6
# DS.QualityAssuranceComments
# DS.DischargeUncertainty.ActiveUncertaintyType                                                None
# DS.DischargeUncertainty.QualitativeUncertainty                                            Unknown
# DS.MeasurementGrade                                                                       Unknown
# DS.GradeCode                                                                                   30
# DS.MeasurementId                                                                              162
# DS.Reviewer
# DS.IsValid                                                                                   True
# DS.Publish                                                                                   True
#
#                                                                                                 0
# VolumetricDischargeActivities                                                                  []
# EngineeredStructureDischargeActivities                                                         []
# PointVelocityDischargeActivities                [{'DischargeChannelMeasurement': {'Channel': '...
# OtherMethodDischargeActivities                                                                 []
# AdcpDischargeActivities                                                                        []
# DS.MeasurementStartTime                                         2017-09-08T10:28:00.0000000+09:30
# DS.MeasurementEndTime                                           2017-09-08T11:04:00.0000000+09:30
# DS.MeasurementTime                                              2017-09-08T10:46:00.0000000+09:30
# DS.Party                                                                                   DCR/PB
# DS.BaseFlow                                                                               Unknown
# DS.Adjustment.AdjustmentType                                                              Unknown
# DS.Adjustment.ReasonForAdjustment                                                         Unknown
# DS.AlternateRatingDischarge.Unit                                                            m^3/s
# DS.Discharge.Unit                                                                           m^3/s
# DS.Discharge.Numeric                                                                         1.37
# DS.DischargeMethod                                                                    Mid-section
# DS.MeanGageHeight.Unit                                                                          m
# DS.MeanGageHeight.Numeric                                                                    1.69
# DS.MeanGageHeightMethod                                                                      None
# DS.MeanIndexVelocity.Unit
# DS.DischargeMeasurementReason                                                             Unknown
# DS.Comments                                     METHOD: Moving Boat METER NO: RS-M9 3934 COMMN...
# DS.GageHeightCalculation                                                            SimpleAverage
# DS.GageHeightReadings                           {'IsUsed': True, 'ReadingTime': '2017-09-08T11...
# DS.DifferenceDuringVisit.Numeric                                                           -0.002
# DS.DurationInHours.Numeric                                                                    0.6
# DS.QualityAssuranceComments
# DS.DischargeUncertainty.ActiveUncertaintyType                                                None
# DS.DischargeUncertainty.QualitativeUncertainty                                            Unknown
# DS.MeasurementGrade                                                                       Unknown
# DS.GradeCode                                                                                   30
# DS.MeasurementId                                                                              162
# DS.Reviewer
# DS.IsValid                                                                                   True
# DS.Publish                                                                                   True

# %%
import excellentpandas

# %%
excellentpandas.show_in_excel(fixdf(e))

# %%
for col in out.columns:
    series = out[col]
    print(col)
    print(type(series.iloc[0]))
# Out:
# VolumetricDischargeActivities
# <class 'list'>
# EngineeredStructureDischargeActivities
# <class 'list'>
# OtherMethodDischargeActivities
# <class 'list'>
# AdcpDischargeActivities
# <class 'list'>
# DS.MeasurementStartTime
# <class 'str'>
# DS.MeasurementEndTime
# <class 'str'>
# DS.MeasurementTime
# <class 'str'>
# DS.Party
# <class 'str'>
# DS.BaseFlow
# <class 'str'>
# DS.Adjustment.AdjustmentType
# <class 'str'>
# DS.Adjustment.ReasonForAdjustment
# <class 'str'>
# DS.AlternateRatingDischarge.Unit
# <class 'str'>
# DS.Discharge.Unit
# <class 'str'>
# DS.Discharge.Numeric
# <class 'numpy.float64'>
# DS.DischargeMethod
# <class 'str'>
# DS.MeanGageHeight.Unit
# <class 'str'>
# DS.MeanGageHeight.Numeric
# <class 'numpy.float64'>
# DS.MeanGageHeightMethod
# <class 'str'>
# DS.MeanIndexVelocity.Unit
# <class 'str'>
# DS.DischargeMeasurementReason
# <class 'str'>
# DS.Comments
# <class 'str'>
# DS.GageHeightCalculation
# <class 'str'>
# DS.DifferenceDuringVisit.Numeric
# <class 'numpy.float64'>
# DS.DurationInHours.Numeric
# <class 'numpy.float64'>
# DS.QualityAssuranceComments
# <class 'str'>
# DS.DischargeUncertainty.ActiveUncertaintyType
# <class 'str'>
# DS.DischargeUncertainty.QualitativeUncertainty
# <class 'str'>
# DS.MeasurementGrade
# <class 'str'>
# DS.GradeCode
# <class 'numpy.int64'>
# DS.MeasurementId
# <class 'str'>
# DS.Reviewer
# <class 'str'>
# DS.IsValid
# <class 'numpy.bool_'>
# DS.Publish
# <class 'numpy.bool_'>
# DS.GageHeightReadings.IsUsed
# <class 'numpy.bool_'>
# DS.GageHeightReadings.ReadingTime
# <class 'str'>
# DS.GageHeightReadings.GageHeight.Numeric
# <class 'numpy.float64'>
# PointVelocityDischargeActivities.DischargeChannelMeasurement
# <class 'dict'>
# PointVelocityDischargeActivities.DistanceToMeter
# <class 'dict'>
# PointVelocityDischargeActivities.Width
# <class 'dict'>
# PointVelocityDischargeActivities.Area
# <class 'dict'>
# PointVelocityDischargeActivities.MeanObservationDurationInSeconds
# <class 'dict'>
# PointVelocityDischargeActivities.SuspensionCoefficientUsed
# <class 'numpy.bool_'>
# PointVelocityDischargeActivities.MethodCoefficientUsed
# <class 'numpy.bool_'>
# PointVelocityDischargeActivities.HorizontalCoefficientUsed
# <class 'numpy.bool_'>
# PointVelocityDischargeActivities.NumberOfPanels
# <class 'numpy.int64'>
# PointVelocityDischargeActivities.DischargeMethod
# <class 'str'>
# PointVelocityDischargeActivities.StartPoint
# <class 'str'>
# PointVelocityDischargeActivities.IsValid
# <class 'numpy.bool_'>
# PointVelocityDischargeActivities.Verticals
# <class 'list'>
# PointVelocityDischargeActivities.VelocityAverage.Unit
# <class 'str'>
# PointVelocityDischargeActivities.VelocityAverage.Numeric
# <class 'numpy.float64'>

# %%
e.drop(["DS.GageHeightReadings"], axis=1)
# Out:
#   VolumetricDischargeActivities EngineeredStructureDischargeActivities  \
# 0                            []                                     []
# 0                            []                                     []
#
#                     PointVelocityDischargeActivities  \
# 0  [{'DischargeChannelMeasurement': {'Channel': '...
# 0  [{'DischargeChannelMeasurement': {'Channel': '...
#
#   OtherMethodDischargeActivities AdcpDischargeActivities  \
# 0                             []                      []
# 0                             []                      []
#
#              DS.MeasurementStartTime              DS.MeasurementEndTime  \
# 0  2017-09-08T10:28:00.0000000+09:30  2017-09-08T11:04:00.0000000+09:30
# 0  2017-09-08T10:28:00.0000000+09:30  2017-09-08T11:04:00.0000000+09:30
#
#                   DS.MeasurementTime DS.Party DS.BaseFlow  ...  \
# 0  2017-09-08T10:46:00.0000000+09:30   DCR/PB     Unknown  ...
# 0  2017-09-08T10:46:00.0000000+09:30   DCR/PB     Unknown  ...
#
#   DS.DurationInHours.Numeric DS.QualityAssuranceComments  \
# 0                        0.6
# 0                        0.6
#
#   DS.DischargeUncertainty.ActiveUncertaintyType  \
# 0                                          None
# 0                                          None
#
#   DS.DischargeUncertainty.QualitativeUncertainty  DS.MeasurementGrade  \
# 0                                        Unknown              Unknown
# 0                                        Unknown              Unknown
#
#   DS.GradeCode DS.MeasurementId  DS.Reviewer DS.IsValid DS.Publish
# 0           30              162                    True       True
# 0           30              162                    True       True
#
# [2 rows x 34 columns]

# %%
e["DS.GageHeightReadings"].apply(pd.Series).rename(columns=lambda x: "DS.GageHeightReadings." + str(x))
# Out:
#    DS.GageHeightReadings.IsUsed  DS.GageHeightReadings.ReadingTime  \
# 0                          True  2017-09-08T10:28:00.0000000+09:30
# 0                          True  2017-09-08T11:04:00.0000000+09:30
#
#   DS.GageHeightReadings.GageHeight
# 0               {'Numeric': 1.691}
# 0               {'Numeric': 1.689}

# %%
pd.concat([Out[90], Out[95]], axis=1).T
# Out:
#                                                                                                 0  \
# VolumetricDischargeActivities                                                                  []
# EngineeredStructureDischargeActivities                                                         []
# PointVelocityDischargeActivities                [{'DischargeChannelMeasurement': {'Channel': '...
# OtherMethodDischargeActivities                                                                 []
# AdcpDischargeActivities                                                                        []
# DS.MeasurementStartTime                                         2017-09-08T10:28:00.0000000+09:30
# DS.MeasurementEndTime                                           2017-09-08T11:04:00.0000000+09:30
# DS.MeasurementTime                                              2017-09-08T10:46:00.0000000+09:30
# DS.Party                                                                                   DCR/PB
# DS.BaseFlow                                                                               Unknown
# DS.Adjustment.AdjustmentType                                                              Unknown
# DS.Adjustment.ReasonForAdjustment                                                         Unknown
# DS.AlternateRatingDischarge.Unit                                                            m^3/s
# DS.Discharge.Unit                                                                           m^3/s
# DS.Discharge.Numeric                                                                         1.37
# DS.DischargeMethod                                                                    Mid-section
# DS.MeanGageHeight.Unit                                                                          m
# DS.MeanGageHeight.Numeric                                                                    1.69
# DS.MeanGageHeightMethod                                                                      None
# DS.MeanIndexVelocity.Unit
# DS.DischargeMeasurementReason                                                             Unknown
# DS.Comments                                     METHOD: Moving Boat METER NO: RS-M9 3934 COMMN...
# DS.GageHeightCalculation                                                            SimpleAverage
# DS.DifferenceDuringVisit.Numeric                                                           -0.002
# DS.DurationInHours.Numeric                                                                    0.6
# DS.QualityAssuranceComments
# DS.DischargeUncertainty.ActiveUncertaintyType                                                None
# DS.DischargeUncertainty.QualitativeUncertainty                                            Unknown
# DS.MeasurementGrade                                                                       Unknown
# DS.GradeCode                                                                                   30
# DS.MeasurementId                                                                              162
# DS.Reviewer
# DS.IsValid                                                                                   True
# DS.Publish                                                                                   True
# DS.GageHeightReadings.IsUsed                                                                 True
# DS.GageHeightReadings.ReadingTime                               2017-09-08T10:28:00.0000000+09:30
# DS.GageHeightReadings.GageHeight                                               {'Numeric': 1.691}
#
#                                                                                                 0
# VolumetricDischargeActivities                                                                  []
# EngineeredStructureDischargeActivities                                                         []
# PointVelocityDischargeActivities                [{'DischargeChannelMeasurement': {'Channel': '...
# OtherMethodDischargeActivities                                                                 []
# AdcpDischargeActivities                                                                        []
# DS.MeasurementStartTime                                         2017-09-08T10:28:00.0000000+09:30
# DS.MeasurementEndTime                                           2017-09-08T11:04:00.0000000+09:30
# DS.MeasurementTime                                              2017-09-08T10:46:00.0000000+09:30
# DS.Party                                                                                   DCR/PB
# DS.BaseFlow                                                                               Unknown
# DS.Adjustment.AdjustmentType                                                              Unknown
# DS.Adjustment.ReasonForAdjustment                                                         Unknown
# DS.AlternateRatingDischarge.Unit                                                            m^3/s
# DS.Discharge.Unit                                                                           m^3/s
# DS.Discharge.Numeric                                                                         1.37
# DS.DischargeMethod                                                                    Mid-section
# DS.MeanGageHeight.Unit                                                                          m
# DS.MeanGageHeight.Numeric                                                                    1.69
# DS.MeanGageHeightMethod                                                                      None
# DS.MeanIndexVelocity.Unit
# DS.DischargeMeasurementReason                                                             Unknown
# DS.Comments                                     METHOD: Moving Boat METER NO: RS-M9 3934 COMMN...
# DS.GageHeightCalculation                                                            SimpleAverage
# DS.DifferenceDuringVisit.Numeric                                                           -0.002
# DS.DurationInHours.Numeric                                                                    0.6
# DS.QualityAssuranceComments
# DS.DischargeUncertainty.ActiveUncertaintyType                                                None
# DS.DischargeUncertainty.QualitativeUncertainty                                            Unknown
# DS.MeasurementGrade                                                                       Unknown
# DS.GradeCode                                                                                   30
# DS.MeasurementId                                                                              162
# DS.Reviewer
# DS.IsValid                                                                                   True
# DS.Publish                                                                                   True
# DS.GageHeightReadings.IsUsed                                                                 True
# DS.GageHeightReadings.ReadingTime                               2017-09-08T11:04:00.0000000+09:30
# DS.GageHeightReadings.GageHeight                                               {'Numeric': 1.689}

# %%
import collections

def flatten(d, parent_key='', sep='_'):
    items = []
    for k, v in d.items():
        new_key = parent_key + sep + k if parent_key else k
        if isinstance(v, collections.MutableMapping):
            items.extend(flatten(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# %%
flatten(a, sep=".")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-63542ccda15c> in <module>
# ----> 1 flatten(a, sep=".")
#
# <ipython-input-50-72a859df90ce> in flatten(d, parent_key, sep)
#       3 def flatten(d, parent_key='', sep='_'):
#       4     items = []
# ----> 5     for k, v in d.items():
#       6         new_key = parent_key + sep + k if parent_key else k
#       7         if isinstance(v, collections.MutableMapping):
#
# AttributeError: 'list' object has no attribute 'items'
