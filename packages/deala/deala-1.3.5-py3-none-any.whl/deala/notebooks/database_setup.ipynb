# %% [markdown]
# <p style="font-size:30px; font-weight:bold">
# Case Study – Comparison of Pan Production with DEALA (with regiopremise)
# </p>
#
# <p style="font-size:12px">
# In general, this case study demonstrates how the DEALA package can be used and how the DEALA method should be applied to calculate the economic impacts of production systems when considering the package regiopremise.
# </p>
#
# <p style="font-size:12px">
# As an example, one conventional pan is compared regarding its economic and environmental impacts.
# </p>
#
# <p style="font-size:12px">
# The notebook is divided into four steps, which are:
# </p>
#
# 1. [Initialization of the project](#1-initalization-of-the-project)
# 2. [Import of the background system](#2-import-background-system)
# 3. [Import of the intermediate system](#3-import-intermediate-system)
# 4. [Import of the foreground system](#4-import-foreground-system)

# %% [markdown]
# # 1. Initalization of the project
#
# <p style="font-size:12px">
# The initialization step includes two substeps:
# </p>
#
# <ol style="font-size:12px; padding-left: 20px">
#   <li>The required Python modules and packages must be imported and defined.</li>
#   <li>The project is set up, including the definition of file paths to external data and the assumptions made for the case study.</li>
# </ol>

# %% [markdown]
# ## 1.1 load python packages
#
# <p style="font-size:18px">
# To load all required Python modules and packages, you first need to install the <code>DEALA</code> package via pip. Use <code>pip install deala</code> for this.
# </p>

# %%
# initializatiin of packages
import brightway2 as bw
from bw2io import *
from tqdm import *
import toml
from pathlib import Path
import regioinvent
from bw2data import *
import deala as de
from deala import deala_io
deala_io_instance = deala_io()

# %% [markdown]
# ## 1.2 Set up project
#
# <p style="font-size:12px">
# The following aspects are defined in this substep:
# </p>
#
# <ol style="font-size:12px; padding-left: 20px">
#   <li><code>PROJECT_NAME</code>: Define the project name of your project! Default: <code>Pan_Production</code>.</li><br><br>
#
#   <li><code>ECOINVENT_PATH</code>: Define the path to your unzipped ecoinvent database!</li><br><br>
#
#   <li><code>ECOINVENT_VERSION</code>: Define the version (number) of your ecoinvent version!</li><br><br>
#
#   <li><code>NAME_ECOINVENT_DB</code>: Define how the ecoinvent database will be named in your project. For automatic data generation, the name of your base scenario must be taken into account!</li><br><br>
#
#   <li><code>NAME_ECOINVENT_DB_SHORT</code>: Define how the ecoinvent database will be named in your project without the considered base scenario!</li><br><br>
#
#   <li><code>PREMISE_KEY_PATH</code>: Define the file path to the file containing the key for Premise, which is required to manipulate the ecoinvent database!</li><br><br>
#
#   <li><code>FP_INPUT_PATH</code>: Define the path to your excel file representing the intermediate system for material inputs! Ingnore this line if no intermediate system for input materials is required!</li><br><br>
#
#   <li><code>FP_OUTPUT_PATH</code>: Define the path to your excel file representing the intermediate system for outputs! Ingnore this line if no intermediate system for output materials is required!</li><br><br>
#
#   <li><code>FP_NON_STICK_CONVENTIONAL</code>: Define the path to your excel file representing the activities of your foreground system! Here, three pans will be distinguished. Ingnore this line if no further foreground processes have to be included!</li><br><br>
#
#   <li><code>FP_TRADE_DATABASE</code>: Define the path to the trade database, which is required to run the regiopremise code. You can download the database here: <a href="https://zenodo.org/records/15474318" target="_blank">Trade DB</a>.</li><br><br>
#
#   <li><code>dict_countries</code>: Define the countries to be considered in the intermediate and foreground systems as a dictionary. This case study includes China, France, Germany, India, Italy, USA, Turkey, Netherlands, Poland, Belgium, and Czechia, in addition to global activities (used as default).</li><br><br>
#
#   <li><code>dict_scenarios</code>: Define the scenarios to be considered in the case study, including time period and scenario name, as a dictionary. Three scenarios are used in this case: the Status Quo (2024) and two future scenario (2030) based on the REMIND-SSP2-base and REMIND-SSP2-PkBud1150_2030 scenarios. The key nomenclature is selected for automatic regionalization and linking.</li><br><br>
#
#   <li><code>last_process_name</code>: Define the last product of your production process. For example the activity of the final product you can sell on the market. This definition is required to calculate the price of a end product. Use the name of the reference product of for this. In this example the name of the reference product is 'Attaching handle'</li><br><br>
#
#   <li><code>reference_flow</code>: Define the reference flow(s) for the case study. In this assessment, the reference flow is one pan.</li><br><br>
#
#   <li><code>cutoff_regiopremise</code>: Define the cutoff for the regiopremise process. In this case study, we assume a default value of 0.8</li><br><br>
#
#   <li><code>base_year</code>: Define the base year for the economic assessment, meaning all economic values are normalized to this year. In this assessment, the base year is 2023.</li><br><br>
#
#   <li><code>price_calculation_method</code>: Define which method must be used for the price calculation. You can select between real and nominal. In this assessment, real prices are calculated.</li><br><br>
#
#   <li><code>method_calculation_real_prices</code>: Define which method must be used if you are calculating real prices (how the growth rate is considered). You can select between geometric average (geo) and a reggression method (reg). In this assessment, reg ist used.</li><br><br>
#
#   <li><code>percentage_rate_buildings</code>: Define the percentage rate for building investments to be considered in the economic assessment (depreciation). In this assessment, a rate of 3% is used.</li><br><br>
#
#   <li><code>percentage_rate_machinery</code>: Define the percentage rate for machinery investments to be considered in the economic assessment (depreciation). In this assessment, a rate of 5% is used.</li><br><br>
#
#   <li><code>percentage_rate_insurance</code>: Define the percentage rate for insurance costs based on investments in machinery and buildings. In this assessment, a rate of 1% is used.</li><br><br>
#
#   <li><code>dict_interest</code>: Define the national interest rates per country as a dictionary. These rates are used in the economic assessment for investments in machinery and buildings.</li><br><br>
#
#   <li><code>dict_taxes</code>: Define the profit tax rates per country. The tax rates are based on data from <a href="https://taxsummaries.pwc.com/" target="_blank">PwC</a>.</li><br><br>
#
#   <li><code>percentage_rate_administration</code>: Define the percentage rate for administration costs based on personnel costs. In this assessment, a rate of 25% is used.</li><br><br>
#
#   <li><code>percentage_rate_research_development</code>: Define the percentage rate for research and development based on total costs. In this assessment, a rate of 2% is used.</li><br><br>
#
#   <li><code>percentage_rate_warranty</code>: Define the percentage rate for warranty costs based on total costs. In this assessment, a rate of 3% is used.</li><br><br>
#
#   <li><code>percentage_margin</code>: Define the profit margin of the pan producer used to calculate the final product price for each country.</li><br><br>
#
#   <li><code>list_end_products</code>: Define a list of end products (e.g., stainless steel pan and non-stick pan) required for the calculation.</li><br><br>
#
#   <li><code>set_current</code>: Loads the project based on your defined project name.</li><br><br>
#
#   <li><code>directory_deala</code>: Specifies the path to the DEALA package to access all required files.</li><br><br>
#
#   <li><code>current_directory</code>: Specifies the directory where this notebook is stored.</li><br><br>
#
#   <li><code>repository_main_path</code>: Specifies the path to the main repository.</li><br><br>
#
#   <li><code>FP_mapping</code>: Specifies the file path to the TOML file used for mapping life cycle impact assessment methods, energy, and transport data sets to predefined settings.</li><br><br>
#
#   <li><code>FP_transport_matrices</code>, <code>FP_transport_matrices_land</code>, <code>FP_transport_matrices_sea</code>, <code>FP_transport_matrices_harbor</code>: Specifies the file paths to the transport matrices required for the calculations. With DEALA, transport distances between capital cities of various countries can be considered.</li><br><br>
#
#   <li><code>FP_energy_database</code>: Specifies the file paths to the excel file representing the intermediate system for Energy.</li><br><br>

# %% [markdown]
# <p style="font-size:28px">
# Please change the information depending on your paths and the data used!
# </p>

# %%
# project name
PROJECT_NAME = 'Pan_production_regiopremise'

# Ecoinvent datasets folder
ECOINVENT_PATH = Path.home() / "Desktop" / 'ecoinvent 3.9.1_cutoff_ecoSpold02' / 'datasets'
ECOINVENT_VERSION = '3.9.1'

NAME_ECOINVENT_DB = f'ecoinvent_{ECOINVENT_VERSION}-cutoff_remind_SSP2-Base_ecoSpold02'
NAME_ECOINVENT_DB_SHORT = f'ecoinvent_{ECOINVENT_VERSION}-cutoff_'

PREMISE_KEY_PATH = Path.home() / "Desktop" / "key_premise.toml"

# Definition of filepath to input materials
FP_INPUT_PATH = Path(Path().resolve().parent, "files", "Excel_datasets", "pan_production", "input_materials_regioinvent.xlsx")

# Definition of filepath to output materials
FP_OUTPUT_PATH = Path(Path().resolve().parent, "files", "Excel_datasets", "pan_production", "output_materials.xlsx")

# Definition of filepath to non-stick pan (conventional) production dataset
FP_NON_STICK_CONVENTIONAL = Path(Path().resolve().parent, "files", "Excel_datasets", "pan_production", "Excel_BW2_non_stick_conventional.xlsx")

# Definition of filepath to trade databsae for the regiopremise database (you have to download it here: https://zenodo.org/records/15474318)
FP_TRADE_DATABASE = Path.home() / "Downloads" / "trade_data.db"

# %% [markdown]
# <p style="font-size:28px">
# Please define the general scope of your case study!
# </p>

# %%
# definition of countries producing the pans
dict_countries={

    'China': 'CN',
    'France': 'FR',
    'Germany': 'DE',
    'India': 'IN',
    'Italy': 'IT',
    'United States of America': 'US',
    'Turkey': 'TR',
    'Netherlands': 'NL',
    'Poland': 'PL',
    'Belgium': 'BE',
    'Czechia': 'CZ',
}

# Definition of the scenarios required for the case study in a dict
dict_scenarios={
    'remind_SSP2-Base_ecoSpold02':2024,
    'remind_SSP2-PkBudg1150_2030':2030,
    'remind_SSP2-Base_2030':2030
}

# Definition of name of last process
last_process_name = 'Attaching handle'

# Definition of reference flows
reference_flow= 1

# Definition of the cutoff for the regiopremise database
cutoff_regiopremise=0.8

# %% [markdown]
# <p style="font-size:28px">
# Please define your assumptions for the economic assessment with DEALA!
# </p>

# %%
# Definition of the base year for normalization of costs
base_year = 2023

# Definition of price calculation method
price_calculation_method= "real"

# Definition of method for calculation of real prices
method_calculation_real_prices= "reg"

#definition of the percentage rate for maintenance and repair 
percentage_rate_buildings= 'maintenance and repair - 3 percent'
percentage_rate_machinery= 'maintenance and repair - 5 percent'

#definition of the percentage rate for insurance
percentage_rate_insurance= 'insurance - 1 percent'

# #definition of the percentage rate for interest
dict_interest={
    'GLO':'interest (internal) - 5 percent',  
    'CN':'interest (internal) - 3.5 percent',       
    'DE':'interest (internal) - 4 percent',            
    'FR':'interest (internal) - 4 percent',     
    'IN':'interest (internal) - 6.5 percent',
    'IT':'interest (internal) - 4 percent',                 
    'US':'interest (internal) - 5.25 percent',
    'TR':'interest (internal) - 20.75 percent',
    'NL':'interest (internal) - 4 percent',
    'PL':'interest (internal) - 6.5 percent',
    'BE':'interest (internal) - 4 percent',
    'CZ':'interest (internal) - 7 percent',
}

# definition of the percentage rate for taxes
dict_taxes={
    'GLO':'taxes - 20.6 percent',
    'CN':'taxes - 15 percent',          #https://taxsummaries.pwc.com/china/corporate/taxes-on-corporate-income
    'DE':'taxes - 15.8 percent',        #https://taxsummaries.pwc.com/germany/corporate/taxes-on-corporate-income
    'FR':'taxes - 25 percent',          #https://taxsummaries.pwc.com/france/corporate/taxes-on-corporate-income
    'IN':'taxes - 30 percent',          #https://taxsummaries.pwc.com/india/corporate/taxes-on-corporate-income
    'IT':'taxes - 24 percent',          #https://taxsummaries.pwc.com/italy/corporate/taxes-on-corporate-income
    'US':'taxes - 21 percent',          #https://taxsummaries.pwc.com/united-states/corporate/taxes-on-corporate-income
    'TR':'taxes - 25 percent',          #https://taxsummaries.pwc.com/turkey/corporate/taxes-on-corporate-income
    'NL':'taxes - 25.8 percent',        #https://taxsummaries.pwc.com/netherlands/corporate/taxes-on-corporate-income
    'PL':'taxes - 19 percent',          #https://taxsummaries.pwc.com/poland/corporate/taxes-on-corporate-income
    'BE':'taxes - 25 percent',          #https://taxsummaries.pwc.com/belgium/corporate/taxes-on-corporate-income
    'CZ':'taxes - 19 percent',          #https://taxsummaries.pwc.com/czech-republic/corporate/taxes-on-corporate-income
}

#definition of the percentage rate for administration
percentage_rate_administration= 'administration - 25 percent'

#definition of the percentage rate for research and development
percentage_rate_research_development= 'research and development - 2 percent'

#definition of the percentage rate for warranty
percentage_rate_warranty= 'warranty - 3 percent'

#definition of the percentage rate for margin on pans
percentage_margin= 0.5      # 50 percent margin on the production costs

#definition of the end products
list_end_products = ['Non-stick pan']

# %% [markdown]
# <p style="font-size:28px">
# The default paths and the project are loaded. Normally, you do not need to change anything here.</p>

# %%
#Create/load project
bw.projects.set_current(PROJECT_NAME)

# Get the directory of the deala package
directory_deala = Path(de.__file__).parent

# Get the current working directory
current_directory = Path().resolve()

# Determine the main path of the repository
repository_main_path = current_directory.parent

# filepath to mapping file
FP_mapping = Path(directory_deala, 'files', "linking", "mappings.toml")

# filepath to transport matrices
FP_transport_matrices = Path(repository_main_path, 'files', "linking", "distance_matrix.xlsx")

# filepath to transport matrices
FP_transport_matrices_land = Path(repository_main_path, 'files', "linking", "distance_matrix_land.xlsx")

# filepath to transport matrices
FP_transport_matrices_sea = Path(repository_main_path, 'files', "linking", "distance_matrix_sea.xlsx")

# filepath to transport matrices
FP_transport_matrices_land_harbor = Path(repository_main_path, 'files', "linking", "distance_matrix_land_harbor.xlsx")

# Definition of filepath to Energy database
FP_energy_database = Path(directory_deala, "files", "Excel_datasets", "DB_Energy.xlsx")

#Definition of filepath to PPP database
FP_PPP_database = Path(repository_main_path, "files", "linking", "PPP_countries.xlsx")

# %% [markdown]
# # 2. Import background system
#
# <p style="font-size:12px">
# The background system consists of five external databases that must be imported into the initialized project. These databases are:
# </p>
#
# <ul style="font-size:12px; padding-left: 20px">
#   <li>biosphere database</li>
#   <li>Ecoinvent database</li>
#   <li>Premise database</li>
#   <li>Regiopremose database</li>
#   <li>DEALA database</li>
# </ul>
#
# <p style="font-size:12px">
# The premise/regiopremise databases are created for the defined scenarios to reflect temporal differences.
# </p>
#
# <p style="font-size:12px">
# Additionally, life cycle impact assessment (LCIA) methods for both environmental and economic assessments are imported, along with the required databases for elementary flows (<code>biosphere</code> and <code>marketsphere</code>).
# </p>

# %% [markdown]
# ## 2.1 Import biosphere database and environmental impact categories

# %%
# Install biosphere database and impact assessment methods
bw.bw2setup()
# Out:
# Creating default biosphere
#
# Applying strategy: normalize_units
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: ensure_categories_are_tuples
# Applied 3 strategies in 0.00 seconds
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 17:06:10
#   Finished: 01/08/2026 17:06:10
#   Total time elapsed: 00:00:00
#   CPU %: 100.00
#   Memory %: 0.19
# Created database: biosphere3
# Creating default LCIA methods
#
# Wrote 762 LCIA methods with 227223 characterization factors
# Creating core data migrations

# %% [markdown]
# ## 2.2 Import ecoinvent

# %%
# Install ecoinvent database
if NAME_ECOINVENT_DB in bw.databases:
    print("Database has already been imported.")
else:
    fpei39cut = ECOINVENT_PATH
    ei39cut = bw.SingleOutputEcospold2Importer(
        fpei39cut, NAME_ECOINVENT_DB
    )
    ei39cut
    ei39cut.apply_strategies()
    ei39cut.statistics()
    ei39cut.write_database()  # writes database to Brightway2 project
# Out:
# Extracting XML data from 21238 datasets
# Extracted 21238 datasets in 10.89 seconds
# Applying strategy: normalize_units
# Applying strategy: update_ecoinvent_locations
# Applying strategy: remove_zero_amount_coproducts
# Applying strategy: remove_zero_amount_inputs_with_no_activity
# Applying strategy: remove_unnamed_parameters
# Applying strategy: es2_assign_only_product_with_amount_as_reference_product
# Applying strategy: assign_single_product_as_activity
# Applying strategy: create_composite_code
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: fix_ecoinvent_flows_pre35
# Applying strategy: drop_temporary_outdated_biosphere_flows
# Applying strategy: link_biosphere_by_flow_uuid
# Applying strategy: link_internal_technosphere_by_composite_code
# Applying strategy: delete_exchanges_missing_activity
# Applying strategy: delete_ghost_exchanges
# Applying strategy: remove_uncertainty_from_negative_loss_exchanges
# Applying strategy: fix_unreasonably_high_lognormal_uncertainties
# Applying strategy: convert_activity_parameters_to_list
# Applying strategy: add_cpc_classification_from_single_reference_product
# Applying strategy: delete_none_synonyms
# Applying strategy: set_lognormal_loc_value
# Applied 21 strategies in 3.24 seconds
# 21238 datasets
# 674593 exchanges
# 0 unlinked exchanges
#
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 17:06:36
#   Finished: 01/08/2026 17:06:50
#   Total time elapsed: 00:00:13
#   CPU %: 99.90
#   Memory %: 1.68
# Created database: ecoinvent_3.9.1-cutoff_remind_SSP2-Base_ecoSpold02

# %% [markdown]
# ## 2.3 Import Premise databases

# %%
# Definition of the key for the premise database
config = toml.load(PREMISE_KEY_PATH)
key_premise=config['auth']['key_premise']
deala_io.create_premise_databases(dict_scenarios, key_premise, "ecospold", ECOINVENT_PATH, ECOINVENT_VERSION, overwrite=False)
# Out:
# Database 'ecoinvent_3.9.1-cutoff_remind_SSP2-Base_ecoSpold02' already exists. Skipping creation.
# Cache folder cleared!
# premise v.(2, 2, 9)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# +--------------------------------+----------------------------------+
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# +--------------------------------+----------------------------------+
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_source_db_uncertainty=True), keep_imports_uncertainty=True)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
# - Extracting source database
# Cannot find cached database. Will create one now for next time...
# Warning: No valid output stream.
# Title: Extracting ecospold2 files:
#   Started: 01/08/2026 17:07:27
#   Finished: 01/08/2026 17:08:28
#   Total time elapsed: 00:01:00
#   CPU %: 100.00
#   Memory %: 3.08
# Extracted 21238 datasets in 60.99 seconds
# Applying strategy: normalize_units
# Applying strategy: update_ecoinvent_locations
# Applying strategy: remove_zero_amount_coproducts
# Applying strategy: remove_zero_amount_inputs_with_no_activity
# Applying strategy: remove_unnamed_parameters
# Applying strategy: es2_assign_only_product_with_amount_as_reference_product
# Applying strategy: assign_single_product_as_activity
# Applying strategy: create_composite_code
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: fix_ecoinvent_flows_pre35
# Applying strategy: drop_temporary_outdated_biosphere_flows
# Applying strategy: link_biosphere_by_flow_uuid
# Applying strategy: link_internal_technosphere_by_composite_code
# Applying strategy: delete_exchanges_missing_activity
# Applying strategy: delete_ghost_exchanges
# Applying strategy: remove_uncertainty_from_negative_loss_exchanges
# Applying strategy: fix_unreasonably_high_lognormal_uncertainties
# Applying strategy: convert_activity_parameters_to_list
# Applying strategy: add_cpc_classification_from_single_reference_product
# Applying strategy: delete_none_synonyms
# Applying strategy: set_lognormal_loc_value
# Applied 21 strategies in 3.16 seconds
# Set missing location of datasets to global scope.
# Set missing location of production exchanges to scope of dataset.
# Correct missing location of technosphere exchanges.
# Correct missing flow categories for biosphere exchanges
# Remove empty exchanges.
# Remove uncertainty data.
# - Extracting inventories
# Cannot find cached inventories. Will create them now for next time...
# Importing default inventories...
#
# Extracted 1 worksheets in 0.07 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 4 worksheets in 0.13 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 7 worksheets in 0.02 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.03 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 2 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 3.75 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-------------+
# |              Name              |       Reference product        | Location |     File    |
# +--------------------------------+--------------------------------+----------+-------------+
# | fluorspar production, 97% puri |     fluorspar, 97% purity      |   GLO    | lci-PV.xlsx |
# | metallization paste production | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, front sid |   RER    | lci-PV.xlsx |
# | photovoltaic module production | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic module production | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic panel factory con |   photovoltaic panel factory   |   GLO    | lci-PV.xlsx |
# |  polyvinylfluoride production  |       polyvinylfluoride        |    US    | lci-PV.xlsx |
# | polyvinylfluoride production,  | polyvinylfluoride, dispersion  |    US    | lci-PV.xlsx |
# | polyvinylfluoride, film produc |    polyvinylfluoride, film     |    US    | lci-PV.xlsx |
# | silicon production, metallurgi |  silicon, metallurgical grade  |    NO    | lci-PV.xlsx |
# |   vinyl fluoride production    |         vinyl fluoride         |    US    | lci-PV.xlsx |
# |   wafer factory construction   |         wafer factory          |    DE    | lci-PV.xlsx |
# +--------------------------------+--------------------------------+----------+-------------+
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.04 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+--------------------------------+
# |              Name              |       Reference product        | Location |              File              |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# | carbon dioxide, captured at ce | carbon dioxide, captured and r |   RER    | lci-synfuels-from-methanol-fro |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.00 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.00 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.00 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+--------------------------------+
# |              Name              |       Reference product        | Location |              File              |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# | methanol production facility,  | methanol production facility,  |   RER    | lci-synfuels-from-methanol-fro |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.00 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 5 worksheets in 0.11 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.00 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.06 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.03 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Remove uncertainty data.
# Extracted 19 worksheets in 0.24 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.17 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.13 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.61 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.02 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.00 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.01 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Extracted 1 worksheets in 0.00 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Remove uncertainty data.
# Data cached. It is advised to restart your workflow at this point.
# This allows premise to use the cached data instead, which results in
# a faster workflow.
# - Fetching IAM data
# Done!
# Processing scenarios for all sectors: 100%|█| 1/1 [01:12<00:00, 72.51s
# Done!
#
# Write new database(s) to Brightway.
# Running all checks...
# Minor anomalies found: check the change report.
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 17:10:28
#   Finished: 01/08/2026 17:10:42
#   Total time elapsed: 00:00:14
#   CPU %: 98.20
#   Memory %: 6.60
# Created database: ecoinvent_3.9.1-cutoff_remind_SSP2-PkBudg1150_2030
# Generate scenario report.
# Report saved under /Users/popien/Desktop/development/DEALA/deala/notebooks/export/scenario_report.
# Generate change report.
# Report saved under /Users/popien/Desktop/development/DEALA/deala/notebooks.
# premise v.(2, 2, 9)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# +--------------------------------+----------------------------------+
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# +--------------------------------+----------------------------------+
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_source_db_uncertainty=True), keep_imports_uncertainty=True)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
# - Extracting source database
# - Extracting inventories
# - Fetching IAM data
# Done!
# Processing scenarios for all sectors: 100%|█| 1/1 [01:09<00:00, 69.85s
# Done!
#
# Write new database(s) to Brightway.
# Running all checks...
# Minor anomalies found: check the change report.
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 17:13:21
#   Finished: 01/08/2026 17:13:35
#   Total time elapsed: 00:00:14
#   CPU %: 97.30
#   Memory %: 9.53
# Created database: ecoinvent_3.9.1-cutoff_remind_SSP2-Base_2030
# Generate scenario report.
# Report saved under /Users/popien/Desktop/development/DEALA/deala/notebooks/export/scenario_report.
# Generate change report.
# Report saved under /Users/popien/Desktop/development/DEALA/deala/notebooks.

# %% [markdown]
# ## 2.4 Regionalization of ecoinvent databases using regiopremise
#
# The Python package regiopremise is used to regionalize the different ecoinvent databases (as defined in dict_scenario).

# %%
for scenario in dict_scenarios:
    regio = regioinvent.Regiopremise(
        bw_project_name=PROJECT_NAME,
        premise_database_name=NAME_ECOINVENT_DB_SHORT+scenario,
        ecoinvent_database_name=NAME_ECOINVENT_DB,
        ecoinvent_version=ECOINVENT_VERSION,
    )

    regio.fix_iam_location_codes()
    regio.spatialize_my_premise()
    regio.import_fully_regionalized_impact_method(lcia_method='all')
    regio.regionalize_premise_with_trade(
        trade_database_path=FP_TRADE_DATABASE,
        regioinvent_database_name='regioinvent_'+scenario,
        cutoff=cutoff_regiopremise,
    )
# Out:
# 2026-01-08 17:14:29,432 - Regiopremise - INFO - Creating spatialized biosphere flows...
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 17:14:30
#   Finished: 01/08/2026 17:14:32
#   Total time elapsed: 00:00:01
#   CPU %: 99.80
#   Memory %: 7.34
# 2026-01-08 17:16:13,456 - Regiopremise - INFO - Extracting premise to wurst...
# Getting activity data
# 100%|██████████| 21238/21238 [00:00<00:00, 364155.51it/s]
# Adding exchange data to activities
# 100%|██████████| 674593/674593 [00:14<00:00, 47984.30it/s]
# Filling out exchange data
# 100%|██████████| 21238/21238 [00:00<00:00, 29514.88it/s]
# 2026-01-08 17:16:38,087 - Regiopremise - INFO - Spatializing premise...
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 17:16:39
#   Finished: 01/08/2026 17:16:50
#   Total time elapsed: 00:00:10
#   CPU %: 100.00
#   Memory %: 8.89
# 2026-01-08 17:17:33,850 - Regiopremise - INFO - Importing all available fully regionalized lcia methods for ecoinvent3.9.
# 2026-01-08 17:17:56,327 - Regiopremise - INFO - Extracting and formatting trade data...
# 2026-01-08 17:18:04,697 - Regiopremise - INFO - Regionalizing main inputs of internationally-traded products of premise...
# 100%|██████████| 1969/1969 [01:25<00:00, 23.05it/s]
# 2026-01-08 17:19:30,141 - Regiopremise - INFO - Regionalizing main inputs of non-internationally traded processes of premise...
# 100%|██████████| 78/78 [04:40<00:00,  3.60s/it]
# 2026-01-08 17:24:10,823 - Regiopremise - INFO - Creating consumption markets for internationally-traded products...
# 100%|██████████| 1969/1969 [11:36<00:00,  2.83it/s]
# 2026-01-08 17:35:47,101 - Regiopremise - INFO - Link regioinvent processes to each other...
# 2026-01-08 17:35:54,663 - Regiopremise - INFO - Regionalizing the elementary flows of the regiopremise database...
# 2026-01-08 17:36:04,946 - Regiopremise - INFO - Write regioinvent database to brightway...
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 17:36:06
#   Finished: 01/08/2026 17:36:43
#   Total time elapsed: 00:00:37
#   CPU %: 98.70
#   Memory %: 9.70
# 2026-01-08 17:38:01,354 - Regiopremise - INFO - Connecting premise to regioinvent processes...
# 2026-01-08 17:41:18,074 - Regiopremise - INFO - biosphere3_spatialized_flows already exists in this project.
# 2026-01-08 17:41:18,075 - Regiopremise - INFO - Extracting premise to wurst...
# Getting activity data
# 100%|██████████| 28569/28569 [00:00<00:00, 346113.95it/s]
# Adding exchange data to activities
# 100%|██████████| 839817/839817 [00:16<00:00, 51661.95it/s]
# Filling out exchange data
# 100%|██████████| 28569/28569 [00:00<00:00, 36784.16it/s]
# 2026-01-08 17:41:37,516 - Regiopremise - INFO - Spatializing premise...
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 17:41:40
#   Finished: 01/08/2026 17:42:01
#   Total time elapsed: 00:00:20
#   CPU %: 100.00
#   Memory %: 9.83
# 2026-01-08 17:43:04,251 - Regiopremise - INFO - Importing all available fully regionalized lcia methods for ecoinvent3.9.
# 2026-01-08 17:44:05,891 - Regiopremise - INFO - Extracting and formatting trade data...
# 2026-01-08 17:44:13,428 - Regiopremise - INFO - Regionalizing main inputs of internationally-traded products of premise...
# 100%|██████████| 1969/1969 [02:01<00:00, 16.22it/s]
# 2026-01-08 17:46:14,841 - Regiopremise - INFO - Regionalizing main inputs of non-internationally traded processes of premise...
# 100%|██████████| 78/78 [07:57<00:00,  6.12s/it]
# 2026-01-08 17:54:12,381 - Regiopremise - INFO - Creating consumption markets for internationally-traded products...
# 100%|██████████| 1969/1969 [11:40<00:00,  2.81it/s]
# 2026-01-08 18:05:53,021 - Regiopremise - INFO - Link regioinvent processes to each other...
# 2026-01-08 18:06:00,341 - Regiopremise - INFO - Regionalizing the elementary flows of the regiopremise database...
# 2026-01-08 18:06:01,654 - Regiopremise - INFO - Write regioinvent database to brightway...
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:06:04
#   Finished: 01/08/2026 18:06:49
#   Total time elapsed: 00:00:45
#   CPU %: 98.30
#   Memory %: 10.05
# 2026-01-08 18:08:16,586 - Regiopremise - INFO - Connecting premise to regioinvent processes...
# 2026-01-08 18:11:41,034 - Regiopremise - INFO - biosphere3_spatialized_flows already exists in this project.
# 2026-01-08 18:11:41,035 - Regiopremise - INFO - Extracting premise to wurst...
# Getting activity data
# 100%|██████████| 28562/28562 [00:00<00:00, 363186.25it/s]
# Adding exchange data to activities
# 100%|██████████| 839139/839139 [00:24<00:00, 33830.06it/s]
# Filling out exchange data
# 100%|██████████| 28562/28562 [00:00<00:00, 36669.14it/s]
# 2026-01-08 18:12:09,000 - Regiopremise - INFO - Spatializing premise...
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:12:13
#   Finished: 01/08/2026 18:12:25
#   Total time elapsed: 00:00:12
#   CPU %: 100.00
#   Memory %: 9.92
# 2026-01-08 18:13:39,423 - Regiopremise - INFO - Importing all available fully regionalized lcia methods for ecoinvent3.9.
# 2026-01-08 18:14:44,854 - Regiopremise - INFO - Extracting and formatting trade data...
# 2026-01-08 18:14:52,416 - Regiopremise - INFO - Regionalizing main inputs of internationally-traded products of premise...
# 100%|██████████| 1969/1969 [02:01<00:00, 16.26it/s]
# 2026-01-08 18:16:53,545 - Regiopremise - INFO - Regionalizing main inputs of non-internationally traded processes of premise...
# 100%|██████████| 78/78 [08:02<00:00,  6.19s/it]
# 2026-01-08 18:24:56,463 - Regiopremise - INFO - Creating consumption markets for internationally-traded products...
# 100%|██████████| 1969/1969 [11:31<00:00,  2.85it/s]
# 2026-01-08 18:36:28,083 - Regiopremise - INFO - Link regioinvent processes to each other...
# 2026-01-08 18:36:35,215 - Regiopremise - INFO - Regionalizing the elementary flows of the regiopremise database...
# 2026-01-08 18:36:36,495 - Regiopremise - INFO - Write regioinvent database to brightway...
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:36:40
#   Finished: 01/08/2026 18:37:23
#   Total time elapsed: 00:00:43
#   CPU %: 100.00
#   Memory %: 10.15
# 2026-01-08 18:38:59,161 - Regiopremise - INFO - Connecting premise to regioinvent processes...

# %% [markdown]
# ## 2.5 Import DEALA
#
# To import the marketsphere and the DEALA databases, three steps must be performed:
# </p>
#
# <ol style="font-size:12px; padding-left: 20px">
#   <li>
#     <code>deala_setup</code>: This function loads the marketsphere database, including all required marketsphere flows to calculate economic impacts, as well as life cycle impact assessment methods. In this assessment, three different characterization models from DEALA can be selected for the calculations. This step is comparable to <code>bw.setup()</code>.
#   </li><br><br>
#
#   <li>
#     <code>import_deala_activities</code>: In this step, predefined datasets representing prices for personnel, construction, materials, etc. are used to create the corresponding DEALA activities in the database. This includes consideration of the <code>base_year</code> and the different <code>scenarios</code> to generate scenario-dependent databases. The respective data sheets are stored in the DEALA directory. Additionally, it must be specified whether to use nominal or real prices, and how future prices should be approximated—either by regression analysis or geometric average. Besides, you can decide if the prices should be regionalized. In this example, this is based on the Purchasing power parities (PPP) for the year 2023 as stated by the OECD.
#   </li><br><br>
#
#   <li>
#     <code>create_default_DEALA_activities</code>: In this final step, default DEALA activities are added to the databases. These are activities for which no specific price or economic value is known in advance, as they depend on factors such as investments, total costs, or CO₂ emissions.
#   </li>
# </ol>

# %%
# Install the DEALA impact assessment method and marketsphere database
deala_io_instance.deala_setup(overwrite=True)
# Out:
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:42:11
#   Finished: 01/08/2026 18:42:11
#   Total time elapsed: 00:00:00
#   CPU %: 99.20
#   Memory %: 10.15
# 100%|██████████| 73/73 [00:18<00:00,  3.95it/s]
# The marketsphere database and DEALA impact assessment methods are successfully imported.

# %%
#create deala activities that are linked to cost data
deala_io_instance.import_DEALA_activities_fast(base_year, dict_scenarios, directory_deala, price_calculation=price_calculation_method, method_calc_r=method_calculation_real_prices, modus=None)
deala_io_instance.import_PPP_DEALA_activities(FP_PPP_database)
# Out:
# [INFO] Processing scenario: remind_SSP2-Base_ecoSpold02
# Files for remind_SSP2-Base_ecoSpold02: 100%|██████████| 8/8 [00:38<00:00,  4.75s/it]
# [INFO] Writing 5832 activities to database DEALA_activities_remind_SSP2-Base_ecoSpold02 ...
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:43:53
#   Finished: 01/08/2026 18:43:53
#   Total time elapsed: 00:00:00
#   CPU %: 99.90
#   Memory %: 10.15
# [INFO] Finished writing DEALA_activities_remind_SSP2-Base_ecoSpold02
#
# [DEBUG] Scenario remind_SSP2-Base_ecoSpold02:
#   Total datasets read:        3578
#   Skipped (elasticity):       0
#   Skipped (deflator):         0
#   Skipped (GDP missing):      0
#   Skipped (marketsphere):     0
#   Successfully prepared:      5832
#   --> Written to DB:          5832
#
# [INFO] Processing scenario: remind_SSP2-PkBudg1150_2030
# Files for remind_SSP2-PkBudg1150_2030: 100%|██████████| 8/8 [00:29<00:00,  3.72s/it]
# [INFO] Writing 5832 activities to database DEALA_activities_remind_SSP2-PkBudg1150_2030 ...
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:45:11
#   Finished: 01/08/2026 18:45:11
#   Total time elapsed: 00:00:00
#   CPU %: 100.10
#   Memory %: 10.15
# [INFO] Finished writing DEALA_activities_remind_SSP2-PkBudg1150_2030
#
# [DEBUG] Scenario remind_SSP2-PkBudg1150_2030:
#   Total datasets read:        3578
#   Skipped (elasticity):       0
#   Skipped (deflator):         0
#   Skipped (GDP missing):      0
#   Skipped (marketsphere):     0
#   Successfully prepared:      5832
#   --> Written to DB:          5832
#
# [INFO] Processing scenario: remind_SSP2-Base_2030
# Files for remind_SSP2-Base_2030: 100%|██████████| 8/8 [00:29<00:00,  3.72s/it]
# [INFO] Writing 5832 activities to database DEALA_activities_remind_SSP2-Base_2030 ...
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:46:29
#   Finished: 01/08/2026 18:46:29
#   Total time elapsed: 00:00:00
#   CPU %: 99.90
#   Memory %: 10.15
# [INFO] Finished writing DEALA_activities_remind_SSP2-Base_2030
#
# [DEBUG] Scenario remind_SSP2-Base_2030:
#   Total datasets read:        3578
#   Skipped (elasticity):       0
#   Skipped (deflator):         0
#   Skipped (GDP missing):      0
#   Skipped (marketsphere):     0
#   Successfully prepared:      5832
#   --> Written to DB:          5832
#
# [INFO] Loaded PPP data for 195 countries (year 2023).
#
# [INFO] PPP regionalizing DEALA_activities_remind_SSP2-Base_ecoSpold02 …
#   → Found 29 PPP base activities
# DEALA_activities_remind_SSP2-Base_ecoSpold02: 100%|██████████| 29/29 [00:00<00:00, 265.76it/s]
# [INFO] PPP regionalizing DEALA_activities_remind_SSP2-PkBudg1150_2030 …
#   → Found 29 PPP base activities
# DEALA_activities_remind_SSP2-PkBudg1150_2030: 100%|██████████| 29/29 [00:00<00:00, 273.07it/s]
# [INFO] PPP regionalizing DEALA_activities_remind_SSP2-Base_2030 …
#   → Found 29 PPP base activities
# DEALA_activities_remind_SSP2-Base_2030: 100%|██████████| 29/29 [00:00<00:00, 282.52it/s]
# [INFO] Added 16965 new mappings.

# %%
#create remaining DEALA activities

deala_io_instance.create_default_DEALA_activities_fast('DEALA_activities_', dict_scenarios, overwrite=False)
# Out:
# [INFO] Creating GLO DEALA activities for DEALA_activities_remind_SSP2-Base_ecoSpold02 …
# remind_SSP2-Base_ecoSpold02: 100%|██████████| 12/12 [00:00<00:00, 442.38it/s]
# ✅ Added 1091 GLO activities to DEALA_activities_remind_SSP2-Base_ecoSpold02 in 8.4s
#
# [INFO] Creating GLO DEALA activities for DEALA_activities_remind_SSP2-PkBudg1150_2030 …
# remind_SSP2-PkBudg1150_2030: 100%|██████████| 12/12 [00:00<00:00, 474.01it/s]
# ✅ Added 1091 GLO activities to DEALA_activities_remind_SSP2-PkBudg1150_2030 in 8.4s
#
# [INFO] Creating GLO DEALA activities for DEALA_activities_remind_SSP2-Base_2030 …
# remind_SSP2-Base_2030: 100%|██████████| 12/12 [00:00<00:00, 480.75it/s]
# ✅ Added 1091 GLO activities to DEALA_activities_remind_SSP2-Base_2030 in 8.4s
#
# 🧩 Updating Brightway mapping for new DEALA default activities …
# ✅ Added 3273 mappings.
#
# ⚙️ Running db.process() for each DEALA database …

# %% [markdown]
# # 3. Import intermediate system
#
# <p style="font-size:12px">
# The intermediate system consists of four databases that must be imported into the initialized project. These databases are:
# </p>
#
# <ul style="font-size:12px; padding-left: 20px">
#   <li>Energy database</li>
#   <li>Transport database</li>
#   <li>Input materials database</li>
#   <li>Output materials database</li>
# </ul>
#
# <p style="font-size:12px">
# These databases contain activities that are combinations of exchanges from the DEALA and ecoinvent databases.
# </p>
#
# <p style="font-size:12px">
# The energy database includes datasets for electricity and heat from gas, differentiated by household and non-household consumers, various countries, and different consumption levels.
# </p>
#
# <p style="font-size:12px">
# The transport database includes datasets representing distances and transport between capital cities. Two transport modes are considered: container ship and lorry.
# </p>
#
# <p style="font-size:12px">
# The input materials database includes all materials required for pan production.
# </p>
#
# <p style="font-size:12px">
# The output materials database includes all co-products and waste streams that must be further processed.
# </p>

# %% [markdown]
# ## 3.1 Import energy databases

# %%
# allocation of datasets in Energy database to types in DEALA Activities to create regionalized activities
dict_energy=toml.load(FP_mapping)["energy"]

# Delete activities from energy-related ecoinvent databases to reduce vacuuming time

list_databases = []

# Step 1: Retrieve a list of all existing databases in Brightway2
for database in bw.databases:
    list_databases.append(database)

# Step 2: Delete activities from databases whose names contain both 'ecoinvent' and 'Energy'
for database in list_databases:
    if 'ecoinvent' in database and 'Energy' in database:
        for activity in bw.Database(database):
            activity.delete()  # Remove each activity from the database
        print(database)  # Print the name of the database after deletion
#         del bw.databases[database]  # Optionally, delete the database entry from Brightway2

# Step 3: Load default energy datasets for the defined scenarios from Excel
dict_activities = deala_io_instance.create_target_databases(
    FP_energy_database,
    'Energy'
)

# Step 4: Identify dependent activities between the Energy databases and DEALA databases
dict_databases, dict_matches, lst_DB_DEALA, lst_DB_Energy = deala_io.identify_dependent_activities('Energy')

# Step 5: Identify matches between activities in the target energy database and ecoinvent
dict_matches = deala_io.identify_matches(lst_DB_Energy[0])

# Step 6: Copy default activities to regionalized activities and add respective DEALA activities to Energy activities
deala_io_instance.copy_and_add_DEALA_activity_fast(
    dict_databases=dict_databases,
    dict_target=dict_energy,
    dict_activities=dict_activities,
    overwrite=False,
    debug=True
)

# # Step 7: Update ecoinvent exchanges in the energy databases so that they match the defined location
ecoinvent_dbs = [
    db for db in bw.databases
    if "ecoinvent" in db and "Energy" not in db and "Transport" not in db
]

stats = deala_io_instance.update_exchanges_replace_consistent_fast(
    dict_matches=dict_matches,
    lst_DB_energy=lst_DB_Energy,
    lst_DB_ecoinvent=ecoinvent_dbs,
    debug=False
)
print(stats)
# Out:
# Extracted 7 worksheets in 0.01 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.05 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:47:42
#   Finished: 01/08/2026 18:47:42
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.16
# Created database: Energy
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:47:42
#   Finished: 01/08/2026 18:47:42
#   Total time elapsed: 00:00:00
#   CPU %: 67.00
#   Memory %: 10.16
# Extracted 7 worksheets in 0.01 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.06 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:47:45
#   Finished: 01/08/2026 18:47:45
#   Total time elapsed: 00:00:00
#   CPU %: 530.70
#   Memory %: 10.16
# Created database: Energy
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:47:45
#   Finished: 01/08/2026 18:47:45
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.16
# Extracted 7 worksheets in 0.01 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.05 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:47:48
#   Finished: 01/08/2026 18:47:48
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.15
# Created database: Energy
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:47:48
#   Finished: 01/08/2026 18:47:48
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.15
# Extracted 7 worksheets in 0.01 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.04 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:47:51
#   Finished: 01/08/2026 18:47:51
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.16
# Created database: Energy
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:47:51
#   Finished: 01/08/2026 18:47:51
#   Total time elapsed: 00:00:00
#   CPU %: 610.80
#   Memory %: 10.16
# Extracted 7 worksheets in 0.01 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.04 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:47:54
#   Finished: 01/08/2026 18:47:54
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.15
# Created database: Energy
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:47:54
#   Finished: 01/08/2026 18:47:54
#   Total time elapsed: 00:00:00
#   CPU %: 67.40
#   Memory %: 10.15
# Extracted 7 worksheets in 0.01 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.04 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:47:56
#   Finished: 01/08/2026 18:47:56
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.15
# Created database: Energy
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:47:57
#   Finished: 01/08/2026 18:47:57
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.15
# DEALA_activities_remind_SSP2-Base_ecoSpold02 ecoSpold02
# DEALA_activities_remind_SSP2-PkBudg1150_2030 2030
# DEALA_activities_remind_SSP2-Base_2030 2030
# DEALA_activities_remind_SSP2-Base_ecoSpold02 ecoSpold02
# DEALA_activities_remind_SSP2-PkBudg1150_2030 2030
# DEALA_activities_remind_SSP2-Base_2030 2030
# DEALA_activities_remind_SSP2-Base_ecoSpold02 ecoSpold02
# DEALA_activities_remind_SSP2-PkBudg1150_2030 2030
# DEALA_activities_remind_SSP2-Base_2030 2030
# DEALA_activities_remind_SSP2-Base_ecoSpold02 ecoSpold02
# DEALA_activities_remind_SSP2-PkBudg1150_2030 2030
# DEALA_activities_remind_SSP2-Base_2030 2030
# DEALA_activities_remind_SSP2-Base_ecoSpold02 ecoSpold02
# DEALA_activities_remind_SSP2-PkBudg1150_2030 2030
# DEALA_activities_remind_SSP2-Base_2030 2030
# DEALA_activities_remind_SSP2-Base_ecoSpold02 ecoSpold02
# DEALA_activities_remind_SSP2-PkBudg1150_2030 2030
# DEALA_activities_remind_SSP2-Base_2030 2030
# 100%|██████████| 6/6 [00:04<00:00,  1.28it/s]
# 100%|██████████| 7/7 [00:01<00:00,  4.48it/s]
# [INFO] Found 3 DEALA databases.
# Building Energy DBs: 100%|██████████| 6/6 [00:02<00:00,  2.39it/s]
# 🧩 Added 5040 new mappings.
#
# 🎉 Finished adding DEALA links to 6 Energy DBs (5040 total activities).
# Indexing ecoinvent DBs: 100%|██████████| 6/6 [00:02<00:00,  2.24it/s]
# Updating Energy DBs: 100%|██████████| 6/6 [00:04<00:00,  1.42it/s]
# {'Energy_ecoinvent_3.9.1-cutoff_remind_SSP2-Base_ecoSpold02': {'attempted': 840, 'updated': 579, 'failed': 0}, 'Energy_ecoinvent_3.9.1-cutoff_remind_SSP2-PkBudg1150_2030': {'attempted': 840, 'updated': 579, 'failed': 0}, 'Energy_ecoinvent_3.9.1-cutoff_remind_SSP2-Base_2030': {'attempted': 840, 'updated': 579, 'failed': 0}, 'Energy_ecoinvent_3.9.1-cutoff_remind_SSP2-Base_ecoSpold02 regionalized': {'attempted': 840, 'updated': 579, 'failed': 0}, 'Energy_ecoinvent_3.9.1-cutoff_remind_SSP2-PkBudg1150_2030 regionalized': {'attempted': 840, 'updated': 579, 'failed': 0}, 'Energy_ecoinvent_3.9.1-cutoff_remind_SSP2-Base_2030 regionalized': {'attempted': 840, 'updated': 579, 'failed': 0}}

# %% [markdown]
# ## 3.2 Import transport databases

# %%
#this function creates the transport databases for the defined scenarios
deala_io_instance.build_transport_databases_fast(
    dict_scenarios=dict_scenarios,
    FP_transport_matrices_land=FP_transport_matrices_land,
    FP_transport_matrices_sea=FP_transport_matrices_sea,
    FP_transport_matrices_land_harbor=FP_transport_matrices_land_harbor,
    name_ecoinvent_prefix=NAME_ECOINVENT_DB_SHORT,
    overwrite=True,
)
# Out:
# Writing transport activities: 100%|██████████| 16641/16641 [00:00<00:00, 25834.85it/s]
# [PROCESS] Transport_ecoinvent_3.9.1-cutoff_remind_SSP2-Base_ecoSpold02 processed successfully.
# Writing transport activities: 100%|██████████| 16641/16641 [00:00<00:00, 24576.59it/s]
# [PROCESS] Transport_ecoinvent_3.9.1-cutoff_remind_SSP2-Base_ecoSpold02 regionalized processed successfully.
# Writing transport activities: 100%|██████████| 16641/16641 [00:00<00:00, 25557.70it/s]
# [PROCESS] Transport_ecoinvent_3.9.1-cutoff_remind_SSP2-PkBudg1150_2030 processed successfully.
# Writing transport activities: 100%|██████████| 16641/16641 [00:00<00:00, 23529.09it/s]
# [PROCESS] Transport_ecoinvent_3.9.1-cutoff_remind_SSP2-PkBudg1150_2030 regionalized processed successfully.
# Writing transport activities: 100%|██████████| 16641/16641 [00:00<00:00, 25622.90it/s]
# [PROCESS] Transport_ecoinvent_3.9.1-cutoff_remind_SSP2-Base_2030 processed successfully.
# Writing transport activities: 100%|██████████| 16641/16641 [00:00<00:00, 24750.69it/s]
# [PROCESS] Transport_ecoinvent_3.9.1-cutoff_remind_SSP2-Base_2030 regionalized processed successfully.
#
# === Build Summary ===
# [UPDATE] Transport_ecoinvent_3.9.1-cutoff_remind_SSP2-Base_ecoSpold02 → 16,641 activities created.
# [UPDATE] Transport_ecoinvent_3.9.1-cutoff_remind_SSP2-Base_ecoSpold02 regionalized → 16,641 activities created.
# [UPDATE] Transport_ecoinvent_3.9.1-cutoff_remind_SSP2-PkBudg1150_2030 → 16,641 activities created.
# [UPDATE] Transport_ecoinvent_3.9.1-cutoff_remind_SSP2-PkBudg1150_2030 regionalized → 16,641 activities created.
# [UPDATE] Transport_ecoinvent_3.9.1-cutoff_remind_SSP2-Base_2030 → 16,641 activities created.
# [UPDATE] Transport_ecoinvent_3.9.1-cutoff_remind_SSP2-Base_2030 regionalized → 16,641 activities created.
# [INFO] ✅ 6 transport databases successfully built.

# %% [markdown]
# ## 3.3 import input materials

# %%
#import input materials database
databases=[db for db in bw.databases if 'Energy']
for scenario in dict_scenarios:
    for db in databases:
        if 'Energy' in db and 'regionalized' in db and scenario in db:
            name_add=" regionalized"
        elif 'Energy' in db and 'regionalized' not in db and scenario in db:
            name_add=""
        else:
            continue
        imp = bw.ExcelImporter(FP_INPUT_PATH)
        imp.apply_strategies()
        imp.match_database(fields=('name', 'unit', 'location', 'reference product'))
        imp.match_database(NAME_ECOINVENT_DB_SHORT + scenario + name_add, fields=('name','unit','location', 'reference product'))
        imp.match_database('regioinvent_' + scenario, fields=('name','unit','location', 'reference product'))
        imp.match_database('DEALA_activities_' + scenario, fields=('name','location', 'reference product'))
        imp.match_database('Energy_' + NAME_ECOINVENT_DB_SHORT + scenario + name_add, fields=('name','unit','location', 'reference product'))
        imp.match_database('biosphere3', fields=('name','unit','categories'))
        imp.statistics()
        imp.write_database()
        db = bw.Database(imp.db_name).rename(imp.db_name + '_' + scenario + name_add)
        # regionalization of activities in the databases
        deala_io_instance.regionalize_process_input_fast(db.name, dict_countries, commit_every=5000)
# Out:
# Extracted 6 worksheets in 0.01 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.04 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# 6 datasets
# 12 exchanges
# 0 unlinked exchanges
#
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:48:37
#   Finished: 01/08/2026 18:48:37
#   Total time elapsed: 00:00:00
#   CPU %: 559.00
#   Memory %: 10.16
# Created database: input_materials
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:48:37
#   Finished: 01/08/2026 18:48:37
#   Total time elapsed: 00:00:00
#   CPU %: 539.10
#   Memory %: 10.16
# [INFO] Starting fast regionalization for: input_materials_remind_SSP2-Base_ecoSpold02
# [INFO] → Using ecoinvent references
# [INFO] Using DEALA DB: DEALA_activities_remind_SSP2-Base_ecoSpold02
# [INFO] Cached 12478 DEALA activities.
# [INFO] Loaded 6 base activities.
# Regionalizing input_materials_remind_SSP2-Base_ecoSpold02: 100%|██████████| 6/6 [00:52<00:00,  8.81s/it]
# [INFO] Added 43 new mappings.
# [PROCESS] input_materials_remind_SSP2-Base_ecoSpold02 processed successfully.
#
# ✅ Finished regionalizing input_materials_remind_SSP2-Base_ecoSpold02. Total new activities: 43
# Extracted 6 worksheets in 0.02 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.07 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# 6 datasets
# 12 exchanges
# 0 unlinked exchanges
#
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:49:43
#   Finished: 01/08/2026 18:49:43
#   Total time elapsed: 00:00:00
#   CPU %: 627.80
#   Memory %: 10.16
# Created database: input_materials
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:49:43
#   Finished: 01/08/2026 18:49:43
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.16
# [INFO] Starting fast regionalization for: input_materials_remind_SSP2-Base_ecoSpold02 regionalized
# [INFO] → Using regioinvent references
# [INFO] Using DEALA DB: DEALA_activities_remind_SSP2-Base_ecoSpold02
# [INFO] Cached 12478 DEALA activities.
# [INFO] Loaded 6 base activities.
# Regionalizing input_materials_remind_SSP2-Base_ecoSpold02 regionalized: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# [INFO] Added 43 new mappings.
# [PROCESS] input_materials_remind_SSP2-Base_ecoSpold02 regionalized processed successfully.
#
# ✅ Finished regionalizing input_materials_remind_SSP2-Base_ecoSpold02 regionalized. Total new activities: 43
# Extracted 6 worksheets in 0.01 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.04 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# 6 datasets
# 12 exchanges
# 0 unlinked exchanges
#
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:49:53
#   Finished: 01/08/2026 18:49:53
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.16
# Created database: input_materials
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:49:53
#   Finished: 01/08/2026 18:49:53
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.16
# [INFO] Starting fast regionalization for: input_materials_remind_SSP2-PkBudg1150_2030
# [INFO] → Using ecoinvent references
# [INFO] Using DEALA DB: DEALA_activities_remind_SSP2-PkBudg1150_2030
# [INFO] Cached 12478 DEALA activities.
# [INFO] Loaded 6 base activities.
# Regionalizing input_materials_remind_SSP2-PkBudg1150_2030: 100%|██████████| 6/6 [00:52<00:00,  8.79s/it]
# [INFO] Added 43 new mappings.
# [PROCESS] input_materials_remind_SSP2-PkBudg1150_2030 processed successfully.
#
# ✅ Finished regionalizing input_materials_remind_SSP2-PkBudg1150_2030. Total new activities: 43
# Extracted 6 worksheets in 0.02 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.08 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# 6 datasets
# 12 exchanges
# 0 unlinked exchanges
#
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:50:50
#   Finished: 01/08/2026 18:50:50
#   Total time elapsed: 00:00:00
#   CPU %: 567.80
#   Memory %: 10.16
# Created database: input_materials
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:50:51
#   Finished: 01/08/2026 18:50:51
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.16
# [INFO] Starting fast regionalization for: input_materials_remind_SSP2-PkBudg1150_2030 regionalized
# [INFO] → Using regioinvent references
# [INFO] Using DEALA DB: DEALA_activities_remind_SSP2-PkBudg1150_2030
# [INFO] Cached 12478 DEALA activities.
# [INFO] Loaded 6 base activities.
# Regionalizing input_materials_remind_SSP2-PkBudg1150_2030 regionalized: 100%|██████████| 6/6 [00:15<00:00,  2.51s/it]
# [INFO] Added 43 new mappings.
# [PROCESS] input_materials_remind_SSP2-PkBudg1150_2030 regionalized processed successfully.
#
# ✅ Finished regionalizing input_materials_remind_SSP2-PkBudg1150_2030 regionalized. Total new activities: 43
# Extracted 6 worksheets in 0.03 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.06 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# 6 datasets
# 12 exchanges
# 0 unlinked exchanges
#
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:51:10
#   Finished: 01/08/2026 18:51:10
#   Total time elapsed: 00:00:00
#   CPU %: 557.50
#   Memory %: 10.16
# Created database: input_materials
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:51:10
#   Finished: 01/08/2026 18:51:10
#   Total time elapsed: 00:00:00
#   CPU %: 505.10
#   Memory %: 10.16
# [INFO] Starting fast regionalization for: input_materials_remind_SSP2-Base_2030
# [INFO] → Using ecoinvent references
# [INFO] Using DEALA DB: DEALA_activities_remind_SSP2-Base_2030
# [INFO] Cached 12478 DEALA activities.
# [INFO] Loaded 6 base activities.
# Regionalizing input_materials_remind_SSP2-Base_2030: 100%|██████████| 6/6 [00:52<00:00,  8.81s/it]
# [INFO] Added 43 new mappings.
# [PROCESS] input_materials_remind_SSP2-Base_2030 processed successfully.
#
# ✅ Finished regionalizing input_materials_remind_SSP2-Base_2030. Total new activities: 43
# Extracted 6 worksheets in 0.02 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.07 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# 6 datasets
# 12 exchanges
# 0 unlinked exchanges
#
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:52:07
#   Finished: 01/08/2026 18:52:07
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.16
# Created database: input_materials
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:52:07
#   Finished: 01/08/2026 18:52:07
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.16
# [INFO] Starting fast regionalization for: input_materials_remind_SSP2-Base_2030 regionalized
# [INFO] → Using regioinvent references
# [INFO] Using DEALA DB: DEALA_activities_remind_SSP2-Base_2030
# [INFO] Cached 12478 DEALA activities.
# [INFO] Loaded 6 base activities.
# Regionalizing input_materials_remind_SSP2-Base_2030 regionalized: 100%|██████████| 6/6 [00:13<00:00,  2.32s/it]
# [INFO] Added 43 new mappings.
# [PROCESS] input_materials_remind_SSP2-Base_2030 regionalized processed successfully.
#
# ✅ Finished regionalizing input_materials_remind_SSP2-Base_2030 regionalized. Total new activities: 43

# %% [markdown]
# ## 3.4 import output materials

# %%
#import output materials database
databases=[db for db in bw.databases if 'Energy']
for scenario in dict_scenarios:
    for db in databases:
        if 'Energy' in db and 'regionalized' in db and scenario in db:
            name_add=" regionalized"
        elif 'Energy' in db and 'regionalized' not in db and scenario in db:
            name_add=""
        else:
            continue
        target_db_name = f"output_materials_{scenario }{name_add}"
        if target_db_name in bw.databases:
            for activity in bw.Database(target_db_name):
                activity.delete()

        imp = bw.ExcelImporter(FP_OUTPUT_PATH)
        imp.apply_strategies()
        imp.match_database(fields=('name', 'unit', 'location', 'reference product'))
        imp.match_database(NAME_ECOINVENT_DB_SHORT + scenario + name_add, fields=('name','unit','location', 'reference product'))
        imp.match_database('DEALA_activities_' + scenario, fields=('name','location', 'reference product'))
        imp.match_database('Energy_' + NAME_ECOINVENT_DB_SHORT + scenario + name_add, fields=('name','unit','location', 'reference product'))
        imp.match_database('biosphere3', fields=('name','unit','categories'))
        imp.statistics()
        imp.write_database()
        db = bw.Database(imp.db_name).rename(imp.db_name + '_' + scenario + name_add)
        # regionalization of activities in the databases
        deala_io_instance.regionalize_process_outputmaterials_fast(db.name)
# Out:
# Extracted 4 worksheets in 0.02 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.05 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# 4 datasets
# 8 exchanges
# 0 unlinked exchanges
#
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:52:25
#   Finished: 01/08/2026 18:52:25
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.16
# Created database: output_materials
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:52:25
#   Finished: 01/08/2026 18:52:25
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.16
# [INFO] Starting optimized regionalization for output_materials_remind_SSP2-Base_ecoSpold02
# Regionalizing output_materials_remind_SSP2-Base_ecoSpold02: 100%|██████████| 4/4 [00:00<00:00, 17.38it/s]
# [PROCESS] output_materials_remind_SSP2-Base_ecoSpold02 processed successfully.
#
# ✅ Finished regionalizing output_materials_remind_SSP2-Base_ecoSpold02
# [INFO] Total new activities: 585
# [INFO] Duration: 1.54s
# Extracted 4 worksheets in 0.01 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.06 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# 4 datasets
# 8 exchanges
# 0 unlinked exchanges
#
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:52:29
#   Finished: 01/08/2026 18:52:29
#   Total time elapsed: 00:00:00
#   CPU %: 584.70
#   Memory %: 10.16
# Created database: output_materials
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:52:29
#   Finished: 01/08/2026 18:52:29
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.16
# [INFO] Starting optimized regionalization for output_materials_remind_SSP2-Base_ecoSpold02 regionalized
# Regionalizing output_materials_remind_SSP2-Base_ecoSpold02 regionalized: 100%|██████████| 4/4 [00:19<00:00,  4.88s/it]
# [PROCESS] output_materials_remind_SSP2-Base_ecoSpold02 regionalized processed successfully.
#
# ✅ Finished regionalizing output_materials_remind_SSP2-Base_ecoSpold02 regionalized
# [INFO] Total new activities: 585
# [INFO] Duration: 20.31s
# Extracted 4 worksheets in 0.01 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.05 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# 4 datasets
# 8 exchanges
# 0 unlinked exchanges
#
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:52:53
#   Finished: 01/08/2026 18:52:53
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.16
# Created database: output_materials
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:52:53
#   Finished: 01/08/2026 18:52:53
#   Total time elapsed: 00:00:00
#   CPU %: 574.60
#   Memory %: 10.16
# [INFO] Starting optimized regionalization for output_materials_remind_SSP2-PkBudg1150_2030
# Regionalizing output_materials_remind_SSP2-PkBudg1150_2030: 100%|██████████| 4/4 [00:00<00:00, 17.32it/s]
# [PROCESS] output_materials_remind_SSP2-PkBudg1150_2030 processed successfully.
#
# ✅ Finished regionalizing output_materials_remind_SSP2-PkBudg1150_2030
# [INFO] Total new activities: 585
# [INFO] Duration: 1.37s
# Extracted 4 worksheets in 0.01 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.05 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# 4 datasets
# 8 exchanges
# 0 unlinked exchanges
#
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:53:05
#   Finished: 01/08/2026 18:53:05
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.16
# Created database: output_materials
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:53:06
#   Finished: 01/08/2026 18:53:06
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.16
# [INFO] Starting optimized regionalization for output_materials_remind_SSP2-PkBudg1150_2030 regionalized
# Regionalizing output_materials_remind_SSP2-PkBudg1150_2030 regionalized: 100%|██████████| 4/4 [00:19<00:00,  4.86s/it]
# [PROCESS] output_materials_remind_SSP2-PkBudg1150_2030 regionalized processed successfully.
#
# ✅ Finished regionalizing output_materials_remind_SSP2-PkBudg1150_2030 regionalized
# [INFO] Total new activities: 585
# [INFO] Duration: 20.22s
# Extracted 4 worksheets in 0.01 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.05 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# 4 datasets
# 8 exchanges
# 0 unlinked exchanges
#
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:53:29
#   Finished: 01/08/2026 18:53:29
#   Total time elapsed: 00:00:00
#   CPU %: 612.60
#   Memory %: 10.16
# Created database: output_materials
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:53:29
#   Finished: 01/08/2026 18:53:29
#   Total time elapsed: 00:00:00
#   CPU %: 74.60
#   Memory %: 10.16
# [INFO] Starting optimized regionalization for output_materials_remind_SSP2-Base_2030
# Regionalizing output_materials_remind_SSP2-Base_2030: 100%|██████████| 4/4 [00:00<00:00, 17.61it/s]
# [PROCESS] output_materials_remind_SSP2-Base_2030 processed successfully.
#
# ✅ Finished regionalizing output_materials_remind_SSP2-Base_2030
# [INFO] Total new activities: 585
# [INFO] Duration: 1.36s
# Extracted 4 worksheets in 0.01 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.05 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# 4 datasets
# 8 exchanges
# 0 unlinked exchanges
#
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:53:33
#   Finished: 01/08/2026 18:53:33
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.16
# Created database: output_materials
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:53:33
#   Finished: 01/08/2026 18:53:33
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.16
# [INFO] Starting optimized regionalization for output_materials_remind_SSP2-Base_2030 regionalized
# Regionalizing output_materials_remind_SSP2-Base_2030 regionalized: 100%|██████████| 4/4 [00:19<00:00,  4.84s/it]
# [PROCESS] output_materials_remind_SSP2-Base_2030 regionalized processed successfully.
#
# ✅ Finished regionalizing output_materials_remind_SSP2-Base_2030 regionalized
# [INFO] Total new activities: 585
# [INFO] Duration: 20.13s

# %% [markdown]
# # 4. Import foreground system
#
# <p style="font-size:12px">
# The foreground system consists of one databases representing the conventional non-stick pan that must be imported into the initialized project. This databases is called:
# </p>
#
# <ul style="font-size:12px; padding-left: 20px">
#   <li>Non-stick pan (conventional)</li>
# </ul>
#
# <p style="font-size:12px">
# The database is loaded from pre-defined Excel sheets, including global representations of the production steps. These databases are created for the defined scenarios and subsequently regionalized. After regionalization, the corresponding economic DEALA activities are added to the activities in the databases. For this step, the following priority is applied:
# </p>
#
# <ol style="font-size:12px; padding-left: 20px">
#   <li>Add DEALA activities representing maintenance and repair for buildings and machines (investment-dependent).</li>
#   <li>Add DEALA activities representing insurance (investment-dependent).</li>
#   <li>Add DEALA activities representing interest (investment-dependent). The investment is divided by 0.5, as the average interest method is applied in this case study.</li>
#   <li>Add DEALA activities representing administration (personnel cost-dependent).</li>
#   <li>Add DEALA activities representing research and development (total cost-dependent, excluding taxes and warranty).</li>
#   <li>Add DEALA activities representing warranty (total cost-dependent, excluding taxes and revenues from co-products).</li>
# </ol>

# %% [markdown]
# ## 4.1 Non-stick pan (conventional)

# %%
### import pan production processes ###
databases=[db for db in bw.databases if 'Energy']
for scenario in dict_scenarios:
    for db in databases:
        if 'Energy' in db and 'regionalized' in db and scenario in db:
            name_add=" regionalized"
        elif 'Energy' in db and 'regionalized' not in db and scenario in db:
            name_add=""
        else:
            continue
        imp = bw.ExcelImporter(FP_NON_STICK_CONVENTIONAL)
        imp.apply_strategies()
        imp.match_database(fields=('name', 'unit', 'location', 'reference product'))
        imp.match_database(NAME_ECOINVENT_DB_SHORT + scenario + name_add, fields=('name','unit','location', 'reference product'))
        imp.match_database('DEALA_activities_' + scenario, fields=('name','location', 'reference product'))
        imp.match_database('input_materials_' + scenario + name_add, fields=('name','unit','location', 'reference product'))
        imp.match_database('output_materials_' + scenario + name_add, fields=('name','unit','location', 'reference product'))
        imp.match_database('Energy_' + NAME_ECOINVENT_DB_SHORT + scenario + name_add, fields=('name','unit','location', 'reference product'))
        imp.match_database('biosphere3', fields=('name','unit','categories'))
        imp.statistics()
        imp.write_database()
        db = bw.Database(imp.db_name).rename(imp.db_name + '_' + scenario + name_add)


        ### regionalization of activities in the databases ###
        deala_io_instance.regionalize_processes_foreground(db.name, dict_countries)


        ### add the investment-dependent deala activities to the processes of the foreground system ###
        db_deala=bw.Database('DEALA_activities_' + scenario)
        dict_machine, dict_buildings, total_investments = deala_io_instance.calculate_investments_buildings_machine(db, 'depreciation (linear) - machinery and equipment', 'depreciation (linear) - Advanced manufacturing facility') # calculate the investments for buildings and machinery
        # add DEALA activities representing maintenance and repair for buildings
        deala_io_instance.dependent_DEALA_activity_percentage_rate(db, db_deala, dict_buildings, percentage_rate_buildings)
        # add DEALA activities representing maintenance and repair for machines and equipment
        deala_io_instance.dependent_DEALA_activity_percentage_rate(db, db_deala, dict_machine, percentage_rate_machinery)
        # add DEALA activities representing insurance dependent on all investments
        deala_io_instance.dependent_DEALA_activity_percentage_rate(db, db_deala, total_investments, percentage_rate_insurance)
        # add DEALA activities representing interest dependent on all investments
        for location in dict_interest:
            deala_io_instance.dependent_DEALA_activity_percentage_rate(db, db_deala, total_investments, dict_interest[location], amount=0.5, location=location)

        
        ### add the deala activities depending on personnel cost to the processes of the foreground system ###
        # calculate the investments for buildings and machines
        dict_personnel = deala_io_instance.calculate_personnel_cost_processes(db)
        # add DEALA activities representing administration
        deala_io_instance.dependent_DEALA_activity_percentage_rate(db, db_deala, dict_personnel, percentage_rate_administration, keyword='personnel cost')

        
        ## add the deala activities depending on total cost without taxes and warranty to the processes of the foreground system ###
        # calculate the total cost
        total_cost = deala_io_instance.calculate_total_cost_processes(db)
        # # add DEALA activities representing research and development
        deala_io_instance.dependent_DEALA_activity_percentage_rate(db, db_deala, total_cost, percentage_rate_research_development, keyword='total cost')


        ### add the deala activities depending on total cost without taxes to the processes of the foreground system ###
        # calculate the total cost of processes
        total_cost = deala_io_instance.calculate_total_cost_processes_wo_co_products(db)
        # add DEALA activities representing warranty
        deala_io_instance.dependent_DEALA_activity_percentage_rate(db, db_deala, total_cost, percentage_rate_warranty, keyword='total cost')
# Out:
# Extracted 8 worksheets in 0.01 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.05 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# 8 datasets
# 52 exchanges
# 0 unlinked exchanges
#
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:53:57
#   Finished: 01/08/2026 18:53:57
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.16
# Created database: Non-stick pan (conventional)
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:53:57
#   Finished: 01/08/2026 18:53:57
#   Total time elapsed: 00:00:00
#   CPU %: 380.30
#   Memory %: 10.16
# [PHASE 1] Preparing copies for 8 activities …
# Create in-memory copies: 100%|██████████| 8/8 [00:00<00:00, 947.09it/s]
# [PHASE 2] Building indices for 6 referenced DBs …
# Index DBs: 100%|██████████| 6/6 [00:00<00:00, 32.55it/s]
# [PHASE 3] Rewiring exchanges in memory …
# Apply rewiring: 100%|██████████| 88/88 [00:00<00:00, 5263.22it/s]
# [PHASE 3] Rewired 572 inputs.
# [PHASE 4] Writing 88 activities to SQLite …
# Insert into DB: 100%|██████████| 88/88 [00:00<00:00, 16131.94it/s]
# [INFO] Added 88 new mappings.
# [PROCESS] Non-stick pan (conventional)_remind_SSP2-Base_ecoSpold02 processed successfully.
#
# ✅ Regionalization complete: 88 activities created; 572 inputs rewired.
# /Users/popien/Desktop/development/DEALA/.venv/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:737: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.75e+13)
#   warnings.warn(msg, UmfpackWarning)
# Extracted 8 worksheets in 0.01 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.03 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# 8 datasets
# 52 exchanges
# 0 unlinked exchanges
#
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:55:50
#   Finished: 01/08/2026 18:55:50
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 14.14
# Created database: Non-stick pan (conventional)
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:55:50
#   Finished: 01/08/2026 18:55:50
#   Total time elapsed: 00:00:00
#   CPU %: 414.80
#   Memory %: 14.14
# [PHASE 1] Preparing copies for 8 activities …
# Create in-memory copies: 100%|██████████| 8/8 [00:00<00:00, 969.08it/s]
# [PHASE 2] Building indices for 6 referenced DBs …
# Index DBs: 100%|██████████| 6/6 [00:00<00:00, 41.82it/s]
# [PHASE 3] Rewiring exchanges in memory …
# Apply rewiring: 100%|██████████| 88/88 [00:00<00:00, 5343.68it/s]
# [PHASE 3] Rewired 572 inputs.
# [PHASE 4] Writing 88 activities to SQLite …
# Insert into DB: 100%|██████████| 88/88 [00:00<00:00, 15605.39it/s]
# [INFO] Added 88 new mappings.
# [PROCESS] Non-stick pan (conventional)_remind_SSP2-Base_ecoSpold02 regionalized processed successfully.
#
# ✅ Regionalization complete: 88 activities created; 572 inputs rewired.
# Extracted 8 worksheets in 0.01 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.03 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# 8 datasets
# 52 exchanges
# 0 unlinked exchanges
#
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:57:36
#   Finished: 01/08/2026 18:57:36
#   Total time elapsed: 00:00:00
#   CPU %: 398.90
#   Memory %: 17.48
# Created database: Non-stick pan (conventional)
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:57:36
#   Finished: 01/08/2026 18:57:36
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 17.48
# [PHASE 1] Preparing copies for 8 activities …
# Create in-memory copies: 100%|██████████| 8/8 [00:00<00:00, 950.79it/s]
# [PHASE 2] Building indices for 6 referenced DBs …
# Index DBs: 100%|██████████| 6/6 [00:00<00:00, 31.81it/s]
# [PHASE 3] Rewiring exchanges in memory …
# Apply rewiring: 100%|██████████| 88/88 [00:00<00:00, 5275.70it/s]
# [PHASE 3] Rewired 572 inputs.
# [PHASE 4] Writing 88 activities to SQLite …
# Insert into DB: 100%|██████████| 88/88 [00:00<00:00, 15982.45it/s]
# [INFO] Added 88 new mappings.
# [PROCESS] Non-stick pan (conventional)_remind_SSP2-PkBudg1150_2030 processed successfully.
#
# ✅ Regionalization complete: 88 activities created; 572 inputs rewired.
# /Users/popien/Desktop/development/DEALA/.venv/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:737: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 6.06e+19)
#   warnings.warn(msg, UmfpackWarning)
# Extracted 8 worksheets in 0.01 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.04 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# 8 datasets
# 52 exchanges
# 0 unlinked exchanges
#
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:59:10
#   Finished: 01/08/2026 18:59:10
#   Total time elapsed: 00:00:00
#   CPU %: 50.10
#   Memory %: 21.03
# Created database: Non-stick pan (conventional)
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 18:59:10
#   Finished: 01/08/2026 18:59:10
#   Total time elapsed: 00:00:00
#   CPU %: 374.60
#   Memory %: 21.03
# [PHASE 1] Preparing copies for 8 activities …
# Create in-memory copies: 100%|██████████| 8/8 [00:00<00:00, 950.69it/s]
# [PHASE 2] Building indices for 6 referenced DBs …
# Index DBs: 100%|██████████| 6/6 [00:00<00:00, 45.12it/s]
# [PHASE 3] Rewiring exchanges in memory …
# Apply rewiring: 100%|██████████| 88/88 [00:00<00:00, 5283.10it/s]
# [PHASE 3] Rewired 572 inputs.
# [PHASE 4] Writing 88 activities to SQLite …
# Insert into DB: 100%|██████████| 88/88 [00:00<00:00, 15603.41it/s]
# [INFO] Added 88 new mappings.
# [PROCESS] Non-stick pan (conventional)_remind_SSP2-PkBudg1150_2030 regionalized processed successfully.
#
# ✅ Regionalization complete: 88 activities created; 572 inputs rewired.
# /Users/popien/Desktop/development/DEALA/.venv/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:737: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 8.50e+19)
#   warnings.warn(msg, UmfpackWarning)
# Extracted 8 worksheets in 0.01 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.04 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# 8 datasets
# 52 exchanges
# 0 unlinked exchanges
#
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 19:02:10
#   Finished: 01/08/2026 19:02:10
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 27.88
# Created database: Non-stick pan (conventional)
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 19:02:10
#   Finished: 01/08/2026 19:02:10
#   Total time elapsed: 00:00:00
#   CPU %: 45.40
#   Memory %: 27.88
# [PHASE 1] Preparing copies for 8 activities …
# Create in-memory copies: 100%|██████████| 8/8 [00:00<00:00, 955.69it/s]
# [PHASE 2] Building indices for 6 referenced DBs …
# Index DBs: 100%|██████████| 6/6 [00:00<00:00, 29.81it/s]
# [PHASE 3] Rewiring exchanges in memory …
# Apply rewiring: 100%|██████████| 88/88 [00:00<00:00, 5264.72it/s]
# [PHASE 3] Rewired 572 inputs.
# [PHASE 4] Writing 88 activities to SQLite …
# Insert into DB: 100%|██████████| 88/88 [00:00<00:00, 16454.12it/s]
# [INFO] Added 88 new mappings.
# [PROCESS] Non-stick pan (conventional)_remind_SSP2-Base_2030 processed successfully.
#
# ✅ Regionalization complete: 88 activities created; 572 inputs rewired.
# /Users/popien/Desktop/development/DEALA/.venv/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:737: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 6.66e+19)
#   warnings.warn(msg, UmfpackWarning)
# Extracted 8 worksheets in 0.01 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 2.04 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# 8 datasets
# 52 exchanges
# 0 unlinked exchanges
#
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 19:03:35
#   Finished: 01/08/2026 19:03:35
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 30.56
# Created database: Non-stick pan (conventional)
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 01/08/2026 19:03:35
#   Finished: 01/08/2026 19:03:35
#   Total time elapsed: 00:00:00
#   CPU %: 364.60
#   Memory %: 30.56
# [PHASE 1] Preparing copies for 8 activities …
# Create in-memory copies: 100%|██████████| 8/8 [00:00<00:00, 954.63it/s]
# [PHASE 2] Building indices for 6 referenced DBs …
# Index DBs: 100%|██████████| 6/6 [00:00<00:00, 45.37it/s]
# [PHASE 3] Rewiring exchanges in memory …
# Apply rewiring: 100%|██████████| 88/88 [00:00<00:00, 5273.29it/s]
# [PHASE 3] Rewired 572 inputs.
# [PHASE 4] Writing 88 activities to SQLite …
# Insert into DB: 100%|██████████| 88/88 [00:00<00:00, 15790.32it/s]
# [INFO] Added 88 new mappings.
# [PROCESS] Non-stick pan (conventional)_remind_SSP2-Base_2030 regionalized processed successfully.
#
# ✅ Regionalization complete: 88 activities created; 572 inputs rewired.
# /Users/popien/Desktop/development/DEALA/.venv/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:737: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 8.50e+19)
#   warnings.warn(msg, UmfpackWarning)
