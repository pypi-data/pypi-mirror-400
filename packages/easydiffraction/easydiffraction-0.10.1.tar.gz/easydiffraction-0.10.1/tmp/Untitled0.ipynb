# %%
from easydiffraction.sample_models.categories.atom_sites import AtomSite
from easydiffraction.sample_models.categories.cell import Cell
from easydiffraction.sample_models.categories.space_group import SpaceGroup

# %%
from easydiffraction.utils.logging import Logger

Logger.configure(
    level=Logger.Level.WARNING,
    mode=Logger.Mode.VERBOSE,
    reaction=Logger.Reaction.WARN,
)

# %%
s1 = AtomSite(label='La', type_symbol='La')

# %%
s1.fract_x.value = 1.234

# %%
s1.fract_x.value = 'xyz'
# Out:
# WARNING  Type mismatch for <atom_site.La.fract_x>. Expected `numeric`, got `str` ('xyz'). Keeping current 1.234.

# %%
s1.fract_x = 'qwe'
# Out:
# WARNING  Type mismatch for <atom_site.La.fract_x>. Expected `numeric`, got `str` ('qwe'). Keeping current 1.234.

# %%
s1 = AtomSite(label='Si', type_symbol='Si', fract_x='uuuu')
# Out:
# WARNING  Type mismatch for <fract_x>. Expected `numeric`, got `str` ('uuuu'). Using default 0.0.

# %%
s1.fract_x.free = True

# %%
s1.fract_x.free = 'abc'
# Out:
# WARNING  Type mismatch for <atom_site.Si.fract_x.free>. Expected `bool`, got `str` ('abc'). Keeping current True.

# %%
c = Cell()

# %%
c = Cell(length_b=-8.8)
# Out:
# WARNING  Value mismatch for <length_b>. Provided -8.8 outside [0, 1000]. Using default 10.0.

# %%
c = Cell(length_b='7.7')
# Out:
# WARNING  Type mismatch for <length_b>. Expected `numeric`, got `str` ('7.7'). Using default 10.0.

# %%
c = Cell(length_b=6.6)

# %%
c.length_b.value = -5.5
# Out:
# WARNING  Value mismatch for <cell.length_b>. Provided -5.5 outside [0, 1000]. Keeping current 6.6.

# %%
c.length_b = -4.4
# Out:
# WARNING  Value mismatch for <cell.length_b>. Provided -4.4 outside [0, 1000]. Keeping current 6.6.

# %%
c.length_b = 3.3

# %%
c.length_b = 2222.2
# Out:
# WARNING  Value mismatch for <cell.length_b>. Provided 2222.2 outside [0, 1000]. Keeping current 3.3.

# %%
c.length_b.free = 'qwe'
# Out:
# WARNING  Type mismatch for <cell.length_b.free>. Expected `bool`, got `str` ('qwe'). Keeping current False.

# %%
c.length_b.fre = 'fre'
# Out:
# WARNING  Unknown attribute 'fre' of <cell.length_b>. Did you mean 'free'?

# %%
c.length_b.qwe = 'qwe'
# Out:
# WARNING  Unknown attribute 'qwe' of <cell.length_b>. Allowed writable: 'fit_max', 'fit_min', 'free', 'uncertainty',
#          'value'.

# %%
c.length_b.description = 'desc'
# Out:
# WARNING  Cannot modify read-only attribute 'description' of <cell.length_b>.

# %%
c.qwe = 'qwe'
# Out:
# WARNING  Unknown attribute 'qwe' of <cell>. Allowed writable: 'angle_alpha', 'angle_beta', 'angle_gamma', 'length_a',
#          'length_b', 'length_c'.

# %%
sg = SpaceGroup()

# %%
sg = SpaceGroup(name_h_m='qwe')
# Out:
# WARNING  Value mismatch for <name_h_m>. Provided 'qwe' is unknown. (230 allowed values not listed here). Using default
#          'P 1'.

# %%
sg = SpaceGroup(name_h_m='P n m', it_coordinate_system_code='cab')
# Out:
# WARNING  Value mismatch for <name_h_m>. Provided 'P n m' is unknown. (230 allowed values not listed here). Using default
#          'P 1'.
# WARNING  Value mismatch for <it_coordinate_system_code>. Provided 'cab' is unknown. Allowed values: ''. Using default
#          ''.

# %%
sg = SpaceGroup(name_h_m='P n m a', it_coordinate_system_code='cabd')
# Out:
# WARNING  Value mismatch for <it_coordinate_system_code>. Provided 'cabd' is unknown. Allowed values: '-cba', 'a-cb',
#          'abc', 'ba-c', 'bca', 'cab'. Using default 'abc'.

# %%
sg.name_h_m = 34.9
# Out:
# WARNING  Type mismatch for <space_group.name_h_m>. Expected `string`, got `float` (34.9). Keeping current 'P n m a'.

# %%
sg.name_h_m = 'P 1'

# %%
sg.name_h_m = 'P n m a'
